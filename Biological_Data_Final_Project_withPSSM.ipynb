# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install biopython
# Out:
# Collecting biopython
#   Downloading biopython-1.85-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from biopython) (1.26.4)
# Downloading biopython-1.85-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 31.0 MB/s eta 0:00:00
# Installing collected packages: biopython
# Successfully installed biopython-1.85

# %%
import os
import pandas as pd
import math
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
import requests
import xml.etree.ElementTree as ET
from collections import Counter
from time import sleep
import networkx as nx
from Bio import SeqIO
from Bio.ExPASy import Prosite
import re
import string

# %% [markdown]
# # Models Building
#
# 1. Retrieve homologous proteins starting from the given input sequence performing an NCBI BLAST search (https://www.ebi.ac.uk/jdispatcher/sss/ncbiblast) against UniProtKB/Swiss-Prot (The manually annotated section of UniProtKB).
# Parameters:
# - Sequence type: Protein
# - Program: blastp
# - Matrix (The substitution matrix used for scoring alignments when searching the database): BLOSUM62
# - Gap open (Penalty taken away from the score when a gap is created in sequence. Increasing the gap opening penalty will decrease the number of gaps in the final alignment): 11
# - Gap extend (Penalty taken away from the score for each base or residue in the gap. Increasing the gap extension penalty favors short gaps in the final alignment, conversly decreasing the gap extension penalty favors long gaps in the final alignment): 1
# - Exp. thr (Limits the number of scores and alignments reported based on the expectation value. This is the maximum number of times the match is expected to occur by chance): 1e-5
# - Scores (Maximum number of match score summaries reported in the result output): 1000
# - Alignments (Maximum number of match alignments reported in the result output): 1000
# - Sequence range (Specify a range or section of the input sequence to use in the search): Start-End
# - HSPS (Maximum number of HSPs alignments to keep for any single query-subject pair): 100
# - Word size (Word size for wordfinder algorithm): 6
#
# Obtained 302 results (sequences) with E-value ranging from 2.5e-69 to 9.4e-6 Downloaded all the alignments in FASTA format. The resulting file is located in the 'data/blast' folder and is named blast_swissprot.fasta.
#
# 2. Generate a multiple sequence alignment (MSA) starting from retrieved hits using ClustalOmega and MUSCLE.
#
# ClustalOmega (maximum 4000 sequences):
# - Sequence type: Protein
# - Output format: Pearson/FASTA
# - Other default parameters
#
# MUSCLE (maximum 500 sequences):
# - Output format: Pearson/FASTA
# - Other default parameters
#
# Result Files -> Alignment in FASTA format (.aln-fasta) and The alignment in FASTA format converted by Seqret (.fa). The output files are inside 'data/msa' folder and are named: 'clustalo.fa' and 'muscle.fa'
#
# 3. Edit the MSA with JalView to remove not conserved positions (columns) and/or redundant information (rows)
# - No refinement (Clustal Omega and MUSCLE - 302 sequences)
# - Remove redundancy at 100% threshold and remove empty columns (Clustal Omega - 178 sequences, MUSCLE-277 sequences)
# - Remove redundancy at 100% threshold, remove empty columns and remove poorly occupied columns (less than 15 percent) (Clustal Omega - 178 sequences, MUSCLE-277 sequences)
# - Remove redundancy at 100% threshold, remove empty columns and remove columns with consensus below 10% (Clustal Omega - 178 sequences, MUSCLE-277 sequences)
#
# The output files are inside 'data/msa_after_jalview' folder and are named: 'clustalo-1.fa', 'clustalo-2.fa', 'clustalo-3.fa', 'clustalo-4.fa',
# 'muscle-1.fa', 'muscle-2.fa', 'muscle-3.fa', 'muscle-4.fa'.
#
# 4. Build an HMM model starting from the MSA
#
# The output files are inside the 'data/hmm' folder and are named: 'clustalo-1.hmm', 'clustalo-2.hmm', 'clustalo-3.hmm', 'clustalo-4.hmm',
# 'muscle-1.hmm', 'muscle-2.hmm', 'muscle-3.hmm', 'muscle-4.hmm'.
#
# 5. Build an PSSM model starting from the MSA
#
# The output files are inside the 'data/pssm' folder and are named: The output files are inside the 'data/hmm' folder and are named: 'clustalo-1.hmm', 'clustalo-2.pssm', 'clustalo-3.pssm', 'clustalo-4.pssm',
# 'muscle-1.pssm', 'muscle-2.pssm', 'muscle-3.pssm', 'muscle-4.pssm'.

# %%
# Constants
SWISSPROT_SIZE = 572619 # Total number of SwissProt proteins
SWISSPROT_LENGTH = 207431389 # Total residue count in SwissProt
MSA_METHODS = ["clustalo", "muscle"] # Alignment methods used
DATA_FOLDER ="/content/drive/MyDrive/Biological-Data-Project/data/" # Base data folder

# %% [markdown]
# # Model evaluation
#
# ## Prediction
#
# In this part we generate the prediction by running HMM-SEARCH against the SwissProt database, with our eight different models described previously. We collected the list of retrieved hits and the matching positions of our models in the retrieved hits. The output files ase inside the 'data/predictions' folder and are names: 'clustalo-1-hmmsearch.tsv', 'clustalo-2-hmmsearch.tsv', 'clustalo-3-hmmsearch.tsv', 'clustalo-4-hmmsearch.tsv', 'muscle-1-hmmsearch.tsv', 'muscle-2-hmmsearch.tsv', 'muscle-3-hmmsearch.tsv', 'muscle-4-hmmsearch.tsv'.
#
# ## Ground Truth
#
# Next step is to define a ground truth to evaluate our results and this is done by finding all proteins in SwissProt annotated with the Pfam domain - PF00085, given in the file named 'protein-matching-PF00085/tsv'. To do this, we collect the set of SwissProt proteins matching the assigned Pfam domain, and also collect the matching positions of the Pfam domain in the sequences by performing a search for the domain by its id on the InterPro database. We found 474 proteins from SwissProt that contain the Thioredoxin domain.

# %%
# Read Ground Truth Data
def load_ground_truth(file_path):
    """Loads ground truth data from TSV file and processes matching residue positions."""

    # Read the TSV file into a pandas DataFrame
    df = pd.read_csv(file_path, sep='\t')
    unique_proteins = df.shape[0]
    print(f"Number of unique proteins with PF00085 domain: {unique_proteins}")

    # Splitting the "Matches" column by comma to create multiple rows
    df = df.assign(Matches=df["Matches"].str.split(",")).explode("Matches")

    # Splitting the "Matches" column by ".." into "Start" and "End"
    df[["Start", "End"]] = df["Matches"].str.split("\.\.", expand=True)

    # Dropping the old "Matches column"
    df.drop(columns=["Matches"], inplace=True)

    # Convert "Start" and "End" to integers
    df["Start"] = df["Start"].astype(int)
    df["End"] = df["End"].astype(int)

    return df

# %%
gt_df = load_ground_truth(f"{DATA_FOLDER}protein-matching-PF00085.tsv")
gt_df
# Out:
# Number of unique proteins with PF00085 domain: 474
#       Accession Source Database  \
# 0    A0A1L1SUL6        reviewed
# 1    A0A509AQW5        reviewed
# 2    A0A8M1N5Y4        reviewed
# 3        A2YIW7        reviewed
# 4        A2YUQ6        reviewed
# ..          ...             ...
# 469      Q9ZP20        reviewed
# 470      Q9ZP21        reviewed
# 471      Q9ZPE9        reviewed
# 472      Q9ZPH2        reviewed
# 473      Q9ZU40        reviewed
#
#                                               Name  Tax ID  \
# 0          Thioredoxin domain-containing protein 6   10090
# 1                                    Thioredoxin 2    5823
# 2                Protein disulfide-isomerase tmx3a    7955
# 3                               Thioredoxin H-type   39946
# 4    Thioredoxin-like protein CITRX, chloroplastic   39946
# ..                                             ...     ...
# 469                  Thioredoxin M5, chloroplastic   39947
# 470              Thioredoxin M-type, chloroplastic    4565
# 471            5'-adenylylsulfate reductase-like 6    3702
# 472                     Monothiol glutaredoxin-S17    3702
# 473                           Sulfhydryl oxidase 2    3702
#
#                              Tax Name  Length Entry Accession  Start  End
# 0                        Mus musculus     329         PF00085     14  109
# 1    Plasmodium berghei (strain Anka)     157         PF00085     59  154
# 2                         Danio rerio     437         PF00085     32  121
# 3          Oryza sativa subsp. indica     122         PF00085      9  109
# 4          Oryza sativa subsp. indica     189         PF00085     83  182
# ..                                ...     ...             ...    ...  ...
# 469      Oryza sativa subsp. japonica     172         PF00085     67  167
# 470                 Triticum aestivum     175         PF00085     70  170
# 471              Arabidopsis thaliana     295         PF00085     79  156
# 472              Arabidopsis thaliana     488         PF00085     16  102
# 473              Arabidopsis thaliana     495         PF00085     38  124
#
# [588 rows x 9 columns]

# %% [markdown]
# ## Evaluation
#
# The evaluation of the models is done with two different methods:
#
# 1. A comparison at protein level, measuring the ability of our models to retrieve the same proteins matched by Pfam.
# 2. A comparison at residue level, measuring the ability of our models to match the same positions matched by Pfam.
#
# The metrics used are precision, recall, F-score, balanced accuracy, MCC.

# %%
def calculate_metrics(tp, tn, fp, fn):
    """
    Computes various classification metrics.

    Parameters:
        tp (int): True Positives
        tn (int): True Negatives
        fp (int): False Positives
        fn (int): False Negatives

    Returns:
        dict: Dictionary containing precision, recall, F-score, balanced accuracy, and MCC.
    """
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    fscore = 2 * (precision * recall) / (precision + recall)
    balanced_accuracy = 0.5 * ((tp / (tp + fn)) + (tn / (tn + fp)))
    mcc = ((tp * tn) - (fp * fn)) / (math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)))
    data = [[precision, recall, fscore, balanced_accuracy, mcc]]
    data_df = pd.DataFrame(data, columns = ["Precision", "Recall", "F-score", "Balanced Accuracy", "MCC"])
    display(data_df)
    return {
        "Precision": precision,
        "Recall": recall,
        "F-score": fscore,
        "Balanced accuracy": balanced_accuracy,
        "MCC": mcc
    }

# %%
def read_tsv(file_path):
    df = pd.read_csv(file_path, sep="\t", na_values=["-", "NA"])
    return df

# %%
def read_csv(file_path):
    df = pd.read_csv(file_path, sep=",", names=['query', 'subject', 'identity', 'alignment_length', 'mismatches', 'gap_opens', 'q_start', 'q_end', 's_start', 's_end', 'evalue', 'bit_score', 'q_coverage'])
    df[['acc', 'version']] = df['subject'].str.split(pat='.', n=1, expand=True)
    return df

# %%
def compare_at_protein_level(hmmsearch, ground_truth):
    """
    Compares HMM search results with ground truth at the protein level.

    Parameters:
        hmmsearch (pd.DataFrame): HMM search results DataFrame.
        ground_truth (pd.DataFrame): Ground truth DataFrame.

    Returns:
        dict: Metrics dictionary.
    """
    # Convert protein lists to sets using the correct column names
    hmm_proteins = set(hmmsearch["Target Accession"])
    gt_proteins = set(ground_truth["Accession"])

    # Compute metrics
    # True Positives: proteins found in both sets
    tp = len(hmm_proteins.intersection(gt_proteins))
    # False Positives: found in HMMSEARCH, but not in ground truth
    fp = len(hmm_proteins - gt_proteins)
    # False Negatives: found in ground truth, but not retrieved by HMMSEARCH
    fn = len(gt_proteins - hmm_proteins)
    # True Negatives: SWISSPROT_SIZE - TP
    tn = SWISSPROT_SIZE - tp

    data = [[tp, fp, fn, tn]]
    data_df = pd.DataFrame(data, columns=['TP', 'FP', 'FN', 'TN'])
    display(data_df)
    return calculate_metrics(tp, tn, fp, fn)

# %% [markdown]
# ## Protein level

# %% [markdown]
# ### HMMSEARCH result

# %%
# Run evaluation at protein level
for msa in MSA_METHODS:
    for i in range(1, 5):
        hmm_file = os.path.join(DATA_FOLDER, f"predictions/{msa}-{i}-hmmsearch.tsv")
        hmmsearch_df = read_tsv(hmm_file)
        results = compare_at_protein_level(hmmsearch_df, gt_df)
        print(f"Results for {msa}-{i}-hmmsearch.tsv:")
        print(results)
# Out:
#     TP  FP  FN      TN
# 0  439  97  35  572180
#    Precision   Recall   F-score  Balanced Accuracy       MCC
# 0    0.81903  0.92616  0.869307           0.962995  0.870837
# Results for clustalo-1-hmmsearch.tsv:
# {'Precision': 0.8190298507462687, 'Recall': 0.9261603375527426, 'F-score': 0.8693069306930693, 'Balanced accuracy': 0.9629954196076995, 'MCC': 0.8708372407318762}
#     TP   FP  FN      TN
# 0  436  103  38  572183
#    Precision    Recall   F-score  Balanced Accuracy       MCC
# 0   0.808905  0.919831  0.860809           0.959826  0.862467
# Results for clustalo-2-hmmsearch.tsv:
# {'Precision': 0.8089053803339518, 'Recall': 0.919831223628692, 'F-score': 0.8608094768015794, 'Balanced accuracy': 0.959825621844296, 'MCC': 0.8624672555723863}
#     TP   FP  FN      TN
# 0  443  104  31  572176
#    Precision    Recall   F-score  Balanced Accuracy      MCC
# 0   0.809872  0.934599  0.867777           0.967209  0.86989
# Results for clustalo-3-hmmsearch.tsv:
# {'Precision': 0.8098720292504571, 'Recall': 0.9345991561181435, 'F-score': 0.8677766895200785, 'Balanced accuracy': 0.9672087134473433, 'MCC': 0.8698895990309423}
#     TP   FP  FN      TN
# 0  444  103  30  572175
#    Precision    Recall   F-score  Balanced Accuracy       MCC
# 0     0.8117  0.936709  0.869736           0.968264  0.871855
# Results for clustalo-4-hmmsearch.tsv:
# {'Precision': 0.8117001828153565, 'Recall': 0.9367088607594937, 'F-score': 0.8697355533790402, 'Balanced accuracy': 0.9682644391517072, 'MCC': 0.8718552406682449}
#     TP  FP  FN      TN
# 0  430  90  44  572189
#    Precision    Recall   F-score  Balanced Accuracy       MCC
# 0   0.826923  0.907173  0.865191           0.953508  0.866004
# Results for muscle-1-hmmsearch.tsv:
# {'Precision': 0.8269230769230769, 'Recall': 0.9071729957805907, 'F-score': 0.8651911468812877, 'Balanced accuracy': 0.9535078649158196, 'MCC': 0.8660037506259183}
#     TP  FP  FN      TN
# 0  430  89  44  572189
#    Precision    Recall   F-score  Balanced Accuracy       MCC
# 0   0.828516  0.907173  0.866062           0.953509  0.866839
# Results for muscle-2-hmmsearch.tsv:
# {'Precision': 0.8285163776493256, 'Recall': 0.9071729957805907, 'F-score': 0.866062437059416, 'Balanced accuracy': 0.9535087384796592, 'MCC': 0.8668385618491912}
#     TP  FP  FN      TN
# 0  440  84  34  572179
#    Precision   Recall   F-score  Balanced Accuracy       MCC
# 0   0.839695  0.92827  0.881764           0.964062  0.882771
# Results for muscle-3-hmmsearch.tsv:
# {'Precision': 0.8396946564885496, 'Recall': 0.9282700421940928, 'F-score': 0.8817635270541081, 'Balanced accuracy': 0.9640616282689236, 'MCC': 0.8827711999423898}
#     TP  FP  FN      TN
# 0  446  84  28  572173
#    Precision    Recall   F-score  Balanced Accuracy       MCC
# 0   0.841509  0.940928  0.888446           0.970391  0.889736
# Results for muscle-4-hmmsearch.tsv:
# {'Precision': 0.8415094339622642, 'Recall': 0.9409282700421941, 'F-score': 0.8884462151394422, 'Balanced accuracy': 0.9703907414234653, 'MCC': 0.8897361727216047}

# %% [markdown]
# ### PSSMSEARCH result

# %%
def compare_at_protein_level_pssm(pssmsearch, ground_truth):
    """
    Compares PSSM search results with ground truth at the protein level.

    Parameters:
        pssmsearch (pd.DataFrame): PSSM search results DataFrame.
        ground_truth (pd.DataFrame): Ground truth DataFrame.

    Returns:
        dict: Metrics dictionary.
    """
    # Convert protein lists to sets using the correct column names
    pssm_proteins = set(pssmsearch["acc"])
    gt_proteins = set(ground_truth["Accession"])

    # Compute metrics
    # True Positives: proteins found in both sets
    tp = len(pssm_proteins.intersection(gt_proteins))
    # False Positives: found in HMMSEARCH, but not in ground truth
    fp = len(pssm_proteins - gt_proteins)
    # False Negatives: found in ground truth, but not retrieved by HMMSEARCH
    fn = len(gt_proteins - pssm_proteins)
    # True Negatives: SWISSPROT_SIZE - TP
    tn = SWISSPROT_SIZE - tp

    data = [[tp, fp, fn, tn]]
    data_df = pd.DataFrame(data, columns=['TP', 'FP', 'FN', 'TN'])
    display(data_df)
    return calculate_metrics(tp, tn, fp, fn)

# %%
# Run evaluation at protein level
for msa in MSA_METHODS:
    for i in range(1, 5):
        pssm_file = os.path.join(DATA_FOLDER, f"predictions/{msa}-{i}-pssmsearch.csv")
        pssmsearch_df = read_csv(pssm_file)
        results = compare_at_protein_level_pssm(pssmsearch_df, gt_df)
        print(f"Results for {msa}-{i}-pssmsearch.csv:")
        print(results)
# Out:
#     TP  FP  FN      TN
# 0  431  69  43  572188
#    Precision    Recall  F-score  Balanced Accuracy       MCC
# 0      0.862  0.909283  0.88501           0.954581  0.885228
# Results for clustalo-1-pssmsearch.csv:
# {'Precision': 0.862, 'Recall': 0.9092827004219409, 'F-score': 0.8850102669404517, 'Balanced accuracy': 0.9545810626129158, 'MCC': 0.8852284639747053}
#     TP  FP  FN      TN
# 0  402  98  72  572217
#    Precision    Recall   F-score  Balanced Accuracy       MCC
# 0      0.804  0.848101  0.825462           0.923965  0.825608
# Results for clustalo-2-pssmsearch.csv:
# {'Precision': 0.804, 'Recall': 0.8481012658227848, 'F-score': 0.8254620123203286, 'Balanced accuracy': 0.9239650157250527, 'MCC': 0.8256083010321255}
#     TP  FP  FN      TN
# 0  428  72  46  572191
#    Precision    Recall  F-score  Balanced Accuracy       MCC
# 0      0.856  0.902954  0.87885           0.951414  0.879061
# Results for clustalo-3-pssmsearch.csv:
# {'Precision': 0.856, 'Recall': 0.9029535864978903, 'F-score': 0.8788501026694044, 'Balanced accuracy': 0.9514138851105542, 'MCC': 0.8790608604352664}
#     TP  FP  FN      TN
# 0  428  72  46  572191
#    Precision    Recall  F-score  Balanced Accuracy       MCC
# 0      0.856  0.902954  0.87885           0.951414  0.879061
# Results for clustalo-4-pssmsearch.csv:
# {'Precision': 0.856, 'Recall': 0.9029535864978903, 'F-score': 0.8788501026694044, 'Balanced accuracy': 0.9514138851105542, 'MCC': 0.8790608604352664}
#     TP  FP  FN      TN
# 0  427  73  47  572192
#    Precision    Recall   F-score  Balanced Accuracy       MCC
# 0      0.854  0.900844  0.876797           0.950358  0.877005
# Results for muscle-1-pssmsearch.csv:
# {'Precision': 0.854, 'Recall': 0.9008438818565401, 'F-score': 0.8767967145790555, 'Balanced accuracy': 0.950358159288645, 'MCC': 0.8770049926132203}
#     TP  FP  FN      TN
# 0  427  73  47  572192
#    Precision    Recall   F-score  Balanced Accuracy       MCC
# 0      0.854  0.900844  0.876797           0.950358  0.877005
# Results for muscle-2-pssmsearch.csv:
# {'Precision': 0.854, 'Recall': 0.9008438818565401, 'F-score': 0.8767967145790555, 'Balanced accuracy': 0.950358159288645, 'MCC': 0.8770049926132203}
#     TP  FP  FN      TN
# 0  427  73  47  572192
#    Precision    Recall   F-score  Balanced Accuracy       MCC
# 0      0.854  0.900844  0.876797           0.950358  0.877005
# Results for muscle-3-pssmsearch.csv:
# {'Precision': 0.854, 'Recall': 0.9008438818565401, 'F-score': 0.8767967145790555, 'Balanced accuracy': 0.950358159288645, 'MCC': 0.8770049926132203}
#     TP  FP  FN      TN
# 0  431  69  43  572188
#    Precision    Recall  F-score  Balanced Accuracy       MCC
# 0      0.862  0.909283  0.88501           0.954581  0.885228
# Results for muscle-4-pssmsearch.csv:
# {'Precision': 0.862, 'Recall': 0.9092827004219409, 'F-score': 0.8850102669404517, 'Balanced accuracy': 0.9545810626129158, 'MCC': 0.8852284639747053}

# %% [markdown]
# ## Residue level

# %% [markdown]
# ### HMMSEARCH residue level result

# %%
# Convert to dictionary mapping each protein to a list of residue ranges
def get_residue_ranges(df, protein_col, start_col, end_col):
    """Maps proteins to residue positions from a DataFrame."""
    protein_residues = {}
    for _, row in df.iterrows():
        protein = row[protein_col]
        start, end = row[start_col], row[end_col]
        if protein not in protein_residues:
            protein_residues[protein] = set()
        # Store all residue positions
        protein_residues[protein].update(range(start, end+1))
    return protein_residues

# %%
  # Extract residue mappings from both dataframes
def compare_at_residue_level(hmmsearch, ground_truth):
    """
    Compares HMM search results with ground truth at the residue level.

    Parameters:
        hmmsearch (pd.DataFrame): HMM search results DataFrame.
        ground_truth (pd.DataFrame): Ground truth DataFrame.

    Returns:
        dict: Metrics dictionary.
    """
    hmm_residues = get_residue_ranges(hmmsearch, "Target Accession", "Target Ali. Start", "Target Ali. End")
    gt_residues = get_residue_ranges(ground_truth, "Accession", "Start", "End")

    # Initialize TP, TN, FP, FN
    tp, tn, fp, fn = 0, 0, 0, 0

    # Calculate metrics for proteins in both dataframes
    all_proteins = set(hmm_residues.keys()).union(set(gt_residues.keys()))

    for protein in all_proteins:
        predicted_residues = hmm_residues.get(protein, set())
        actual_residues = gt_residues.get(protein, set())

        tp += len(predicted_residues.intersection(actual_residues))
        fp += len(predicted_residues - actual_residues)
        fn += len(actual_residues - predicted_residues)

    tn = SWISSPROT_LENGTH - tp - fp - fn

    data = [[tp, fp, fn, tn]]
    data_df = pd.DataFrame(data, columns=['TP', 'FP', 'FN', 'TN'])
    display(data_df)
    return calculate_metrics(tp, tn, fp, fn)

# %%
# Run evaluation at residue level
for msa in MSA_METHODS:
    for i in range(1, 5):
        file_path = f"{DATA_FOLDER}predictions/{msa}-{i}-hmmsearch.tsv"
        hmmsearch_df = read_tsv(file_path)
        results = compare_at_residue_level(hmmsearch_df, gt_df)
        print(f"Results for {msa}-{i}-hmmsearch.tsv:")
        print(results)
# Out:
#       TP     FP    FN         TN
# 0  52288  56753  3866  207318482
#    Precision    Recall   F-score  Balanced Accuracy       MCC
# 0   0.479526  0.931154  0.633046            0.96544  0.668105
# Results for clustalo-1-hmmsearch.tsv:
# {'Precision': 0.47952604983446595, 'Recall': 0.9311536132777718, 'F-score': 0.6330457943642362, 'Balanced accuracy': 0.9654399701453673, 'MCC': 0.6681046491750511}
#       TP     FP    FN         TN
# 0  51739  56663  4415  207318572
#    Precision    Recall   F-score  Balanced Accuracy       MCC
# 0   0.477288  0.921377  0.628832           0.960552  0.663033
# Results for clustalo-2-hmmsearch.tsv:
# {'Precision': 0.4772882419143558, 'Recall': 0.9213769277344446, 'F-score': 0.6288315223996694, 'Balanced accuracy': 0.9605518443716494, 'MCC': 0.6630326877800667}
#       TP     FP    FN         TN
# 0  52396  45288  3758  207329947
#    Precision    Recall   F-score  Balanced Accuracy       MCC
# 0   0.536383  0.933077  0.681184           0.966429  0.707356
# Results for clustalo-3-hmmsearch.tsv:
# {'Precision': 0.5363826215142705, 'Recall': 0.9330768956797378, 'F-score': 0.6811841027574461, 'Balanced accuracy': 0.966429254473554, 'MCC': 0.707355769133069}
#       TP     FP    FN         TN
# 0  52273  31972  3881  207343263
#    Precision    Recall   F-score  Balanced Accuracy       MCC
# 0   0.620488  0.930886  0.744635           0.965366  0.759928
# Results for clustalo-4-hmmsearch.tsv:
# {'Precision': 0.620487862781174, 'Recall': 0.9308864907219432, 'F-score': 0.7446349332972457, 'Balanced accuracy': 0.9653661580462785, 'MCC': 0.7599280786640568}
#       TP     FP    FN         TN
# 0  51332  56574  4822  207318661
#    Precision    Recall   F-score  Balanced Accuracy       MCC
# 0    0.47571  0.914129  0.625771           0.956928  0.659325
# Results for muscle-1-hmmsearch.tsv:
# {'Precision': 0.4757103404815302, 'Recall': 0.9141290023862948, 'F-score': 0.6257710593685236, 'Balanced accuracy': 0.956928096284432, 'MCC': 0.6593250986731093}
#       TP     FP    FN         TN
# 0  51329  56656  4825  207318579
#    Precision    Recall   F-score  Balanced Accuracy       MCC
# 0   0.475335  0.914076  0.625433           0.956901  0.659045
# Results for muscle-2-hmmsearch.tsv:
# {'Precision': 0.47533453720424135, 'Recall': 0.9140755778751292, 'F-score': 0.6254333217577785, 'Balanced accuracy': 0.9569011863196097, 'MCC': 0.65904518899513}
#       TP     FP    FN         TN
# 0  52130  46256  4024  207328979
#    Precision   Recall   F-score  Balanced Accuracy       MCC
# 0   0.529852  0.92834  0.674647           0.964058  0.701246
# Results for muscle-3-hmmsearch.tsv:
# {'Precision': 0.5298518081840913, 'Recall': 0.9283399223563771, 'F-score': 0.6746473404943705, 'Balanced accuracy': 0.9640584338784124, 'MCC': 0.7012463100309321}
#       TP     FP    FN         TN
# 0  52621  14907  3533  207360328
#    Precision    Recall   F-score  Balanced Accuracy       MCC
# 0   0.779247  0.937084  0.850908           0.968506  0.854487
# Results for muscle-4-hmmsearch.tsv:
# {'Precision': 0.7792471271176401, 'Recall': 0.937083734017167, 'F-score': 0.8509079736744232, 'Balanced accuracy': 0.968505924915498, 'MCC': 0.8544868796792036}

# %% [markdown]
# ### PSSMSEARCH residue level result

# %%
  # Extract residue mappings from both dataframes
def compare_at_residue_level_pssm(pssmsearch, ground_truth):
    """
    Compares PSSM search results with ground truth at the residue level.

    Parameters:
        pssm (pd.DataFrame): PSSM search results DataFrame.
        ground_truth (pd.DataFrame): Ground truth DataFrame.

    Returns:
        dict: Metrics dictionary.
    """
    pssm_residues = get_residue_ranges(pssmsearch, "acc", "s_start", "s_end")
    gt_residues = get_residue_ranges(ground_truth, "Accession", "Start", "End")

    # Initialize TP, TN, FP, FN
    tp, tn, fp, fn = 0, 0, 0, 0

    # Calculate metrics for proteins in both dataframes
    all_proteins = set(pssm_residues.keys()).union(set(gt_residues.keys()))

    for protein in all_proteins:
        predicted_residues = pssm_residues.get(protein, set())
        actual_residues = gt_residues.get(protein, set())

        tp += len(predicted_residues.intersection(actual_residues))
        fp += len(predicted_residues - actual_residues)
        fn += len(actual_residues - predicted_residues)

    tn = SWISSPROT_LENGTH - tp - fp - fn

    data = [[tp, fp, fn, tn]]
    data_df = pd.DataFrame(data, columns=['TP', 'FP', 'FN', 'TN'])
    display(data_df)
    return calculate_metrics(tp, tn, fp, fn)

# %%
# Run evaluation at residue level
for msa in MSA_METHODS:
    for i in range(1, 5):
        file_path = f"{DATA_FOLDER}predictions/{msa}-{i}-pssmsearch.csv"
        pssmsearch_df = read_csv(file_path)
        results = compare_at_residue_level_pssm(pssmsearch_df, gt_df)
        print(f"Results for {msa}-{i}-pssmsearch.csv:")
        print(results)
# Out:
#       TP     FP    FN         TN
# 0  51509  12482  4645  207362753
#    Precision    Recall   F-score  Balanced Accuracy       MCC
# 0   0.804941  0.917281  0.857447            0.95861  0.859237
# Results for clustalo-1-pssmsearch.csv:
# {'Precision': 0.8049413198731071, 'Recall': 0.9172810485450725, 'F-score': 0.8574472512380874, 'Balanced accuracy': 0.9586104290685453, 'MCC': 0.8592371166029937}
#       TP     FP    FN         TN
# 0  49124  42963  7030  207332272
#    Precision    Recall   F-score  Balanced Accuracy       MCC
# 0   0.533452  0.874809  0.662759           0.937301  0.683029
# Results for clustalo-2-pssmsearch.csv:
# {'Precision': 0.5334520616373647, 'Recall': 0.8748085621683228, 'F-score': 0.6627586160373986, 'Balanced accuracy': 0.9373006934981124, 'MCC': 0.6830287394868689}
#       TP     FP    FN         TN
# 0  51326  22517  4828  207352718
#    Precision    Recall   F-score  Balanced Accuracy       MCC
# 0   0.695069  0.914022  0.789649           0.956957  0.797002
# Results for clustalo-3-pssmsearch.csv:
# {'Precision': 0.6950692685833457, 'Recall': 0.9140221533639634, 'F-score': 0.7896489918998131, 'Balanced accuracy': 0.9569567862070366, 'MCC': 0.797001856497905}
#       TP     FP    FN         TN
# 0  51311  17500  4843  207357735
#    Precision    Recall   F-score  Balanced Accuracy     MCC
# 0    0.74568  0.913755  0.821206           0.956835  0.8254
# Results for clustalo-4-pssmsearch.csv:
# {'Precision': 0.7456801964802139, 'Recall': 0.9137550308081348, 'F-score': 0.8212059376625455, 'Balanced accuracy': 0.9568353213590552, 'MCC': 0.8253997609615201}
#       TP     FP    FN         TN
# 0  51031  51334  5123  207323901
#    Precision    Recall   F-score  Balanced Accuracy       MCC
# 0    0.49852  0.908769  0.643847           0.954261  0.672974
# Results for muscle-1-pssmsearch.csv:
# {'Precision': 0.4985200019537928, 'Recall': 0.908768743099334, 'F-score': 0.6438471098101805, 'Balanced accuracy': 0.9542606007435724, 'MCC': 0.6729736562604435}
#       TP     FP    FN         TN
# 0  51031  51334  5123  207323901
#    Precision    Recall   F-score  Balanced Accuracy       MCC
# 0    0.49852  0.908769  0.643847           0.954261  0.672974
# Results for muscle-2-pssmsearch.csv:
# {'Precision': 0.4985200019537928, 'Recall': 0.908768743099334, 'F-score': 0.6438471098101805, 'Balanced accuracy': 0.9542606007435724, 'MCC': 0.6729736562604435}
#       TP     FP    FN         TN
# 0  51278  57567  4876  207317668
#    Precision    Recall   F-score  Balanced Accuracy       MCC
# 0    0.47111  0.913167  0.621555           0.956445  0.655782
# Results for muscle-3-pssmsearch.csv:
# {'Precision': 0.47111029445541824, 'Recall': 0.9131673611853118, 'F-score': 0.6215552821532252, 'Balanced accuracy': 0.9564448814732722, 'MCC': 0.6557822007770752}
#       TP     FP    FN         TN
# 0  51336  32183  4818  207343052
#    Precision  Recall   F-score  Balanced Accuracy       MCC
# 0   0.614663  0.9142  0.735088           0.957023  0.749539
# Results for muscle-4-pssmsearch.csv:
# {'Precision': 0.6146625318789737, 'Recall': 0.9142002350678491, 'F-score': 0.7350883850135674, 'Balanced accuracy': 0.9570225214796031, 'MCC': 0.7495385255742685}

# %% [markdown]
# # Taxonomy
#
# In this part we collect the taxonomic lineage from UniProt for each protein in the defined protein family by our best model. Then, we plot the taxonomic tree of the family with node sizes proportional to their relative abundance.

# %%
# Function to fetch XML data from UniProt
def fetch_uniprot_xml(accession):
    """
    Fetches taxonomy data for a given protein accession from UniProt.

    Parameters:
        accession (str): Protein accession ID.

    Returns:
        str: XML response or None on failure.
    """
    url = f"https://www.uniprot.org/uniprot/{accession}.xml"
    response = requests.get(url)
    if response.status_code == 200:
        return response.text
    else:
        print(f"Failed to fetch {accession}: {response.status_code}")
        return None

# Function to parse XML and extract taxonomy details
def parse_uniprot_xml(xml_data):
    """
    Extracts taxonomy lineage from UniProt XML response.

    Parameters:
        xml_data (str): XML response from UniProt.

    Returns:
        str: Taxonomic lineage path.
    """
    root = ET.fromstring(xml_data)
    lineage = [node.text for node in root.findall(".//{http://uniprot.org/uniprot}lineage/{http://uniprot.org/uniprot}taxon")]
    return " > ".join(lineage) if lineage else "N/A"

# %%
best_hmm = read_tsv(f"{DATA_FOLDER}predictions/muscle-4-hmmsearch.tsv")
protein_ids = best_hmm["Target Accession"].unique().tolist()

# %%
pssm_file = os.path.join(DATA_FOLDER, f"predictions/{msa}-{i}-pssmsearch.csv")
pssmsearch_df = read_csv(pssm_file)
pssmsearch_df.head()
# Out:
#     query   subject  identity  alignment_length  mismatches  gap_opens  \
# 0  P40557  P0A4L1.2    19.626               107          84          1
# 1  P40557  P12243.2    19.802               101          79          1
# 2  P40557  P48384.1    19.820               111          87          1
# 3  P40557  P0AA25.2    18.349               109          87          1
# 4  P40557  P52231.3    17.757               107          86          1
#
#    q_start  q_end  s_start  s_end        evalue  bit_score  q_coverage  \
# 0       21    125        1    107  1.190000e-43      147.0       42.99
# 1       27    125        7    107  6.370000e-43      145.0       45.54
# 2       17    125       62    172  8.540000e-43      147.0       42.34
# 3       20    126        1    109  9.160000e-43      145.0       41.28
# 4       21    125        1    107  6.630000e-42      142.0       45.79
#
#       acc version
# 0  P0A4L1       2
# 1  P12243       2
# 2  P48384       1
# 3  P0AA25       2
# 4  P52231       3

# %%
# Collect taxonomy lineage data
lineage_counter = Counter()
for protein_id in protein_ids:
    xml_data = fetch_uniprot_xml(protein_id)
    if xml_data:
        lineage_path = parse_uniprot_xml(xml_data)
        if lineage_path != "N/A":
            lineage_counter[lineage_path] += 1
    sleep(1) # Prevents server overload

# Convert lineage data to DataFrame and compute relative abundance
df = pd.DataFrame(lineage_counter.items(), columns=["Lineage", "Count"])
df["Relative_Abundance"] = df["Count"] / df["Count"].sum()

# Save results to CSV
df.to_csv(f"{DATA_FOLDER}uniprot_taxonomy_abundance.csv", index=False)
print(df.head())
# Out:
#                                              Lineage  Count  \
# 0  Eukaryota > Metazoa > Chordata > Craniata > Ve...     10
# 1  Eukaryota > Metazoa > Chordata > Craniata > Ve...     30
# 2  Eukaryota > Metazoa > Chordata > Craniata > Ve...     30
# 3  Eukaryota > Metazoa > Chordata > Craniata > Ve...     20
# 4  Eukaryota > Metazoa > Chordata > Craniata > Ve...      6
#
#    Relative_Abundance
# 0            0.018868
# 1            0.056604
# 2            0.056604
# 3            0.037736
# 4            0.011321

# %%
# Set threshold for visibility
ABUNDANCE_THRESHOLD = 0.05

# Build hierarchical tree
G = nx.DiGraph()
node_sizes = {}

for lineage, count in lineage_counter.items():
    abundance = count / sum(lineage_counter.values())
    if abundance < ABUNDANCE_THRESHOLD:
        continue  # Skip nodes below threshold

    taxa = lineage.split(" > ")
    for i in range(len(taxa) - 1):
        parent, child = taxa[i], taxa[i + 1]
        G.add_edge(parent, child)
        node_sizes[child] = abundance * 5000  # Scale for visibility

# Plot the tree
plt.figure(figsize=(12, 8))
pos = nx.kamada_kawai_layout(G)  # Layout for hierarchy
nx.draw(G, pos, with_labels=True, node_size=[node_sizes.get(node, 300) for node in G.nodes()], font_size=8, edge_color="gray")
plt.title("Taxonomic Tree of Protein Family")
plt.show()

# %% [markdown]
# # Motifs

# %%
# File paths
mobidb_file = f"{DATA_FOLDER}motifs/mobidb_lite_swissprot.csv"
elm_file = f"{DATA_FOLDER}motifs/elm_classes.tsv"
prosite_file = f"{DATA_FOLDER}motifs/prosite.dat.txt"

# %%
# Load disordered regions from MobiDB-Lite
disordered_regions_pd = pd.read_csv(mobidb_file, names =['Accession', 'Start_End'],
                                 converters={'Start_End': pd.eval} )
disordered_regions_pd
# Out:
#        Accession                                       Start_End
# 0         P9WEU3                                  [[1493, 1529]]
# 1         P9WEU4                           [[1, 84], [118, 141]]
# 2         P0DTH5                                       [[1, 38]]
# 3         P0DO34                                       [[1, 24]]
# 4         P0DO30                    [[2520, 2583], [2597, 2621]]
# ...          ...                                             ...
# 118676    Q8WYJ6                                    [[352, 372]]
# 118677    B2AFA8  [[18, 51], [211, 249], [442, 525], [734, 761]]
# 118678    Q93364                                       [[1, 96]]
# 118679    P34306                                       [[1, 23]]
# 118680    Q09277                      [[818, 903], [1061, 1087]]
#
# [118681 rows x 2 columns]

# %%
disordered_regions = dict(zip(disordered_regions_pd["Accession"], disordered_regions_pd["Start_End"]))
disordered_regions
# Out:
# {'P9WEU3': array([[1493, 1529]], dtype=object),
#  'P9WEU4': array([[1, 84],
#         [118, 141]], dtype=object),
#  'P0DTH5': array([[1, 38]], dtype=object),
#  'P0DO34': array([[1, 24]], dtype=object),
#  'P0DO30': array([[2520, 2583],
#         [2597, 2621]], dtype=object),
#  'P0DO27': array([[1, 26]], dtype=object),
#  'P0DUK1': array([[1, 53]], dtype=object),
#  'Q6GZX1': array([[38, 60]], dtype=object),
#  'Q6GZX3': array([[261, 294]], dtype=object),
#  'Q6GZX0': array([[1, 20]], dtype=object),
#  'Q197F8': array([[339, 397],
#         [434, 458]], dtype=object),
#  'Q197F3': array([[392, 435]], dtype=object),
#  'Q197E7': array([[13, 34]], dtype=object),
#  'Q6GZW1': array([[95, 119]], dtype=object),
#  'Q6GZW0': array([[277, 322]], dtype=object),
#  'Q6GZV5': array([[27, 61]], dtype=object),
#  'Q197E9': array([[73, 169]], dtype=object),
#  'Q6GZV4': array([[42, 71]], dtype=object),
#  'Q197D2': array([[285, 337]], dtype=object),
#  'Q197D0': array([[98, 127]], dtype=object),
#  'Q6GZV6': array([[1, 24],
#         [61, 91],
#         [104, 160],
#         [190, 216],
#         [340, 400]], dtype=object),
#  'Q197C8': array([[136, 279]], dtype=object),
#  'Q6GZU9': array([[942, 970]], dtype=object),
#  'Q6GZU4': array([[30, 155],
#         [169, 327],
#         [376, 474]], dtype=object),
#  'Q6GZU1': array([[24, 87],
#         [101, 153]], dtype=object),
#  'Q6GZT7': array([[77, 116]], dtype=object),
#  'Q197C3': array([[141, 225]], dtype=object),
#  'Q6GZT6': array([[68, 90]], dtype=object),
#  'Q197C0': array([[15, 36]], dtype=object),
#  'Q6GZT4': array([[1, 22],
#         [41, 85]], dtype=object),
#  'Q91G56': array([[1, 22]], dtype=object),
#  'Q6GZT0': array([[46, 81]], dtype=object),
#  'Q6GZT5': array([[422, 442]], dtype=object),
#  'Q6GZS7': array([[1, 110]], dtype=object),
#  'Q6GZS6': array([[61, 229]], dtype=object),
#  'Q6GZS2': array([[1, 24]], dtype=object),
#  'Q197B1': array([[213, 237]], dtype=object),
#  'Q6GZS3': array([[503, 522]], dtype=object),
#  'Q6GZS1': array([[403, 431]], dtype=object),
#  'O55703': array([[70, 146],
#         [234, 269]], dtype=object),
#  'Q67475': array([[1, 20],
#         [227, 290],
#         [331, 371]], dtype=object),
#  'Q6GZR7': array([[1, 23],
#         [82, 167]], dtype=object),
#  'Q6GZR0': array([[1, 54]], dtype=object),
#  'O55704': array([[183, 236]], dtype=object),
#  'Q6GZQ9': array([[1, 44],
#         [68, 137],
#         [163, 183]], dtype=object),
#  'Q6GZQ7': array([[57, 95]], dtype=object),
#  'Q6GZQ5': array([[93, 124]], dtype=object),
#  'Q6GZQ4': array([[56, 77]], dtype=object),
#  'Q196Y7': array([[100, 135]], dtype=object),
#  'Q6GZP9': array([[1, 32]], dtype=object),
#  'Q6GZQ1': array([[133, 155]], dtype=object),
#  'Q6GZT2': array([[13, 34]], dtype=object),
#  'O55715': array([[123, 156]], dtype=object),
#  'Q6GZP6': array([[13, 45]], dtype=object),
#  'Q196X1': array([[1, 63]], dtype=object),
#  'Q6GZN2': array([[1, 30]], dtype=object),
#  'Q6GZN1': array([[28, 52]], dtype=object),
#  'Q6GZN6': array([[161, 388]], dtype=object),
#  'Q6GZN8': array([[10, 79],
#         [216, 248]], dtype=object),
#  'O55723': array([[1, 57]], dtype=object),
#  'O55724': array([[1, 57]], dtype=object),
#  'Q4U9M9': array([[492, 666],
#         [681, 799],
#         [818, 873]], dtype=object),
#  'P15711': array([[490, 907]], dtype=object),
#  'P13813': array([[133, 296]], dtype=object),
#  'Q196V0': array([[86, 119],
#         [182, 206]], dtype=object),
#  'Q196U1': array([[85, 107]], dtype=object),
#  'B5KVH4': array([[193, 232],
#         [282, 318]], dtype=object),
#  'P19084': array([[190, 229],
#         [269, 305]], dtype=object),
#  'Q9XHP0': array([[118, 139]], dtype=object),
#  'Q196T6': array([[83, 114],
#         [185, 236]], dtype=object),
#  'Q196T5': array([[1, 44]], dtype=object),
#  'Q05349': array([[18, 111]], dtype=object),
#  'O55741': array([[20, 40],
#         [128, 151]], dtype=object),
#  'O55747': array([[1, 21]], dtype=object),
#  'O23880': array([[128, 158],
#         [214, 237],
#         [289, 314]], dtype=object),
#  'O23878': array([[126, 228],
#         [271, 301],
#         [356, 376]], dtype=object),
#  'Q9XFM4': array([[125, 194],
#         [241, 272],
#         [326, 346]], dtype=object),
#  'Q9C5W6': array([[240, 268]], dtype=object),
#  'Q84J55': array([[245, 264]], dtype=object),
#  'Q41418': array([[237, 259]], dtype=object),
#  'P46077': array([[244, 267]], dtype=object),
#  'Q2R2W2': array([[244, 265]], dtype=object),
#  'P42652': array([[238, 260]], dtype=object),
#  'P42645': array([[243, 268]], dtype=object),
#  'P93784': array([[238, 258]], dtype=object),
#  'Q06967': array([[241, 260]], dtype=object),
#  'Q96300': array([[242, 265]], dtype=object),
#  'P93211': array([[238, 258]], dtype=object),
#  'P93213': array([[237, 261]], dtype=object),
#  'P93214': array([[239, 261]], dtype=object),
#  'Q96299': array([[239, 263]], dtype=object),
#  'P29305': array([[240, 262]], dtype=object),
#  'P42654': array([[237, 261]], dtype=object),
#  'Q96452': array([[237, 258]], dtype=object),
#  'Q96453': array([[238, 261]], dtype=object),
#  'P62261': array([[234, 255]], dtype=object),
#  'Q5ZMT0': array([[234, 255]], dtype=object),
#  'P92177': array([[236, 262]], dtype=object),
#  'P62258': array([[234, 255]], dtype=object),
#  'P62259': array([[234, 255]], dtype=object),
#  'P62260': array([[234, 255]], dtype=object),
#  'P62262': array([[234, 255]], dtype=object),
#  'O49997': array([[249, 272]], dtype=object),
#  'O42766': array([[236, 264]], dtype=object),
#  'P52908': array([[238, 259]], dtype=object),
#  'O96436': array([[252, 277]], dtype=object),
#  'P93259': array([[239, 264]], dtype=object),
#  'Q25538': array([[154, 177]], dtype=object),
#  'P29307': array([[240, 260]], dtype=object),
#  'P14009': array([[30, 53]], dtype=object),
#  'O55755': array([[31, 57]], dtype=object),
#  'O55761': array([[176, 207]], dtype=object),
#  'P29697': array([[47, 80]], dtype=object),
#  'P16909': array([[140, 215]], dtype=object),
#  'P16211': array([[339, 365]], dtype=object),
#  'P16209': array([[339, 360]], dtype=object),
#  'P30515': array([[337, 361]], dtype=object),
#  'P30376': array([[338, 365]], dtype=object),
#  'P16210': array([[336, 362]], dtype=object),
#  'P30377': array([[338, 365]], dtype=object),
#  'P30375': array([[338, 365]], dtype=object),
#  'P30378': array([[338, 365]], dtype=object),
#  'P13749': array([[338, 365]], dtype=object),
#  'P13748': array([[339, 360]], dtype=object),
#  'Q9LQ10': array([[1, 29],
#         [70, 104]], dtype=object),
#  'Q42881': array([[432, 452]], dtype=object),
#  'Q00379': array([[474, 494]], dtype=object),
#  'P27486': array([[443, 466],
#         [497, 517]], dtype=object),
#  'O76511': array([[1, 32]], dtype=object),
#  'P04818': array([[1, 28]], dtype=object),
#  'P45352': array([[1, 22]], dtype=object),
#  'Q9UTI7': array([[224, 323]], dtype=object),
#  'Q6NUM6': array([[202, 269]], dtype=object),
#  'Q9NV66': array([[248, 314]], dtype=object),
#  'Q08C92': array([[252, 351]], dtype=object),
#  'Q8BJM7': array([[242, 291],
#         [305, 339]], dtype=object),
#  'Q8H8N3': array([[211, 276],
#         [629, 653]], dtype=object),
#  'Q5REF9': array([[248, 312]], dtype=object),
#  'Q2KHP8': array([[253, 356]], dtype=object),
#  'Q08960': array([[86, 116],
#         [156, 176],
#         [374, 407],
#         [782, 810]], dtype=object),
#  'Q8H4D4': array([[53, 75]], dtype=object),
#  'Q4V8B8': array([[331, 374]], dtype=object),
#  'Q5E9U4': array([[199, 258]], dtype=object),
#  'Q6DHJ1': array([[213, 240]], dtype=object),
#  'Q8BSA9': array([[202, 244]], dtype=object),
#  'Q19QT9': array([[200, 259]], dtype=object),
#  'Q641F8': array([[1, 23],
#         [209, 251]], dtype=object),
#  'P53177': array([[243, 273]], dtype=object),
#  'Q5A931': array([[1, 33]], dtype=object),
#  'Q2U6D4': array([[702, 726]], dtype=object),
#  'Q5BH52': array([[1, 31]], dtype=object),
#  'O60294': array([[1, 21]], dtype=object),
#  'O60157': array([[1, 21]], dtype=object),
#  'Q5XIA3': array([[1, 22]], dtype=object),
#  'Q6C3P4': array([[1, 42]], dtype=object),
#  'Q8BYR1': array([[1, 23]], dtype=object),
#  'Q9P3K9': array([[1, 76],
#         [215, 272],
#         [879, 900]], dtype=object),
#  'P25490': array([[33, 81],
#         [157, 203]], dtype=object),
#  'O15391': array([[126, 174],
#         [186, 210]], dtype=object),
#  'P0C6P6': array([[200, 220]], dtype=object),
#  'Q00899': array([[32, 83],
#         [159, 203]], dtype=object),
#  'Q2FAY8': array([[200, 220]], dtype=object),
#  'P10074': array([[119, 140],
#         [161, 192]], dtype=object),
#  'Q1H9T6': array([[121, 176],
#         [189, 222]], dtype=object),
#  'Q5R633': array([[159, 205]], dtype=object),
#  'Q84WS8': array([[145, 165]], dtype=object),
#  'Q9CAE4': array([[18, 51],
#         [165, 261]], dtype=object),
#  'Q8VY74': array([[154, 333]], dtype=object),
#  'Q8VYD3': array([[274, 297]], dtype=object),
#  'Q9M8X2': array([[562, 712]], dtype=object),
#  'Q3SYR2': array([[1, 60]], dtype=object),
#  'Q8RWV8': array([[101, 138],
#         [200, 242],
#         [290, 317]], dtype=object),
#  'O19177': array([[1, 61]], dtype=object),
#  'Q13432': array([[1, 61]], dtype=object),
#  'Q9Z2R6': array([[1, 62]], dtype=object),
#  'Q62885': array([[1, 62]], dtype=object),
#  'Q90Z08': array([[1, 49]], dtype=object),
#  'A6NIH7': array([[1, 28]], dtype=object),
#  'Q8C4B4': array([[1, 56]], dtype=object),
#  'Q9SR32': array([[49, 70],
#         [147, 170]], dtype=object),
#  'Q7RTZ2': array([[382, 411]], dtype=object),
#  'Q6R6M4': array([[382, 416],
#         [490, 530]], dtype=object),
#  'A6NCW0': array([[382, 412],
#         [491, 524]], dtype=object),
#  'A6NCW7': array([[382, 410],
#         [493, 530]], dtype=object),
#  'A8MUK1': array([[382, 412],
#         [477, 530]], dtype=object),
#  'P0C7H9': array([[382, 412],
#         [431, 454],
#         [490, 530]], dtype=object),
#  'C9JJH3': array([[382, 410],
#         [477, 530]], dtype=object),
#  'C9JVI0': array([[382, 413],
#         [509, 530]], dtype=object),
#  'C9JLJ4': array([[382, 412],
#         [477, 530]], dtype=object),
#  'P0C7I0': array([[382, 412],
#         [493, 530]], dtype=object),
#  'C9J2P7': array([[382, 413],
#         [491, 524]], dtype=object),
#  'D6RBQ6': array([[382, 411],
#         [477, 530]], dtype=object),
#  'D6R9N7': array([[382, 414],
#         [509, 530]], dtype=object),
#  'D6RCP7': array([[382, 413],
#         [476, 530]], dtype=object),
#  'D6RJB6': array([[382, 413],
#         [509, 530]], dtype=object),
#  'D6R901': array([[382, 412],
#         [477, 530]], dtype=object),
#  'D6RA61': array([[382, 412],
#         [476, 530]], dtype=object),
#  'G5E8I7': array([[368, 442],
#         [489, 539]], dtype=object),
#  'E9Q9U0': array([[1, 20],
#         [374, 449]], dtype=object),
#  'G5E8G2': array([[367, 443],
#         [521, 545]], dtype=object),
#  'Q61068': array([[1, 21],
#         [374, 394],
#         [465, 494]], dtype=object),
#  'Q7M764': array([[1, 22],
#         [431, 461],
#         [499, 540]], dtype=object),
#  'Q17J49': array([[1, 39],
#         [83, 117]], dtype=object),
#  'Q8T784': array([[57, 90]], dtype=object),
#  'O97420': array([[1, 28],
#         [70, 96]], dtype=object),
#  'Q0WX57': array([[382, 412],
#         [477, 530]], dtype=object),
#  'O62252': array([[1, 32]], dtype=object),
#  'Q6INE2': array([[1, 46]], dtype=object),
#  'Q66JA9': array([[1, 49]], dtype=object),
#  'Q1LZH0': array([[146, 165],
#         [173, 222]], dtype=object),
#  'Q4KMD3': array([[133, 208]], dtype=object),
#  'Q16560': array([[187, 217]], dtype=object),
#  'Q9D384': array([[146, 244]], dtype=object),
#  'Q5U1W5': array([[146, 244]], dtype=object),
#  'Q05AT9': array([[146, 272]], dtype=object),
#  'Q89698': array([[1, 63],
#         [76, 123]], dtype=object),
#  'Q9U5Y0': array([[52, 87]], dtype=object),
#  'Q54UW1': array([[1, 22]], dtype=object),
#  'O77286': array([[51, 87]], dtype=object),
#  'Q9U5V3': array([[50, 87]], dtype=object),
#  'O23212': array([[1, 175]], dtype=object),
#  'Q9ZR39': array([[1, 165]], dtype=object),
#  'Q2QKB3': array([[1, 215]], dtype=object),
#  'Q8L716': array([[1, 195]], dtype=object),
#  'Q2QZL4': array([[1, 156]], dtype=object),
#  'A1A4K8': array([[185, 237]], dtype=object),
#  'Q2R0Q1': array([[1, 180]], dtype=object),
#  'Q94535': array([[190, 264]], dtype=object),
#  'Q9D883': array([[183, 239]], dtype=object),
#  'Q01081': array([[183, 240]], dtype=object),
#  'Q9ZR40': array([[1, 187]], dtype=object),
#  'Q2QKB4': array([[1, 171]], dtype=object),
#  'Q09176': array([[194, 216]], dtype=object),
#  'Q24562': array([[1, 47]], dtype=object),
#  'P90727': array([[25, 133]], dtype=object),
#  'P26369': array([[1, 90]], dtype=object),
#  'P26368': array([[1, 90]], dtype=object),
#  'Q3T127': array([[186, 220]], dtype=object),
#  'Q8WU68': array([[185, 220]], dtype=object),
#  'P36629': array([[1, 112]], dtype=object),
#  'Q8BGJ9': array([[186, 220]], dtype=object),
#  'P90978': array([[1, 142]], dtype=object),
#  'Q7TP17': array([[186, 220]], dtype=object),
#  'P0DN76': array([[183, 240]], dtype=object),
#  'Q9S709': array([[191, 296]], dtype=object),
#  'Q9ZQW8': array([[188, 290]], dtype=object),
#  'Q9FMY5': array([[191, 283]], dtype=object),
#  'Q6AUG0': array([[184, 304]], dtype=object),
#  'Q64707': array([[1, 51],
#         [339, 428]], dtype=object),
#  'Q15695': array([[1, 63],
#         [356, 479]], dtype=object),
#  'Q15696': array([[1, 59],
#         [115, 135],
#         [351, 482]], dtype=object),
#  'Q62377': array([[1, 22],
#         [44, 66],
#         [115, 138],
#         [354, 462]], dtype=object),
#  'H0YL09': array([[1, 21]], dtype=object),
#  'Q9VM35': array([[18, 77]], dtype=object),
#  'Q4WK56': array([[1, 37],
#         [61, 90]], dtype=object),
#  'P0CS21': array([[1, 57],
#         [75, 97]], dtype=object),
#  'P0CS20': array([[1, 57],
#         [75, 97]], dtype=object),
#  'Q24JV4': array([[1, 38],
#         [63, 98]], dtype=object),
#  'Q9P7I8': array([[1, 32]], dtype=object),
#  'Q4P7C7': array([[1, 94]], dtype=object),
#  'Q9VE11': array([[1, 28],
#         [139, 174]], dtype=object),
#  'Q9VL63': array([[1, 137],
#         [193, 216],
#         [249, 290]], dtype=object),
#  'Q91WM3': array([[1, 75]], dtype=object),
#  'A2XDK8': array([[1, 25]], dtype=object),
#  'Q10QE9': array([[1, 25]], dtype=object),
#  'A2YH25': array([[385, 408]], dtype=object),
#  'Q5Z8N6': array([[385, 408]], dtype=object),
#  'O43818': array([[1, 75]], dtype=object),
#  'Q7XFE1': array([[1, 37]], dtype=object),
#  'A2Z6C5': array([[1, 40]], dtype=object),
#  'Q337C0': array([[368, 390]], dtype=object),
#  'Q8GW16': array([[1, 30]], dtype=object),
#  'Q56XQ0': array([[1, 20]], dtype=object),
#  'Q9LJK4': array([[1, 29]], dtype=object),
#  'Q9LT84': array([[1, 41]], dtype=object),
#  'Q6BJ87': array([[1097, 1124]], dtype=object),
#  'Q758A1': array([[473, 523]], dtype=object),
#  'Q54FF0': array([[1, 20]], dtype=object),
#  'Q55D15': array([[1, 26]], dtype=object),
#  'Q6CXR1': array([[478, 537]], dtype=object),
#  'A8P7J8': array([[586, 608],
#         [757, 778]], dtype=object),
#  'Q17AI4': array([[1, 32],
#         [494, 514],
#         [821, 866],
#         [905, 977]], dtype=object),
#  'Q7PZ36': array([[1, 39],
#         [797, 927]], dtype=object),
#  'A8XW52': array([[800, 841]], dtype=object),
#  'Q11187': array([[823, 865]], dtype=object),
#  'B3MLI0': array([[1, 20],
#         [797, 856],
#         [907, 987]], dtype=object),
#  'B4JQY3': array([[1, 33],
#         [647, 688],
#         [827, 885],
#         [942, 1010]], dtype=object),
#  'Q9VQK0': array([[619, 648],
#         [792, 818],
#         [857, 879],
#         [903, 947],
#         [959, 986]], dtype=object),
#  'B3NAN9': array([[831, 877],
#         [904, 945],
#         [957, 984]], dtype=object),
#  'B0X755': array([[558, 579],
#         [759, 922]], dtype=object),
#  'B4KJS5': array([[1, 35],
#         [651, 682],
#         [821, 913],
#         [935, 1007]], dtype=object),
#  'B4G8N3': array([[1, 31],
#         [503, 525],
#         [832, 1013]], dtype=object),
#  'B5DI68': array([[1, 31],
#         [504, 524],
#         [650, 685],
#         [830, 913],
#         [933, 1027]], dtype=object),
#  'B4LQW4': array([[1, 32],
#         [652, 675],
#         [813, 871],
#         [924, 984]], dtype=object),
#  'Q54D05': array([[18, 37]], dtype=object),
#  'A9UYK7': array([[437, 471],
#         [677, 805]], dtype=object),
#  'B4NXB9': array([[800, 827],
#         [865, 888],
#         [911, 954],
#         [968, 995]], dtype=object),
#  'A7S6A1': array([[739, 761],
#         [781, 814]], dtype=object),
#  'B4MTY2': array([[1, 25],
#         [639, 684],
#         [820, 856],
#         [932, 1042]], dtype=object),
#  'Q9U2G0': array([[54, 82],
#         [202, 243]], dtype=object),
#  'Q9VUV9': array([[52, 74],
#         [211, 234],
#         [366, 396]], dtype=object),
#  'Q6P4T2': array([[39, 81]], dtype=object),
#  'F1LNJ2': array([[39, 80]], dtype=object),
#  'O75643': array([[50, 80]], dtype=object),
#  'Q39168': array([[123, 148]], dtype=object),
#  'O04573': array([[57, 82],
#         [119, 150]], dtype=object),
#  'O04587': array([[63, 82],
#         [122, 153]], dtype=object),
#  'O04575': array([[119, 150]], dtype=object),
#  'A4FUD3': array([[1, 53]], dtype=object),
#  'Q5F3X4': array([[1, 53]], dtype=object),
#  'Q15029': array([[1, 54]], dtype=object),
#  'Q9ZVL6': array([[1, 48],
#         [228, 251]], dtype=object),
#  'A2Y4G9': array([[1, 60],
#         [244, 265]], dtype=object),
#  'Q6ATY4': array([[1, 60],
#         [244, 265]], dtype=object),
#  'O08810': array([[1, 52]], dtype=object),
#  'A6NN06': array([[1, 33]], dtype=object),
#  'Q5R6E0': array([[1, 53]], dtype=object),
#  'Q5VV11': array([[1, 34]], dtype=object),
#  'Q5XG85': array([[1, 30]], dtype=object),
#  'Q9VCE8': array([[1, 32]], dtype=object),
#  'Q54BM8': array([[91, 142],
#         [156, 192]], dtype=object),
#  'Q16EE5': array([[69, 97]], dtype=object),
#  'Q7PSY2': array([[65, 96]], dtype=object),
#  'O97172': array([[60, 99]], dtype=object),
#  'A8WTH5': array([[51, 83]], dtype=object),
#  'B4R3W7': array([[64, 97]], dtype=object),
#  'Q9ZQ97': array([[450, 475]], dtype=object),
#  'Q9ZQ95': array([[449, 475]], dtype=object),
#  'Q9ZQ94': array([[446, 477]], dtype=object),
#  'Q96896': array([[156, 241],
#         [417, 438]], dtype=object),
#  'P52531': array([[155, 233]], dtype=object),
#  'P52529': array([[156, 219],
#         [412, 441]], dtype=object),
#  'P52530': array([[156, 241],
#         [417, 438]], dtype=object),
#  'Q9M8Z7': array([[1, 29],
#         [66, 112]], dtype=object),
#  'Q9XIG1': array([[1, 54]], dtype=object),
#  'Q77PU6': array([[1, 28],
#         [464, 483],
#         [703, 732],
#         [781, 818]], dtype=object),
#  'Q89882': array([[179, 198],
#         [649, 683],
#         [701, 734]], dtype=object),
#  'Q9QJ12': array([[783, 802]], dtype=object),
#  'Q9BZF9': array([[1, 24]], dtype=object),
#  'Q9GL21': array([[1186, 1205]], dtype=object),
#  'O74503': array([[55, 122],
#         [194, 233]], dtype=object),
#  'Q08747': array([[89, 118],
#         [209, 228]], dtype=object),
#  'Q8CGB3': array([[1, 30],
#         [263, 301],
#         [1006, 1031]], dtype=object),
#  'Q46821': array([[1, 20]], dtype=object),
#  'Q3KQV9': array([[56, 91]], dtype=object),
#  'Q28CH3': array([[1, 22]], dtype=object),
#  'Q940S3': array([[1, 32]], dtype=object),
#  'Q4A0V8': array([[50, 262],
#         [861, 2292]], dtype=object),
#  'O43120': array([[36, 104]], dtype=object),
#  'Q07307': array([[1, 20],
#         [555, 574]], dtype=object),
#  'Q9ZU75': array([[8, 29]], dtype=object),
#  'Q5M981': array([[145, 168]], dtype=object),
#  'P49413': array([[1, 48],
#         [163, 207],
#         [251, 282],
#         [367, 391],
#         [811, 862],
#         [876, 969]], dtype=object),
#  'Q7ZXR7': array([[136, 173],
#         [284, 305],
#         [573, 600]], dtype=object),
#  'Q52KZ6': array([[145, 167]], dtype=object),
#  'Q2NL57': array([[118, 156],
#         [270, 291],
#         [560, 580]], dtype=object),
#  'P51965': array([[1, 45]], dtype=object),
#  'P52482': array([[1, 45]], dtype=object),
#  'Q96LR5': array([[1, 55]], dtype=object),
#  'Q91W82': array([[1, 55]], dtype=object),
#  'Q2T9X7': array([[1, 63]], dtype=object),
#  'Q969T4': array([[1, 63]], dtype=object),
#  'P52483': array([[1, 63]], dtype=object),
#  'Q9CY34': array([[1, 27]], dtype=object),
#  'Q2TA03': array([[174, 200]], dtype=object),
#  'Q54LP7': array([[170, 215]], dtype=object),
#  'Q9JJZ4': array([[215, 283]], dtype=object),
#  'Q9Y385': array([[229, 283]], dtype=object),
#  'Q32L27': array([[88, 116]], dtype=object),
#  'Q7Z7E8': array([[1, 40],
#         [173, 221]], dtype=object),
#  'Q7TSS2': array([[1, 40],
#         [173, 221]], dtype=object),
#  'Q8K2Z8': array([[126, 152]], dtype=object),
#  'Q7YQJ9': array([[117, 143]], dtype=object),
#  'Q8WVN8': array([[123, 174]], dtype=object),
#  'Q712K3': array([[194, 238]], dtype=object),
#  'P49427': array([[216, 236]], dtype=object),
#  'Q8AVU2': array([[158, 211]], dtype=object),
#  'A1L3K1': array([[170, 223]], dtype=object),
#  'Q76EZ2': array([[158, 211]], dtype=object),
#  'Q29503': array([[194, 238]], dtype=object),
#  'Q6ZWZ2': array([[194, 238]], dtype=object),
#  'P91853': array([[1, 83]], dtype=object),
#  'Q9RV58': array([[174, 298]], dtype=object),
#  'Q9SHZ6': array([[1, 61],
#         [312, 343]], dtype=object),
#  'F5GYI3': array([[87, 141],
#         [185, 228]], dtype=object),
#  'O64571': array([[322, 360]], dtype=object),
#  'Q9SHZ5': array([[1, 99]], dtype=object),
#  'A3KMV5': array([[1, 37]], dtype=object),
#  'P31254': array([[1, 22]], dtype=object),
#  'Q55C16': array([[765, 788]], dtype=object),
#  'P22314': array([[1, 47]], dtype=object),
#  'Q02053': array([[1, 46]], dtype=object),
#  'Q9LES2': array([[1, 99],
#         [321, 359],
#         [442, 478]], dtype=object),
#  'Q29504': array([[1, 47]], dtype=object),
#  'O80678': array([[1, 86],
#         [301, 335],
#         [423, 451]], dtype=object),
#  'Q9LKA4': array([[1, 29],
#         [246, 270],
#         [344, 404]], dtype=object),
#  'O42939': array([[597, 628]], dtype=object),
#  'P52488': array([[552, 636]], dtype=object),
#  'Q5U300': array([[1, 46]], dtype=object),
#  'Q0CFD4': array([[39, 58]], dtype=object),
#  'O59954': array([[33, 57]], dtype=object),
#  'A4RPM5': array([[33, 54]], dtype=object),
#  'Q17DT0': array([[362, 384]], dtype=object),
#  'O23034': array([[339, 396]], dtype=object),
#  'C3YZ51': array([[1, 44]], dtype=object),
#  'A8XEQ8': array([[25, 47],
#         [363, 406]], dtype=object),
#  'P91430': array([[18, 47]], dtype=object),
#  'B3NUC9': array([[369, 402]], dtype=object),
#  'Q9VYY3': array([[372, 404]], dtype=object),
#  'B4GYC7': array([[352, 375]], dtype=object),
#  'Q29HT0': array([[343, 384]], dtype=object),
#  'B4IK21': array([[372, 393]], dtype=object),
#  'B4R345': array([[372, 393]], dtype=object),
#  'B4NDE5': array([[373, 397]], dtype=object),
#  'B4PYA4': array([[371, 403]], dtype=object),
#  'Q5M7A4': array([[306, 337]], dtype=object),
#  'Q5ZJI9': array([[100, 119],
#         [235, 275]], dtype=object),
#  'A0AVT1': array([[1, 21]], dtype=object),
#  'Q8VDI7': array([[101, 122],
#         [239, 273]], dtype=object),
#  'Q5XIR9': array([[235, 273]], dtype=object),
#  'Q28DG7': array([[95, 122],
#         [238, 272]], dtype=object),
#  'Q5ZJQ8': array([[284, 307]], dtype=object),
#  'Q9BSL1': array([[101, 120],
#         [235, 271]], dtype=object),
#  'H5SQ95': array([[1, 56]], dtype=object),
#  'S0EX56': array([[1, 64]], dtype=object),
#  'A0A1F5UTC9': array([[1, 60]], dtype=object),
#  'Q8R1K1': array([[287, 306]], dtype=object),
#  'A0A1F6CTG8': array([[1, 63]], dtype=object),
#  'J9ZCN8': array([[1, 64]], dtype=object),
#  'B3DVI3': array([[1, 65]], dtype=object),
#  'M1YW29': array([[1, 59]], dtype=object),
#  'A0A0K2G9F6': array([[1, 66]], dtype=object),
#  'B9XEI9': array([[1, 56]], dtype=object),
#  'A0A0J1BDH3': array([[1, 50]], dtype=object),
#  'A0A1G2PK14': array([[1, 70]], dtype=object),
#  'A0A0G0MF47': array([[1, 33]], dtype=object),
#  'Q6DGM1': array([[81, 155]], dtype=object),
#  'Q8TB05': array([[89, 177]], dtype=object),
#  'Q6P3B2': array([[87, 176]], dtype=object),
#  'Q6AXN0': array([[88, 176]], dtype=object),
#  'Q502A3': array([[118, 172]], dtype=object),
#  'Q8IYN6': array([[128, 164]], dtype=object),
#  'Q8BQH4': array([[144, 164]], dtype=object),
#  'Q5XGE4': array([[120, 166]], dtype=object),
#  'F6P6X0': array([[83, 119],
#         [189, 223],
#         [260, 335]], dtype=object),
#  'Q9NZ09': array([[86, 117]], dtype=object),
#  'Q8BH48': array([[80, 117],
#         [135, 156]], dtype=object),
#  'Q5XIS7': array([[77, 120],
#         [135, 156]], dtype=object),
#  'Q5T6F2': array([[1, 26],
#         [110, 202],
#         [385, 476],
#         [622, 736],
#         [853, 905],
#         [937, 966],
#         [982, 1020],
#         [1082, 1119]], dtype=object),
#  'O00103': array([[1, 25]], dtype=object),
#  'Q9C9Y7': array([[1, 22]], dtype=object),
#  'Q75AF2': array([[10, 29]], dtype=object),
#  'A3KN22': array([[1, 29]], dtype=object),
#  'Q6FVQ8': array([[11, 34]], dtype=object),
#  'P61081': array([[1, 29]], dtype=object),
#  'Q54TI6': array([[1, 87]], dtype=object),
#  'P61082': array([[1, 29]], dtype=object),
#  'Q6DCZ9': array([[1, 28]], dtype=object),
#  'Q6P8D9': array([[1, 28]], dtype=object),
#  'Q91VX2': array([[1, 29],
#         [95, 202],
#         [221, 248],
#         [331, 351],
#         [380, 479],
#         [602, 679],
#         [713, 749],
#         [875, 919],
#         [996, 1033],
#         [1040, 1059],
#         [1087, 1132]], dtype=object),
#  'P52491': array([[1, 23]], dtype=object),
#  'Q9LJZ5': array([[1, 33]], dtype=object),
#  'P25865': array([[119, 152]], dtype=object),
#  'P52478': array([[1, 28],
#         [171, 192]], dtype=object),
#  'Q11076': array([[1, 23],
#         [123, 155],
#         [649, 678],
#         [709, 728]], dtype=object),
#  'Q8L7T3': array([[1, 33]], dtype=object),
#  'Q9FF66': array([[230, 251]], dtype=object),
#  'Q93571': array([[117, 164]], dtype=object),
#  'Q9LUQ5': array([[70, 99],
#         [151, 185]], dtype=object),
#  'Q8VY10': array([[1, 23],
#         [485, 509]], dtype=object),
#  'Q75EB8': array([[148, 170]], dtype=object),
#  'Q4WLA7': array([[1, 26]], dtype=object),
#  'Q9ZVX1': array([[1, 20],
#         [25, 111],
#         [396, 418],
#         [579, 602],
#         [660, 710],
#         [760, 800]], dtype=object),
#  'Q6FR76': array([[148, 167]], dtype=object),
#  'Q6BU36': array([[143, 168]], dtype=object),
#  'Q8GY87': array([[1, 21],
#         [514, 543]], dtype=object),
#  'Q96UP5': array([[1, 26]], dtype=object),
#  'O74201': array([[1, 28],
#         [145, 179]], dtype=object),
#  'P23566': array([[1, 25]], dtype=object),
#  'Q5UQ57': array([[195, 388]], dtype=object),
#  'Q4PFA5': array([[149, 185]], dtype=object),
#  'Q6C093': array([[1, 26]], dtype=object),
#  'P06104': array([[145, 172]], dtype=object),
#  'Q9FK29': array([[168, 197]], dtype=object),
#  'Q9SHI7': array([[168, 207]], dtype=object),
#  'Q9C918': array([[297, 326]], dtype=object),
#  'Q941B6': array([[207, 232],
#         [373, 395]], dtype=object),
#  'P42748': array([[145, 187]], dtype=object),
#  'P14682': array([[185, 295]], dtype=object),
#  'P15731': array([[1, 22]], dtype=object),
#  'P16577': array([[146, 184]], dtype=object),
#  'Q8S920': array([[1, 24]], dtype=object),
#  'P42749': array([[146, 185]], dtype=object),
#  'Q6BYG4': array([[170, 190]], dtype=object),
#  'Q6CMG6': array([[173, 200]], dtype=object),
#  'Q5UQ88': array([[180, 207],
#         [283, 305],
#         [505, 554],
#         [577, 605]], dtype=object),
#  'P42750': array([[148, 183]], dtype=object),
#  'P33296': array([[209, 229]], dtype=object),
#  'P25868': array([[1, 21]], dtype=object),
#  'Q9P7R4': array([[154, 184]], dtype=object),
#  'P28263': array([[154, 218]], dtype=object),
#  'P52485': array([[1, 87]], dtype=object),
#  'P0C8G4': array([[173, 217]], dtype=object),
#  'P0C8G5': array([[200, 221]], dtype=object),
#  'Q6IP57': array([[120, 166]], dtype=object),
#  'Q6DD24': array([[119, 165]], dtype=object),
#  'P93028': array([[1, 20],
#         [29, 50]], dtype=object),
#  'P31251': array([[1, 42]], dtype=object),
#  'P31252': array([[1, 40]], dtype=object),
#  'Q32PA5': array([[1, 31]], dtype=object),
#  'Q9VTY6': array([[1, 28]], dtype=object),
#  'O00762': array([[1, 31]], dtype=object),
#  'P92974': array([[16, 36]], dtype=object),
#  'Q4R9D1': array([[1, 31]], dtype=object),
#  'Q95044': array([[1, 31]], dtype=object),
#  'P56616': array([[1, 31]], dtype=object),
#  'Q5ZKX6': array([[11, 30]], dtype=object),
#  'Q6IRC7': array([[1, 21]], dtype=object),
#  'Q5M8Y2': array([[1, 29]], dtype=object),
#  'Q32LN1': array([[152, 183]], dtype=object),
#  'P62256': array([[152, 183]], dtype=object),
#  'P62257': array([[152, 183]], dtype=object),
#  'Q1RML1': array([[155, 223]], dtype=object),
#  'C3Z724': array([[157, 213]], dtype=object),
#  'Q4V908': array([[157, 221]], dtype=object),
#  'Q54I43': array([[159, 215]], dtype=object),
#  'B3MQV3': array([[164, 209]], dtype=object),
#  'B3NWW9': array([[162, 209]], dtype=object),
#  'B4JKB7': array([[161, 196]], dtype=object),
#  'Q9VX25': array([[168, 194]], dtype=object),
#  'B4L7V4': array([[165, 191]], dtype=object),
#  'B4H9W2': array([[165, 194]], dtype=object),
#  'B5DKM4': array([[165, 194]], dtype=object),
#  'B4IF39': array([[165, 209]], dtype=object),
#  'B4R6G1': array([[165, 209]], dtype=object),
#  'B4MA02': array([[161, 193]], dtype=object),
#  'Q9C0C9': array([[1, 56],
#         [85, 114],
#         [401, 459],
#         [472, 519],
#         [714, 746],
#         [882, 903],
#         [1160, 1248]], dtype=object),
#  'B4N208': array([[159, 208]], dtype=object),
#  'B4Q2J2': array([[164, 209]], dtype=object),
#  'Q16763': array([[156, 222]], dtype=object),
#  'C1C3R6': array([[157, 211]], dtype=object),
#  'Q921J4': array([[170, 223]], dtype=object),
#  'A7SE05': array([[165, 204]], dtype=object),
#  'B5DFI8': array([[159, 223]], dtype=object),
#  'Q6ZPJ3': array([[1, 51],
#         [80, 109],
#         [396, 529],
#         [711, 743],
#         [872, 899],
#         [1158, 1247]], dtype=object),
#  'Q28F89': array([[157, 211]], dtype=object),
#  'Q9NPD8': array([[149, 197]], dtype=object),
#  'Q08BH7': array([[158, 194]], dtype=object),
#  'Q9CQ37': array([[150, 204]], dtype=object),
#  'Q7ZY08': array([[150, 192]], dtype=object),
#  'Q32LD2': array([[146, 195]], dtype=object),
#  'Q5VVX9': array([[285, 321]], dtype=object),
#  'Q6DG60': array([[295, 328]], dtype=object),
#  'Q9H832': array([[1, 21],
#         [332, 354]], dtype=object),
#  'Q3UE37': array([[1, 23],
#         [334, 356]], dtype=object),
#  'Q3B7D1': array([[1, 22],
#         [334, 356]], dtype=object),
#  'Q6PCF7': array([[283, 313]], dtype=object),
#  'Q66KB0': array([[283, 313]], dtype=object),
#  'Q05086': array([[175, 226]], dtype=object),
#  'Q15386': array([[1, 40],
#         [355, 385]], dtype=object),
#  'Q80U95': array([[1, 40],
#         [354, 386]], dtype=object),
#  'O08759': array([[171, 223]], dtype=object),
#  'A5PKG6': array([[33, 57]], dtype=object),
#  'Q14139': array([[33, 56]], dtype=object),
#  'E9Q735': array([[33, 57]], dtype=object),
#  'Q5R9G3': array([[33, 57]], dtype=object),
#  'O95155': array([[1, 155],
#         [299, 406],
#         [1057, 1077]], dtype=object),
#  'Q9LF41': array([[430, 459],
#         [1010, 1038]], dtype=object),
#  'P25979': array([[1, 21],
#         [182, 201],
#         [376, 404],
#         [557, 677]], dtype=object),
#  'Q9ES00': array([[1, 155],
#         [928, 948]], dtype=object),
#  'Q6P7A2': array([[36, 57]], dtype=object),
#  'P25980': array([[1, 21],
#         [382, 426],
#         [584, 701]], dtype=object),
#  'O14562': array([[1, 80],
#         [171, 204]], dtype=object),
#  'P17480': array([[1, 21],
#         [381, 411],
#         [459, 487],
#         [546, 576],
#         [648, 764]], dtype=object),
#  'Q78JW9': array([[106, 139],
#         [231, 263]], dtype=object),
#  'P25977': array([[1, 21],
#         [370, 411],
#         [456, 488],
#         [546, 576],
#         [648, 764]], dtype=object),
#  'Q3USZ2': array([[167, 197],
#         [305, 394]], dtype=object),
#  'P0CB47': array([[308, 393]], dtype=object),
#  'P0CB48': array([[320, 400]], dtype=object),
#  'P25976': array([[1, 21],
#         [370, 411],
#         [456, 487],
#         [546, 576],
#         [649, 765]], dtype=object),
#  'Q5ZKS8': array([[13, 33]], dtype=object),
#  'E7FB98': array([[1, 22]], dtype=object),
#  'Q9V3R8': array([[1, 23]], dtype=object),
#  'D3ZG27': array([[1, 39]], dtype=object),
#  'Q3JUM4': array([[1, 23]], dtype=object),
#  'Q62ID2': array([[1, 23]], dtype=object),
#  'Q63W06': array([[1, 23]], dtype=object),
#  'Q2SZY9': array([[1, 25]], dtype=object),
#  'Q1LIU6': array([[183, 214]], dtype=object),
#  'Q0K6Y1': array([[194, 220]], dtype=object),
#  'Q142T1': array([[192, 227]], dtype=object),
#  'Q70C33': array([[181, 202]], dtype=object),
#  'Q1R011': array([[483, 508]], dtype=object),
#  'Q2KUG1': array([[1, 24]], dtype=object),
#  'Q9CKD6': array([[1, 23]], dtype=object),
#  'Q1I3T0': array([[1, 21]], dtype=object),
#  'Q9Z5E9': array([[1, 22]], dtype=object),
#  'A5WA45': array([[1, 23]], dtype=object),
#  'B0KM36': array([[1, 23]], dtype=object),
#  'Q88D17': array([[1, 23]], dtype=object),
#  'Q9Z439': array([[1, 22]], dtype=object),
#  'B1J2S8': array([[1, 21]], dtype=object),
#  'B3PZ92': array([[1, 20]], dtype=object),
#  'Q2KDB0': array([[1, 20]], dtype=object),
#  'Q1MME0': array([[1, 21]], dtype=object),
#  'B5ZYK8': array([[1, 21]], dtype=object),
#  'Q46Y42': array([[1, 23]], dtype=object),
#  'Q3SVP3': array([[1, 22]], dtype=object),
#  'Q2NSL7': array([[1, 21]], dtype=object),
#  'Q8ZLY9': array([[96, 119]], dtype=object),
#  'Q2RMZ4': array([[1, 22]], dtype=object),
#  'Q9NZI7': array([[236, 270],
#         [285, 368]], dtype=object),
#  'Q811S7': array([[235, 265],
#         [285, 372]], dtype=object),
#  'Q2T9Q2': array([[139, 165]], dtype=object),
#  'Q8N7F7': array([[141, 174]], dtype=object),
#  'Q19KS6': array([[139, 181]], dtype=object),
#  'Q9CQ84': array([[146, 188]], dtype=object),
#  'Q2KIS3': array([[201, 313]], dtype=object),
#  'Q91W67': array([[200, 313]], dtype=object),
#  'Q96S82': array([[200, 313]], dtype=object),
#  'Q8RX78': array([[108, 137],
#         [157, 287],
#         [310, 332],
#         [609, 631],
#         [660, 684]], dtype=object),
#  'F4I700': array([[114, 136],
#         [166, 308],
#         [620, 717]], dtype=object),
#  'Q4G0F8': array([[1, 38],
#         [75, 96],
#         [171, 220],
#         [253, 280],
#         [480, 503],
#         [603, 646],
#         [747, 985],
#         [1094, 1135]], dtype=object),
#  'Q9NPG3': array([[1, 38],
#         [78, 98],
#         [171, 220],
#         [253, 282],
#         [321, 358],
#         [480, 504],
#         [594, 660],
#         [712, 836],
#         [852, 986],
#         [1093, 1134]], dtype=object),
#  'E1B7L7': array([[1, 133],
#         [249, 304],
#         [336, 356],
#         [574, 597],
#         [672, 730],
#         [802, 833],
#         [864, 913],
#         [938, 988],
#         [1017, 1201],
#         [1308, 1330]], dtype=object),
#  'Q6ZU65': array([[1, 134],
#         [250, 301],
#         [573, 597],
#         [707, 740],
#         [815, 849],
#         [880, 913],
#         [981, 1006],
#         [1035, 1218]], dtype=object),
#  'D4A666': array([[1, 113],
#         [236, 304],
#         [322, 345],
#         [559, 583],
#         [767, 789],
#         [801, 835],
#         [866, 909],
#         [964, 991],
#         [1021, 1202],
#         [1292, 1330]], dtype=object),
#  'Q80WC1': array([[1, 113],
#         [236, 288],
#         [322, 346],
#         [400, 424],
#         [559, 584],
#         [657, 709],
#         [785, 818],
#         [849, 893],
#         [948, 975],
#         [1003, 1185],
#         [1288, 1314]], dtype=object),
#  'Q9ZSB5': array([[65, 91]], dtype=object),
#  'A5PJS6': array([[132, 159],
#         [306, 335],
#         [555, 596]], dtype=object),
#  'P52479': array([[126, 164],
#         [300, 323],
#         [350, 369],
#         [542, 580]], dtype=object),
#  'Q5ZJN4': array([[113, 145],
#         [262, 314],
#         [537, 581]], dtype=object),
#  'Q3KR59': array([[92, 164],
#         [303, 326],
#         [546, 588]], dtype=object),
#  'Q01988': array([[127, 194],
#         [416, 445]], dtype=object),
#  'Q6DIJ4': array([[139, 170],
#         [561, 593]], dtype=object),
#  'Q14694': array([[139, 166],
#         [194, 257],
#         [307, 337],
#         [551, 594]], dtype=object),
#  'P53874': array([[64, 87],
#         [103, 320],
#         [526, 563],
#         [749, 792]], dtype=object),
#  'Q9MAQ3': array([[69, 89],
#         [636, 660]], dtype=object),
#  'P51784': array([[64, 93],
#         [644, 691],
#         [716, 735],
#         [938, 963]], dtype=object),
#  'P36026': array([[231, 268],
#         [531, 577]], dtype=object),
#  'Q5D006': array([[1, 29],
#         [592, 697],
#         [893, 921]], dtype=object),
#  'A5D9H7': array([[145, 165]], dtype=object),
#  'A4FUN7': array([[148, 169]], dtype=object),
#  'O75317': array([[145, 169]], dtype=object),
#  'Q9D9M2': array([[146, 168]], dtype=object),
#  'Q9FPT1': array([[1, 52]], dtype=object),
#  'C0HB46': array([[150, 169]], dtype=object),
#  'Q99K46': array([[1, 29],
#         [593, 668],
#         [893, 921]], dtype=object),
#  'O60079': array([[1, 36],
#         [721, 762]], dtype=object),
#  'Q84WU2': array([[1, 51]], dtype=object),
#  'P39538': array([[827, 893],
#         [1188, 1207]], dtype=object),
#  'F1QFS9': array([[611, 636],
#         [755, 795]], dtype=object),
#  'P38187': array([[172, 306],
#         [318, 367]], dtype=object),
#  'Q17361': array([[467, 489]], dtype=object),
#  'Q9FPS9': array([[226, 301],
#         [317, 366],
#         [750, 793]], dtype=object),
#  'Q2HJE4': array([[598, 666],
#         [923, 952]], dtype=object),
#  'Q9Y4E8': array([[216, 237],
#         [629, 694],
#         [952, 981]], dtype=object),
#  'Q8R5H1': array([[216, 237],
#         [633, 694],
#         [952, 981]], dtype=object),
#  'Q9R085': array([[597, 665],
#         [923, 952]], dtype=object),
#  'F6Z5C0': array([[623, 695],
#         [950, 982]], dtype=object),
#  'Q08DA3': array([[144, 189],
#         [393, 458]], dtype=object),
#  'Q9SB51': array([[122, 149],
#         [159, 178],
#         [187, 233],
#         [275, 309],
#         [326, 379],
#         [859, 905],
#         [952, 1008]], dtype=object),
#  'P0CAQ1': array([[453, 573]], dtype=object),
#  'A8HAL1': array([[1, 27],
#         [148, 200],
#         [411, 510]], dtype=object),
#  'Q9Y5T5': array([[146, 189],
#         [394, 460]], dtype=object),
#  'Q4R6X7': array([[146, 190],
#         [394, 460]], dtype=object),
#  'O74442': array([[34, 97],
#         [434, 457]], dtype=object),
#  'Q99LG0': array([[1, 20],
#         [164, 184],
#         [393, 456]], dtype=object),
#  'Q2KJ09': array([[1, 23],
#         [145, 184],
#         [392, 456],
#         [526, 553]], dtype=object),
#  'Q6PAW2': array([[398, 502]], dtype=object),
#  'Q9UMW8': array([[19, 45]], dtype=object),
#  'Q9FKP5': array([[171, 219],
#         [262, 281],
#         [637, 702]], dtype=object),
#  'Q0VA64': array([[162, 196],
#         [397, 497]], dtype=object),
#  'Q5RE63': array([[18, 45]], dtype=object),
#  'Q67XW5': array([[518, 631]], dtype=object),
#  'Q9SJA1': array([[484, 672]], dtype=object),
#  'Q9SYG4': array([[1, 26],
#         [230, 268]], dtype=object),
#  'O94966': array([[1, 109],
#         [234, 255],
#         [390, 479],
#         [1218, 1239]], dtype=object),
#  'Q9LQI9': array([[217, 257]], dtype=object),
#  'Q9LJH8': array([[1, 23],
#         [223, 261]], dtype=object),
#  'Q3UJD6': array([[1, 46],
#         [163, 239],
#         [432, 482],
#         [965, 988],
#         [1259, 1281]], dtype=object),
#  'Q6J1Y9': array([[1, 52],
#         [162, 239],
#         [275, 296],
#         [432, 479],
#         [962, 981],
#         [1259, 1278],
#         [1292, 1320]], dtype=object),
#  'Q29RP1': array([[1, 22],
#         [34, 55],
#         [234, 311],
#         [685, 722]], dtype=object),
#  'Q9FPT5': array([[387, 424],
#         [450, 486]], dtype=object),
#  'O94782': array([[1, 21],
#         [33, 52],
#         [258, 336],
#         [693, 723]], dtype=object),
#  'Q9M427': array([[231, 250]], dtype=object),
#  'Q8BJQ2': array([[1, 21],
#         [34, 56],
#         [233, 342],
#         [362, 414],
#         [684, 725]], dtype=object),
#  'Q569C3': array([[1, 21],
#         [33, 54],
#         [232, 341],
#         [363, 411],
#         [686, 723]], dtype=object),
#  'Q9FPS7': array([[1, 20],
#         [42, 162],
#         [556, 585],
#         [674, 695]], dtype=object),
#  'P25037': array([[143, 195],
#         [569, 597],
#         [750, 809]], dtype=object),
#  'A7Z056': array([[101, 120],
#         [258, 308],
#         [322, 415]], dtype=object),
#  'A5PN09': array([[279, 309],
#         [327, 420]], dtype=object),
#  'Q9Y2K6': array([[257, 347],
#         [360, 415]], dtype=object),
#  'Q8C6M1': array([[258, 420]], dtype=object),
#  'Q5R5Z6': array([[256, 414]], dtype=object),
#  'B1WBD7': array([[204, 254],
#         [315, 342]], dtype=object),
#  'Q9FIQ1': array([[1, 111],
#         [534, 732]], dtype=object),
#  'A0JM59': array([[95, 142],
#         [247, 296],
#         [368, 388]], dtype=object),
#  'Q2KJ72': array([[1, 103],
#         [109, 128],
#         [142, 163]], dtype=object),
#  'Q9UK80': array([[1, 103]], dtype=object),
#  'Q9QZL6': array([[1, 103],
#         [146, 169],
#         [324, 349]], dtype=object),
#  'B2GUX4': array([[1, 128],
#         [324, 347]], dtype=object),
#  'Q9UTT1': array([[1, 26]], dtype=object),
#  'Q9FPS3': array([[51, 104],
#         [163, 188],
#         [329, 349]], dtype=object),
#  'Q9FPS4': array([[1, 26],
#         [722, 749],
#         [822, 859]], dtype=object),
#  'Q9FPS2': array([[387, 406],
#         [449, 558]], dtype=object),
#  'Q9UHP3': array([[464, 507],
#         [727, 749]], dtype=object),
#  'P57080': array([[464, 509],
#         [728, 747]], dtype=object),
#  'Q9SCJ9': array([[1, 22],
#         [384, 418]], dtype=object),
#  'Q99MX1': array([[102, 128],
#         [597, 747]], dtype=object),
#  'Q9BXU7': array([[601, 636],
#         [753, 772]], dtype=object),
#  'B1AY13': array([[45, 99],
#         [1030, 1056],
#         [1127, 1148],
#         [1920, 1942],
#         [2060, 2087],
#         [2572, 2617]], dtype=object),
#  'Q9UPU5': array([[45, 102],
#         [1034, 1054],
#         [1129, 1151],
#         [1921, 1945],
#         [2063, 2090],
#         [2575, 2620]], dtype=object),
#  'A3AF13': array([[1, 21],
#         [384, 419],
#         [948, 972]], dtype=object),
#  'A2XDG4': array([[1, 21],
#         [384, 419],
#         [948, 972]], dtype=object),
#  'Q5ZID5': array([[60, 95],
#         [110, 138],
#         [461, 528],
#         [694, 735]], dtype=object),
#  'Q96RU2': array([[60, 80],
#         [477, 535],
#         [697, 728]], dtype=object),
#  'D3ZJ96': array([[60, 82],
#         [483, 539],
#         [703, 728]], dtype=object),
#  'Q9HBJ7': array([[160, 196]], dtype=object),
#  'Q5I043': array([[60, 82],
#         [121, 140],
#         [483, 538],
#         [703, 735]], dtype=object),
#  'Q9ES63': array([[104, 226],
#         [723, 754]], dtype=object),
#  'Q14157': array([[1, 33],
#         [92, 234],
#         [377, 420],
#         [440, 493],
#         [530, 656],
#         [669, 794],
#         [865, 901],
#         [1040, 1087]], dtype=object),
#  'Q80X50': array([[1, 33],
#         [92, 229],
#         [461, 513],
#         [550, 676],
#         [689, 814],
#         [885, 921],
#         [1060, 1107]], dtype=object),
#  'Q8W4N3': array([[1, 36],
#         [85, 105],
#         [387, 418],
#         [744, 770],
#         [784, 826]], dtype=object),
#  'Q2KHV7': array([[53, 112],
#         [207, 228]], dtype=object),
#  'O75604': array([[71, 107],
#         [237, 264]], dtype=object),
#  'Q8IQ27': array([[1, 53],
#         [91, 117],
#         [130, 254],
#         [273, 297],
#         [360, 410],
#         [500, 610]], dtype=object),
#  'O88623': array([[1, 23],
#         [54, 112],
#         [133, 169],
#         [215, 270]], dtype=object),
#  'Q5U349': array([[54, 112],
#         [246, 275]], dtype=object),
#  'A2BGT0': array([[346, 365]], dtype=object),
#  'Q9W462': array([[267, 300]], dtype=object),
#  'Q9P3U0': array([[748, 770]], dtype=object),
#  'Q01476': array([[884, 918]], dtype=object),
#  'Q70CQ3': array([[364, 395]], dtype=object),
#  'Q3UN04': array([[198, 221],
#         [364, 395]], dtype=object),
#  'D3ZPG5': array([[198, 221],
#         [364, 395]], dtype=object),
#  'A4QNN3': array([[379, 405]], dtype=object),
#  'Q70CQ4': array([[1, 62],
#         [79, 119],
#         [162, 185],
#         [812, 835],
#         [919, 939],
#         [951, 1352]], dtype=object),
#  'A6QNM7': array([[274, 334],
#         [403, 433]], dtype=object),
#  'A5PMR2': array([[261, 308],
#         [343, 420],
#         [875, 897]], dtype=object),
#  'M9PD06': array([[393, 429],
#         [1103, 1213],
#         [1536, 1574]], dtype=object),
#  'Q8NFA0': array([[1343, 1362],
#         [1367, 1431]], dtype=object),
#  'Q8TEY7': array([[294, 357],
#         [419, 469]], dtype=object),
#  'Q8R5K2': array([[261, 315],
#         [397, 436]], dtype=object),
#  'Q5REG5': array([[266, 313],
#         [387, 437]], dtype=object),
#  'Q28CN3': array([[268, 311]], dtype=object),
#  'Q9P2H5': array([[544, 566],
#         [610, 757],
#         [984, 1011]], dtype=object),
#  'B3M3M6': array([[115, 152],
#         [523, 572],
#         [594, 892],
#         [972, 1007],
#         [1068, 1091]], dtype=object),
#  'B4IXE0': array([[37, 56],
#         [100, 144],
#         [637, 705],
#         [723, 818],
#         [831, 998],
#         [1076, 1163],
#         [1198, 1240]], dtype=object),
#  'Q9VRP5': array([[22, 44],
#         [107, 148],
#         [487, 794],
#         [818, 881],
#         [912, 985],
#         [1000, 1038]], dtype=object),
#  'B3NC86': array([[23, 47],
#         [104, 149],
#         [489, 730],
#         [745, 888],
#         [963, 1030],
#         [1043, 1085]], dtype=object),
#  'Q70CQ2': array([[502, 535],
#         [550, 679],
#         [1459, 1478],
#         [3331, 3443]], dtype=object),
#  'B4KXJ5': array([[126, 174],
#         [642, 804],
#         [818, 975],
#         [1056, 1122],
#         [1136, 1185]], dtype=object),
#  'Q6ZQ93': array([[503, 533],
#         [551, 670],
#         [682, 705],
#         [775, 801],
#         [1496, 1515],
#         [3369, 3484]], dtype=object),
#  'Q2LZB1': array([[24, 49],
#         [94, 148],
#         [505, 673],
#         [687, 893],
#         [926, 998],
#         [1012, 1059]], dtype=object),
#  'B4LG38': array([[124, 169],
#         [509, 532],
#         [631, 819],
#         [836, 964],
#         [977, 1001],
#         [1048, 1161],
#         [1176, 1214]], dtype=object),
#  'B4PIW8': array([[24, 45],
#         [104, 149],
#         [488, 886],
#         [960, 1026],
#         [1040, 1082]], dtype=object),
#  'B4QIS3': array([[16, 55],
#         [393, 423],
#         [483, 782],
#         [868, 988]], dtype=object),
#  'B4HUI5': array([[22, 45],
#         [102, 145],
#         [464, 512],
#         [554, 853],
#         [941, 1005],
#         [1022, 1059]], dtype=object),
#  'Q9P275': array([[1, 22],
#         [67, 95],
#         [430, 577],
#         [589, 999]], dtype=object),
#  'F1N5V1': array([[111, 306],
#         [670, 705],
#         [721, 797]], dtype=object),
#  'B4MLR8': array([[120, 189],
#         [546, 575],
#         [587, 620],
#         [640, 1095],
#         [1136, 1311]], dtype=object),
#  'B1AQJ2': array([[72, 97],
#         [428, 464],
#         [483, 574],
#         [589, 641],
#         [664, 710],
#         [722, 973]], dtype=object),
#  'E2RK09': array([[111, 308],
#         [673, 705],
#         [719, 831]], dtype=object),
#  'E1C213': array([[134, 239],
#         [251, 305],
#         [683, 710],
#         [729, 751],
#         [811, 840]], dtype=object),
#  'E7F6T8': array([[132, 216],
#         [232, 258],
#         [609, 632],
#         [688, 710]], dtype=object),
#  'Q86T82': array([[110, 153],
#         [183, 304],
#         [673, 702],
#         [719, 795]], dtype=object),
#  'Q8C0R0': array([[116, 178],
#         [192, 240],
#         [719, 795]], dtype=object),
#  'F1SRY5': array([[128, 162],
#         [183, 307],
#         [672, 705],
#         [720, 798]], dtype=object),
#  'O94269': array([[64, 109]], dtype=object),
#  'Q01477': array([[1, 30],
#         [68, 176],
#         [241, 384],
#         [396, 417]], dtype=object),
#  'B2RQC2': array([[1, 38],
#         [64, 86],
#         [417, 517],
#         [549, 587],
#         [624, 676],
#         [717, 781],
#         [816, 847],
#         [880, 1026],
#         [1145, 1262],
#         [1303, 1324]], dtype=object),
#  'Q9H9J4': array([[1, 39],
#         [63, 87],
#         [452, 494],
#         [536, 707],
#         [722, 1026],
#         [1085, 1131],
#         [1148, 1254],
#         [1275, 1294]], dtype=object),
#  'E1B9W9': array([[1, 39],
#         [63, 87],
#         [452, 519],
#         [533, 1041],
#         [1119, 1145],
#         [1160, 1271]], dtype=object),
#  'Q9NVE5': array([[1180, 1235]], dtype=object),
#  'D3ZU96': array([[1, 38],
#         [64, 86],
#         [416, 502],
#         [539, 590],
#         [602, 674],
#         [718, 780],
#         [802, 849],
#         [879, 1032],
#         [1146, 1259],
#         [1290, 1325]], dtype=object),
#  'Q9H0E7': array([[690, 712]], dtype=object),
#  'Q8BUM9': array([[1, 103],
#         [839, 891],
#         [935, 1008],
#         [1024, 1044],
#         [1057, 1106]], dtype=object),
#  'Q8C2S0': array([[170, 251],
#         [685, 711]], dtype=object),
#  'D2HBJ8': array([[237, 264],
#         [336, 358],
#         [689, 711]], dtype=object),
#  'Q7ZUM8': array([[198, 294]], dtype=object),
#  'Q70EL4': array([[1, 102],
#         [202, 221],
#         [795, 826],
#         [854, 886],
#         [959, 1049],
#         [1068, 1099]], dtype=object),
#  'Q0V9G5': array([[183, 230]], dtype=object),
#  'P34547': array([[162, 181]], dtype=object),
#  'Q70EL2': array([[1, 28],
#         [418, 443],
#         [479, 534]], dtype=object),
#  'Q8K387': array([[1, 27],
#         [405, 552]], dtype=object),
#  'E9QG68': array([[1, 34],
#         [394, 554]], dtype=object),
#  'Q96K76': array([[425, 452],
#         [840, 859],
#         [880, 968],
#         [983, 1024]], dtype=object),
#  'Q8BY87': array([[426, 452],
#         [835, 863],
#         [880, 971],
#         [985, 1025]], dtype=object),
#  'Q5U252': array([[110, 138],
#         [409, 437],
#         [815, 836],
#         [859, 1000]], dtype=object),
#  'A1A5G2': array([[114, 139],
#         [407, 438],
#         [863, 1004],
#         [1314, 1335]], dtype=object),
#  'E1C1R4': array([[425, 451],
#         [831, 852],
#         [879, 1025]], dtype=object),
#  'G5ECC7': array([[390, 415],
#         [522, 610],
#         [630, 679]], dtype=object),
#  'Q5ZM45': array([[610, 639],
#         [878, 920]], dtype=object),
#  'Q86UV5': array([[612, 640],
#         [879, 919]], dtype=object),
#  'Q70CQ1': array([[169, 230],
#         [293, 317]], dtype=object),
#  'Q76LT8': array([[611, 644],
#         [881, 924]], dtype=object),
#  'Q3V0C5': array([[609, 639],
#         [896, 940]], dtype=object),
#  'Q754R5': array([[369, 394]], dtype=object),
#  'Q6FQF0': array([[358, 465],
#         [484, 505]], dtype=object),
#  'A6QR55': array([[219, 277],
#         [634, 701],
#         [930, 963]], dtype=object),
#  'Q13107': array([[1, 22],
#         [219, 253],
#         [637, 699],
#         [928, 963]], dtype=object),
#  'P35123': array([[220, 249],
#         [638, 699],
#         [928, 962]], dtype=object),
#  'Q5RCD3': array([[220, 255],
#         [637, 698],
#         [928, 963]], dtype=object),
#  'B2GUZ1': array([[219, 257],
#         [641, 700],
#         [924, 961]], dtype=object),
#  'A7TGY3': array([[382, 411]], dtype=object),
#  'Q70EK9': array([[1, 174]], dtype=object),
#  'B1AY15': array([[1, 144]], dtype=object),
#  'Q70EK8': array([[389, 437],
#         [485, 636]], dtype=object),
#  'P15975': array([[414, 438],
#         [457, 476],
#         [486, 634],
#         [646, 710],
#         [805, 866],
#         [946, 981],
#         [1046, 1069]], dtype=object),
#  'O22207': array([[64, 87],
#         [648, 690]], dtype=object),
#  'Q70EL1': array([[374, 416],
#         [430, 578],
#         [607, 703],
#         [720, 742],
#         [859, 894],
#         [928, 950],
#         [967, 1060],
#         [1139, 1227],
#         [1334, 1391],
#         [1425, 1455],
#         [1620, 1652]], dtype=object),
#  'Q8BL06': array([[382, 519],
#         [555, 577],
#         [601, 624],
#         [801, 834],
#         [1089, 1182],
#         [1221, 1242],
#         [1491, 1561]], dtype=object),
#  'P45974': array([[74, 96]], dtype=object),
#  'Q6IE24': array([[380, 447],
#         [459, 519],
#         [601, 620],
#         [801, 839],
#         [856, 895],
#         [950, 969],
#         [1093, 1172],
#         [1525, 1562]], dtype=object),
#  'Q949Y0': array([[350, 407]], dtype=object),
#  'Q5R407': array([[74, 96]], dtype=object),
#  'P39944': array([[359, 380]], dtype=object),
#  'P56399': array([[73, 98]], dtype=object),
#  'P43593': array([[365, 391]], dtype=object),
#  'Q84WC6': array([[364, 401]], dtype=object),
#  'P35125': array([[348, 380],
#         [1120, 1231],
#         [1384, 1406]], dtype=object),
#  'Q6U7I1': array([[1, 64]], dtype=object),
#  'Q9VYQ8': array([[1, 20]], dtype=object),
#  'Q93009': array([[1, 38]], dtype=object),
#  'Q6A4J8': array([[1, 41],
#         [46, 65]], dtype=object),
#  'Q9P7S5': array([[396, 486],
#         [575, 628]], dtype=object),
#  'Q4VSI4': array([[1, 40]], dtype=object),
#  'Q9C585': array([[615, 650]], dtype=object),
#  'P40453': array([[467, 532],
#         [913, 942]], dtype=object),
#  'P40818': array([[120, 177],
#         [402, 447],
#         [475, 648],
#         [679, 746]], dtype=object),
#  'Q80U87': array([[119, 176],
#         [379, 455],
#         [468, 605],
#         [642, 710]], dtype=object),
#  'Q9P7V9': array([[1, 23],
#         [85, 110],
#         [447, 473],
#         [511, 530],
#         [540, 585]], dtype=object),
#  'Q93Y01': array([[68, 89]], dtype=object),
#  'P39967': array([[1, 76],
#         [194, 273],
#         [726, 754]], dtype=object),
#  'O96612': array([[83, 154]], dtype=object),
#  'P54201': array([[676, 695]], dtype=object),
#  'Q8WT44': array([[681, 725]], dtype=object),
#  'Q24574': array([[117, 231],
#         [628, 697],
#         [1087, 1148]], dtype=object),
#  'Q09931': array([[375, 402]], dtype=object),
#  'Q9UMX0': array([[1, 35],
#         [110, 145],
#         [295, 371],
#         [488, 520]], dtype=object),
#  'Q8R317': array([[1, 25],
#         [103, 136],
#         [286, 365],
#         [478, 513]], dtype=object),
#  'Q5R684': array([[1, 35],
#         [110, 145],
#         [295, 371],
#         [488, 520]], dtype=object),
#  'Q9JJP9': array([[1, 26],
#         [102, 136],
#         [285, 365],
#         [481, 513]], dtype=object),
#  'Q9UHD9': array([[1, 32],
#         [106, 141],
#         [287, 349],
#         [512, 556]], dtype=object),
#  'Q9QZM0': array([[1, 31],
#         [107, 158],
#         [298, 364],
#         [528, 570]], dtype=object),
#  'Q9H347': array([[102, 124],
#         [277, 330],
#         [364, 399],
#         [411, 447]], dtype=object),
#  'Q8C5U9': array([[280, 336],
#         [362, 478]], dtype=object),
#  'Q9NRR5': array([[87, 155],
#         [301, 366],
#         [490, 533]], dtype=object),
#  'Q8IYU4': array([[113, 138],
#         [305, 325]], dtype=object),
#  'Q99NB8': array([[89, 148],
#         [297, 361],
#         [482, 528]], dtype=object),
#  'G5EFF7': array([[84, 136],
#         [235, 294]], dtype=object),
#  'Q5XIP4': array([[1, 25]], dtype=object),
#  'Q9NIF3': array([[70, 99],
#         [215, 325]], dtype=object),
#  'O13731': array([[471, 490],
#         [496, 525]], dtype=object),
#  'P91133': array([[1107, 1175],
#         [1381, 1416],
#         [1475, 1499]], dtype=object),
#  'Q9VX91': array([[1006, 1043],
#         [1073, 1093]], dtype=object),
#  'O60014': array([[1901, 1945]], dtype=object),
#  'Q8IWV7': array([[842, 868]], dtype=object),
#  'O70481': array([[1, 24],
#         [842, 868]], dtype=object),
#  'Q8IWV8': array([[1004, 1034],
#         [1261, 1287]], dtype=object),
#  'P19812': array([[1826, 1846],
#         [1892, 1950]], dtype=object),
#  'Q07963': array([[1203, 1227]], dtype=object),
#  'F1QJX5': array([[302, 330],
#         [970, 995],
#         [1128, 1152]], dtype=object),
#  'Q6ZT12': array([[1, 24],
#         [339, 362],
#         [1008, 1028],
#         [1164, 1186]], dtype=object),
#  'Q9W3M3': array([[1, 48],
#         [78, 134],
#         [1225, 1244],
#         [1348, 1367],
#         [1440, 1464],
#         [1872, 1902],
#         [1935, 1954]], dtype=object),
#  'Q6WKZ8': array([[1012, 1033]], dtype=object),
#  'Q5U430': array([[1, 27],
#         [338, 362]], dtype=object),
#  'O95071': array([[77, 175],
#         [328, 352],
#         [579, 648],
#         [999, 1031],
#         [1052, 1076],
#         [1299, 1318],
#         [1515, 1740],
#         [1859, 1890],
#         [1984, 2021],
#         [2117, 2142],
#         [2323, 2392],
#         [2473, 2493]], dtype=object),
#  'Q54DV0': array([[1, 47],
#         [183, 202]], dtype=object),
#  'Q80TP3': array([[77, 175],
#         [322, 347],
#         [577, 642],
#         [993, 1029],
#         [1046, 1070],
#         [1293, 1312],
#         [1509, 1734],
#         [1853, 1884],
#         [1978, 2015],
#         [2111, 2137],
#         [2317, 2387],
#         [2467, 2494]], dtype=object),
#  'Q62671': array([[68, 165],
#         [318, 343],
#         [572, 636],
#         [988, 1024],
#         [1041, 1065],
#         [1288, 1308],
#         [1504, 1729],
#         [1848, 1881],
#         [1974, 2011],
#         [2106, 2132],
#         [2313, 2383],
#         [2463, 2490]], dtype=object),
#  'Q8N806': array([[225, 246]], dtype=object),
#  'Q8BU04': array([[212, 269]], dtype=object),
#  'Q5T4S7': array([[1, 26],
#         [549, 588],
#         [601, 638],
#         [1755, 1778],
#         [2430, 2469],
#         [2711, 2764],
#         [2832, 2967],
#         [3342, 3385]], dtype=object),
#  'P38290': array([[254, 277]], dtype=object),
#  'Q9VCE9': array([[367, 394],
#         [458, 484]], dtype=object),
#  'A2AN08': array([[1, 26],
#         [205, 228],
#         [549, 588],
#         [601, 639],
#         [2429, 2466],
#         [2708, 2761],
#         [2829, 2963],
#         [3344, 3383]], dtype=object),
#  'Q3ZBQ1': array([[1, 36]], dtype=object),
#  'Q4V8W7': array([[1, 45]], dtype=object),
#  'Q9HAC8': array([[1, 35]], dtype=object),
#  'Q91WB7': array([[1, 35]], dtype=object),
#  'Q68FV8': array([[1, 35]], dtype=object),
#  'Q640W6': array([[1, 47]], dtype=object),
#  'Q6GL38': array([[1, 48]], dtype=object),
#  'Q5EAE3': array([[1, 46]], dtype=object),
#  'Q2TL32': array([[1, 26],
#         [209, 228],
#         [549, 588],
#         [601, 638],
#         [2431, 2468],
#         [2711, 2764],
#         [2875, 2979],
#         [3357, 3396]], dtype=object),
#  'Q6DG43': array([[1, 48]], dtype=object),
#  'Q8WUN7': array([[1, 46]], dtype=object),
#  'Q6PGH0': array([[1, 46]], dtype=object),
#  'Q0P3Z8': array([[1, 79]], dtype=object),
#  'Q96LJ8': array([[41, 94]], dtype=object),
#  'Q8BG34': array([[1, 102]], dtype=object),
#  'Q5T124': array([[1, 26],
#         [476, 520]], dtype=object),
#  'Q9D572': array([[1, 28]], dtype=object),
#  'Q8R512': array([[1, 26]], dtype=object),
#  'Q6IP50': array([[43, 215]], dtype=object),
#  'Q6GLV4': array([[44, 210]], dtype=object),
#  'P0C8Q0': array([[39, 179],
#         [236, 293]], dtype=object),
#  'P34223': array([[44, 167],
#         [299, 348]], dtype=object),
#  'Q99KJ0': array([[1, 30]], dtype=object),
#  'Q5ZLK2': array([[1, 97]], dtype=object),
#  'Q14CS0': array([[1, 26],
#         [40, 66]], dtype=object),
#  'Q0KL01': array([[1, 71]], dtype=object),
#  'P0C627': array([[1, 26],
#         [38, 63]], dtype=object),
#  'Q0P3R5': array([[1, 46]], dtype=object),
#  'O14048': array([[115, 143],
#         [273, 331]], dtype=object),
#  'Q9UT81': array([[46, 139],
#         [154, 212]], dtype=object),
#  'Q12229': array([[25, 48],
#         [120, 142],
#         [305, 332]], dtype=object),
#  'Q9P7L2': array([[224, 257]], dtype=object),
#  'P54730': array([[376, 402]], dtype=object),
#  'P47049': array([[333, 361],
#         [374, 396]], dtype=object),
#  'Q32KW2': array([[40, 210]], dtype=object),
#  'Q06682': array([[50, 70],
#         [142, 169],
#         [371, 399]], dtype=object),
#  'P38349': array([[115, 141],
#         [325, 357],
#         [371, 436]], dtype=object),
#  'Q9TXH9': array([[39, 61],
#         [127, 176],
#         [191, 218]], dtype=object),
#  'Q6NXA9': array([[42, 215]], dtype=object),
#  'Q04323': array([[41, 211]], dtype=object),
#  'Q922Y1': array([[38, 214]], dtype=object),
#  'Q499N6': array([[38, 212]], dtype=object),
#  'Q6GL77': array([[44, 207]], dtype=object),
#  'Q9N2W5': array([[1, 61],
#         [176, 200]], dtype=object),
#  'H2L056': array([[67, 223],
#         [453, 472]], dtype=object),
#  'Q3ZBU9': array([[117, 199],
#         [450, 508]], dtype=object),
#  'P34631': array([[181, 212],
#         [404, 469]], dtype=object),
#  'Q92575': array([[117, 196],
#         [440, 508]], dtype=object),
#  'Q8VCH8': array([[110, 194],
#         [437, 506]], dtype=object),
#  'Q5R4I3': array([[117, 196],
#         [440, 508]], dtype=object),
#  'Q5HZY0': array([[114, 193],
#         [437, 506]], dtype=object),
#  'Q2KIJ6': array([[12, 57],
#         [62, 81],
#         [86, 113]], dtype=object),
#  'Q8WTJ4': array([[1, 45],
#         [89, 110]], dtype=object),
#  'Q9BZV1': array([[13, 79],
#         [87, 106]], dtype=object),
#  'Q99PL6': array([[13, 111]], dtype=object),
#  'Q55BU7': array([[44, 80],
#         [262, 284],
#         [299, 389]], dtype=object),
#  'O94888': array([[56, 77],
#         [300, 384]], dtype=object),
#  'Q6P5G6': array([[57, 77],
#         [240, 260],
#         [281, 364]], dtype=object),
#  'Q2TBH5': array([[137, 181]], dtype=object),
#  'O00124': array([[130, 171]], dtype=object),
#  'Q5REY7': array([[56, 77],
#         [300, 384]], dtype=object),
#  'Q9QZ49': array([[64, 89]], dtype=object),
#  'P05048': array([[125, 193]], dtype=object),
#  'P83949': array([[138, 189]], dtype=object),
#  'P20822': array([[132, 194]], dtype=object),
#  'P83950': array([[138, 189]], dtype=object),
#  'Q25451': array([[116, 191]], dtype=object),
#  'P80618': array([[1, 40]], dtype=object),
#  'P0CG44': array([[1, 29]], dtype=object),
#  'O82081': array([[194, 239]], dtype=object),
#  'Q8IIJ6': array([[244, 293]], dtype=object),
#  'Q54N38': array([[242, 266]], dtype=object),
#  'Q54T48': array([[235, 255]], dtype=object),
#  'Q6PA79': array([[241, 271]], dtype=object),
#  'Q6GPD9': array([[240, 271]], dtype=object),
#  'Q66I71': array([[241, 277]], dtype=object),
#  'Q0P5A4': array([[1, 29],
#         [246, 277]], dtype=object),
#  'Q9HA47': array([[1, 30],
#         [247, 277]], dtype=object),
#  'Q4R4K2': array([[1, 29],
#         [224, 254]], dtype=object),
#  'P52623': array([[1, 30],
#         [238, 277]], dtype=object),
#  'Q7ZV79': array([[238, 261]], dtype=object),
#  'Q9BZX2': array([[1, 24],
#         [236, 261]], dtype=object),
#  'Q99PM9': array([[1, 24],
#         [240, 261]], dtype=object),
#  'Q9QYG8': array([[1, 24],
#         [240, 261]], dtype=object),
#  'B1H116': array([[1, 24],
#         [238, 261]], dtype=object),
#  'Q55EL3': array([[1, 44]], dtype=object),
#  'Q9GNF0': array([[36, 56],
#         [468, 492]], dtype=object),
#  'Q17413': array([[224, 248]], dtype=object),
#  'Q9NWZ5': array([[1, 78]], dtype=object),
#  'B9TQX1': array([[60, 117]], dtype=object),
#  'Q91YL3': array([[1, 74]], dtype=object),
#  'Q6NWB6': array([[65, 135]], dtype=object),
#  'B9TQX3': array([[57, 116]], dtype=object),
#  'Q14BU0': array([[58, 78]], dtype=object),
#  'B9TQX4': array([[58, 85]], dtype=object),
#  'B9TQX2': array([[87, 115]], dtype=object),
#  'Q28HK1': array([[58, 116]], dtype=object),
#  'P55089': array([[23, 46]], dtype=object),
#  'Q96RP3': array([[27, 66]], dtype=object),
#  'Q99ML8': array([[37, 64]], dtype=object),
#  'Q91WW1': array([[24, 60]], dtype=object),
#  'Q1RMJ9': array([[41, 123]], dtype=object),
#  'Q969E3': array([[64, 118]], dtype=object),
#  'Q924A4': array([[58, 120]], dtype=object),
#  'O94536': array([[1, 58],
#         [201, 222]], dtype=object),
#  'O74345': array([[123, 158],
#         [289, 310]], dtype=object),
#  'O13773': array([[1, 94],
#         [305, 346],
#         [547, 573]], dtype=object),
#  'O94685': array([[93, 121],
#         [466, 520],
#         [574, 614],
#         [724, 785]], dtype=object),
#  'Q94JS0': array([[27, 46]], dtype=object),
#  'Q9LYR2': array([[29, 48]], dtype=object),
#  'O49078': array([[1, 20]], dtype=object),
#  'Q69BJ9': array([[30, 54]], dtype=object),
#  'Q9F722': array([[1, 35]], dtype=object),
#  'Q46136': array([[1, 35]], dtype=object),
#  'P49727': array([[25, 46]], dtype=object),
#  'D5ANZ2': array([[95, 116]], dtype=object),
#  'Q69BJ7': array([[28, 54]], dtype=object),
#  'A0A411KUX1': array([[1, 56]], dtype=object),
#  'A0A411KUQ2': array([[23, 42]], dtype=object),
#  'A0A411KUP8': array([[2381, 2473],
#         [3483, 3507]], dtype=object),
#  'P64786': array([[1, 29]], dtype=object),
#  'P9WM52': array([[1, 29]], dtype=object),
#  ...}

# %%
# Load ELM classes (Regex Patterns)
elm_classes_pd = pd.read_csv(elm_file, delimiter="\t", comment="#")
elm_classes_pd
# Out:
#       Accession       ELMIdentifier  \
# 0    ELME000321  CLV_C14_Caspase3-7
# 1    ELME000172       CLV_MEL_PAP_1
# 2    ELME000102       CLV_NRD_NRD_1
# 3    ELME000101      CLV_PCSK_FUR_1
# 4    ELME000108     CLV_PCSK_KEX2_1
# ..          ...                 ...
# 348  ELME000271  TRG_NLS_MonoExtN_4
# 349  ELME000546      TRG_Oom_RxLR_1
# 350  ELME000462  TRG_Pf-PMV_PEXEL_1
# 351  ELME000009            TRG_PTS1
# 352  ELME000069            TRG_PTS2
#
#                                     FunctionalSiteName  \
# 0                               Caspase cleavage motif
# 1                         Melanisation activation site
# 2                                    NRD cleavage site
# 3                                   PCSK cleavage site
# 4                                   PCSK cleavage site
# ..                                                 ...
# 348         NLS classical Nuclear Localization Signals
# 349  Oomycete secretory protein processing motif pe...
# 350                          Apicomplexan export motif
# 351                                               PTS1
# 352                                               PTS2
#
#                                            Description  \
# 0               Caspase-3 and Caspase-7 cleavage site.
# 1    Prophenoloxidase-activating proteinase (PAP) c...
# 2    N-Arg dibasic convertase (NRD/Nardilysin) clea...
# 3         Furin (PACE) cleavage site (R-X-[RK]-R-|-X).
# 4    Yeast kexin 2 cleavage site (K-R-|-X or R-R-|-X).
# ..                                                 ...
# 348  Monopartite variant of the classical basically...
# 349                     Oomycete host targeting signal
# 350  Plasmodium Export Element, PEXEL, is a traffic...
# 351                Generic PTS1 ELM for all eukaryotes
# 352  Generic PTS2 pattern for all eukaryotes (excep...
#
#                                                  Regex  Probability  \
# 0                          [DSTE][^P][^DEWHFYC]D[GSAN]     0.003094
# 1                                    [ILV]..R[VF][GS].     0.000105
# 2                                      (.RK)|(RR[^KR])     0.007465
# 3                                             R.[RK]R.     0.000509
# 4                                               [KR]R.     0.007973
# ..                                                 ...          ...
# 348  (([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^...     0.001276
# 349                                      ((R)|(K.)).LR     0.000583
# 350                (R.[LI].[EDQ])|(R.L..[EDQ])|(K.L.E)     0.002161
# 351  (.[SAPTC][KRH][LMFI]$)|([KRH][SAPTC][NTS][LMFI]$)     0.000015
# 352        ^.{1,40}R[^P][^P][^P][LIV][^P][^P][HQ][LIF]     0.000004
#
#      #Instances  #Instances_in_PDB
# 0            41                  0
# 1            12                  0
# 2             2                  0
# 3            13                  0
# 4             1                  0
# ..          ...                ...
# 348          28                  2
# 349           5                  0
# 350          24                  0
# 351           5                  1
# 352           2                  2
#
# [353 rows x 8 columns]

# %%
elm_patterns = dict(zip(elm_classes_pd["ELMIdentifier"], elm_classes_pd["Regex"]))
elm_patterns
# Out:
# {'CLV_C14_Caspase3-7': '[DSTE][^P][^DEWHFYC]D[GSAN]',
#  'CLV_MEL_PAP_1': '[ILV]..R[VF][GS].',
#  'CLV_NRD_NRD_1': '(.RK)|(RR[^KR])',
#  'CLV_PCSK_FUR_1': 'R.[RK]R.',
#  'CLV_PCSK_KEX2_1': '[KR]R.',
#  'CLV_PCSK_PC1ET2_1': 'KR.',
#  'CLV_PCSK_PC7_1': 'R...[KR]R.',
#  'CLV_PCSK_SKI1_1': '[RK].[AILMFV][LTKF].',
#  'CLV_Separin_Fungi': 'S[IVLMH]E[IVPFMLYAQR]GR.',
#  'CLV_Separin_Metazoa': 'E[IMPVL][MLVP]R.',
#  'CLV_TASPASE1': 'Q[MLVI]DG..[DE]',
#  'DEG_APCC_DBOX_1': '.R..L..[LIVM].',
#  'DEG_APCC_KENBOX_2': '.KEN.',
#  'DEG_APCC_TPR_1': '.[ILM]R$',
#  'DEG_Cend_DCAF12_1': '..EE$',
#  'DEG_Cend_FEM1AC_1': '[RK].{1,2}R$',
#  'DEG_Cend_FEM1B_2': '.L.R$',
#  'DEG_Cend_KLHDC2_1': '...G[GA]$',
#  'DEG_Cend_TRIM7_1': '[^P][^P][FL]Q$',
#  'DEG_COP1_1': '[STDE]{1,3}.{0,2}[TSDE].{2,3}VP[STDE]G{0,1}[FLIMVYPA]',
#  'DEG_CRBN_cyclicCter_1': '...[NQ]$',
#  'DEG_CRL4_CDT2_1': '[NQ]{0,1}..[ILMV][ST][DEN][FY][FY].{2,3}[KR]{2,3}[^DE]',
#  'DEG_CRL4_CDT2_2': '[NQ]{0,1}..[ILMV]T[DEN][HMFY][FMY].{2,3}[KR]{2,3}[^DE]',
#  'DEG_Kelch_actinfilin_1': '[AP]P[MV][IM]V',
#  'DEG_Kelch_Keap1_1': '[DNS].[DES][TNS]GE',
#  'DEG_Kelch_Keap1_2': 'QD.DLGV',
#  'DEG_Kelch_KLHL12_1': '[PGA]PG[AG]PP',
#  'DEG_Kelch_KLHL3_1': 'E.EE.E[AV]DQH',
#  'DEG_MDM2_SWIB_1': 'F[^P]{3}W[^P]{2,3}[VIL]',
#  'DEG_Nend_Nbox_1': '^M{0,1}[FYLIW][^P]',
#  'DEG_Nend_UBRbox_1': '^M{0,1}[RK][^P].',
#  'DEG_Nend_UBRbox_2': '^M{0,1}([ED]).',
#  'DEG_Nend_UBRbox_3': '^M{0,1}([NQ]).',
#  'DEG_Nend_UBRbox_4': '^M{0,1}(C).',
#  'DEG_ODPH_VHL_1': '[IL]A(P).{6,8}[FLIVM].[FLIVM]',
#  'DEG_SCF_COI1_1': '..[RK][RK].SL..F[FLM].[RK]R[HRK].[RK].',
#  'DEG_SCF_FBW7_1': '[LIVMP].{0,2}(T)P..([ST])',
#  'DEG_SCF_FBW7_2': '[LIVMP].{0,2}(T)P..E',
#  'DEG_SCF_FBXO31_1': 'D[LVIM].[DAEN][VILM][^P][ILF]$',
#  'DEG_SCF_SKP2-CKS1_1': '..[DE].(T)P.K',
#  'DEG_SCF_TIR1_1': '.[VLIA][VLI]GWPP[VLI]...R.',
#  'DEG_SCF_TRCP1_1': 'D(S)G.{2,3}([ST])',
#  'DEG_SIAH_1': '.P.A.V.P[^P]',
#  'DEG_SPOP_SBC_1': '[AVP].[ST][ST][ST]',
#  'DOC_AGCK_PIF_1': 'F..[FWY][ST][FY]',
#  'DOC_AGCK_PIF_2': 'F..[FWY][DE][FY]',
#  'DOC_AGCK_PIF_3': 'F..F$',
#  'DOC_ANK_TNKS_1': '.R..[PGAV][DEIP]G.',
#  'DOC_CDC14_PxL_1': '[FYLIM]..[YVILA]P.L..',
#  'DOC_CKS1_1': '[MPVLIFWYQ].(T)P..',
#  'DOC_CYCLIN_D_Helix_1': '[FLV][^P][^P][KR]L[^P][^P][LMIV][^P][^P][^P]R',
#  'DOC_CYCLIN_RevRxL_6': '[EDST].{0,3}[FL].[ILV][^D][RK][^PD][^EDWNG]((.{0,3}[KRH])|.)',
#  'DOC_CYCLIN_RxL_1': '(.|([KRH].{0,3}))[^EDWNSG][^D][RK][^D]L.{0,1}[FL].{0,3}[EDST]',
#  'DOC_CYCLIN_yClb1_LxF_4': '(P.[KR]L.F)|(.N[KR]L.F)|(.N.L.F[LMIVFY])',
#  'DOC_CYCLIN_yClb3_PxF_3': '(PP..P.F)|(P..P.F..[KR])',
#  'DOC_CYCLIN_yClb5_NLxxxL_5': '([ILVMF]...NL...L)|([KR].{0,2}NL...L)',
#  'DOC_CYCLIN_yCln2_LP_2': '(L[MLIV]PP)|(((L[LMIV]PA)|(L..P))[ILMVAFYW].[MLIVFHPAY])',
#  'DOC_GSK3_Axin_1': 'V[ED]P[^P][RK]FA[^P]ELI[^P]RLE[^P][VIL]',
#  'DOC_MAPK_DCC_7': '[RK].{2,4}[LIVP]P.[LIV].[LIVMF]|[RK].{2,4}[LIVP].P[LIV].[LIVMF]',
#  'DOC_MAPK_FxFP_2': 'F.[FY]P',
#  'DOC_MAPK_gen_1': '[KR]{0,2}[KR].{0,2}[KR].{2,4}[ILVM].[ILVF]',
#  'DOC_MAPK_GRA24_9': '[LIV][^P][^P][RK][RK]G.{3,6}[LIVP]P.[LIV].[LIVMF]|[LIV][^P][^P][RK][RK]G.{3,6}[LIVP].P[LIV].[LIVMF]',
#  'DOC_MAPK_HePTP_8': '([LIV][^P][^P][RK]....[LIVMP].[LIV].[LIVMF])|([LIV][^P][^P][RK][RK]G.{4,7}[LIVMP].[LIV].[LIVMF])',
#  'DOC_MAPK_JIP1_4': '[RK]P[^P][^P]L.[LIVMF]',
#  'DOC_MAPK_MEF2A_6': '[RK].{2,4}[LIVMP].[LIV].[LIVMF]',
#  'DOC_MAPK_NFAT4_5': '[RK][^P][^P][LIM].L.[LIVMF].',
#  'DOC_MAPK_RevD_3': '[LIVMPFA].[LIV].{1,2}[LIVMP].{4,6}[LIV]..[RK][RK]',
#  'DOC_MIT_MIM_1': '((F[^P][^P])|([DE].{0,2}))L[^P][^P]R[FL][^P][^P]L[KR]{0,2}',
#  'DOC_PIKK_1': '[DEN][DEN].{2,3}[ILMVA][DEN][DEN]L',
#  'DOC_PP1_MyPhoNE_1': 'R[^P][DEQ]Q[VIL]([RK][^P]|[^P][RK])[YW]',
#  'DOC_PP1_RVXF_1': '..[RK].{0,1}[VIL][^P][FW].',
#  'DOC_PP1_SILK_1': '.[GS]IL[KR][^DE]',
#  'DOC_PP2A_B56_1': '([LMFYWIC]..I.E)|(L..[IVLWC].E).',
#  'DOC_PP2B_LxvP_1': 'L.VP',
#  'DOC_PP2B_PxIxIT_1': 'P[^P][ILVF][^P][ILVF][TSHDEQNKR]',
#  'DOC_PP4_FxxP_1': 'F..P',
#  'DOC_PP4_MxPP_1': 'M.PP',
#  'DOC_PUB_PIM_1': '.D[LM]Y.',
#  'DOC_RSK_DDVF_1': '[DE][DE]VF',
#  'DOC_SPAK_OSR1_1': 'RF[^P][IV].',
#  'DOC_TBK1_STING_1': '[DE].P.[PST]L[RKHNQ][ST][DN]',
#  'DOC_USP7_MATH_1': '[PA][^P][^FYWIL]S[^P]',
#  'DOC_USP7_MATH_2': 'P.E[^P].S[^P]',
#  'DOC_USP7_UBL2_3': 'K...K',
#  'DOC_WD40_RPTOR_TOS_1': 'F[EDQS][MILV][ED][MILV]((.{0,1}[ED])|($))',
#  'DOC_WW_Pin1_4': '...([ST])P.',
#  'LIG_14-3-3_CanoR_1': 'R[^DE]{0,2}[^DEPG]([ST])(([FWYLMV].)|([^PRIKGN]P)|([^PRIKGN].{2,4}[VILMFWYP]))',
#  'LIG_14-3-3_ChREBP_3': 'IR[^P][^P]N[^P][^P]WR[^P]W[YFH][ITML][^P]Y[IVL]',
#  'LIG_14-3-3_CterR_2': 'R[^DE]{0,2}[^DEPG]([ST])[^P]{0,1}$',
#  'LIG_ActinCP_CPI_1': 'L.(([H].[TQVG])|([SC].N)|(D.R))..R[PAVT][KRHM][^DEN].{1,5}((R.)|(.[RK]))..[PAS][^P]',
#  'LIG_ActinCP_TwfCPI_2': 'F.[KR]P..[PAS].{0,3}[RK]',
#  'LIG_Actin_RPEL_3': '[IL]..[^P][^P][^P][^P]R.....[IL]..[^P][^P][ILV][ILM]',
#  'LIG_Actin_WH2_1': 'R..[ILVMF][ILMVF][^P][^P][ILVM].{4,7}L(([KR].)|(NK))[VATI]',
#  'LIG_Actin_WH2_2': '[^R]..((.[ILMVF])|([ILMVF].))[^P][^P][ILVM].{4,7}L(([KR].)|(NK))[VATIGS]',
#  'LIG_ANK_PxLPxL_1': 'P.LP.[IL].{1,3}[VLF]',
#  'LIG_AP2alpha_1': 'F.D.F',
#  'LIG_AP2alpha_2': 'DP[FW]',
#  'LIG_APCC_ABBA_1': '[ILVMF].[ILMVP][FHY].[DE]',
#  'LIG_APCC_ABBAyCdc20_2': '[KR]..[ILVM][FHY].[DE]',
#  'LIG_APCC_Cbox_1': '[DE]R[YFH][ILFVM][PAG].R',
#  'LIG_APCC_Cbox_2': 'DR[YFH][ILFVM][PA]..',
#  'LIG_AP_GAE_1': '[DE][DES][DEGAS]F[SGAD][DEAP][LVIMFD]',
#  'LIG_Arc_Nlobe_1': '[^P][P]G{0,1}[^P][YFH][^P]',
#  'LIG_ARL_BART_1': '^..LL[^P]IL[^P][^P][LM]',
#  'LIG_ARS2_EDGEI_1': 'E[ED]G[EQ][ILVM].{0,2}[DE]',
#  'LIG_BH_BH3_1': '....[LIFVYMTE][ASGC][^P]{2}L[^P]{2}[IVMTL][GACS][D][^P][FVLMI].',
#  'LIG_BIR_II_1': '^M{0,1}[AS]...',
#  'LIG_BIR_III_1': '^M{0,1}A.P.',
#  'LIG_BIR_III_2': 'DA.P.',
#  'LIG_BIR_III_3': '^M{0,1}A.[AP].',
#  'LIG_BIR_III_4': 'DA.G.',
#  'LIG_BRCT_BRCA1_1': '.(S)..F',
#  'LIG_BRCT_BRCA1_2': '.(S)..F.K',
#  'LIG_BRCT_MDC1_1': '.(S)..Y$',
#  'LIG_CaM_IQ_9': '[ACLIVTM][^P][^P][ILVMFCT]Q[^P][^P][^P][RK][^P]{4,5}[RKQ][^P][^P]',
#  'LIG_CaMK_CASK_1': '[STED].{0,2}[IV]W[IVLM].[RHK]',
#  'LIG_CaM_NSCaTE_8': 'W[^P][^P][^P][IL][^P][AGS][AT]',
#  'LIG_CAP-Gly_1': '[ED].{0,2}[ED].{0,2}[EDQ].{0,1}[YF]$',
#  'LIG_CAP-Gly_2': '.W[RK][DE]GCY$',
#  'LIG_Clathr_ClatBox_1': 'L[IVLMF].[IVLMF][DE]',
#  'LIG_Clathr_ClatBox_2': '.[NP]W[DES].W',
#  'LIG_CNOT1_NIM_1': '[FY][^P].[WFY][^P]DY..L',
#  'LIG_CORNRBOX': 'L[^P]{2,2}[HI]I[^P]{2,2}[IAV][IL]',
#  'LIG_CSK_EPIYA_1': 'EP[IL]Y[TAG]',
#  'LIG_CSL_BTD_1': '[AFILMPTVW]W[FHILMPSTVW]P',
#  'LIG_CtBP_PxDLS_1': '(P[LVIPME][DENS][LM][VASTRG])|(G[LVIPME][DENS][LM][VASTRG]((K)|(.[KR])))',
#  'LIG_CtBP_RRT_2': '[RG]RT[GSAT].PP..',
#  'LIG_DCNL_PONY_1': '^M[MIL].[MIL]',
#  'LIG_deltaCOP1_diTrp_1': '[DE]{1,3}.{0,2}W.{1,6}[WF]',
#  'LIG_DLG_GKlike_1': '(R..(S)[YFLM][^P][^P][L])|(R..(S)[YFLM][^P][^P][ASG][LMVIQT])',
#  'LIG_Dynein_DLC8_1': '[^P].[KR].TQT',
#  'LIG_EABR_CEP55_1': '.A.GPP.{2,3}Y.',
#  'LIG_EF_ALG2_ABM_1': 'P[PG]{0,1}YP.{1,6}Y[QS]{0,1}P',
#  'LIG_EF_ALG2_ABM_2': 'P.P.{0,1}GF',
#  'LIG_EH_1': '.NPF.',
#  'LIG_EH1_1': '.[FYH].[IVM][^WFYP][^WFYP][ILM][ILMV].',
#  'LIG_eIF4E_1': 'Y....L[VILMF]',
#  'LIG_eIF4E_2': 'Y.PP.[ILMV]R',
#  'LIG_EVH1_1': '([FYWL]P.PP)|([FYWL]PP[ALIVTFY]P)',
#  'LIG_EVH1_2': 'PP..F',
#  'LIG_EVH1_3': '[FY].[FW].....[LMVIF]P.P[DE]',
#  'LIG_FAT_LD_1': '[LV][DE][^P][LM][LM][^P][^P]L[^P]',
#  'LIG_FERM_MyoX_1': 'L...M[^P][^P]L[^P][^P]LM[^P][QD]L[^P][^P]I[TA]',
#  'LIG_FHA_1': '..(T)..[ILV].',
#  'LIG_FHA_2': '..(T)..[DE].',
#  'LIG_FXI_DFP_1': '[FYWHIL].DF[PD]',
#  'LIG_FZD_DVL_PDZ': 'W.{0,1}[VIL].[ST].KA{0,1}T...W',
#  'LIG_G3BP_FGDF_1': '[FYLIMV].FG[DES]F',
#  'LIG_GBD_Chelix_1': '[ILV][VA][^P][^P][LI][^P][^P][^P][LM]',
#  'LIG_GLEBS_BUB3_1': '[EN][FYLW][NSQ].EE[ILMVF][^P][LIVMFA]',
#  'LIG_GSK3_LRP6_1': '(([CP]PP)|(PP[TP]))[ST]P[^P][TS]{0,1}',
#  'LIG_GYF': '[QHR].{0,1}P[PL]PP[GS]H[RH]',
#  'LIG_HCF-1_HBM_1': '[DE]H.Y',
#  'LIG_HOMEOBOX': '[FY][DEP]WM',
#  'LIG_HP1_1': 'P[MVLIRWY]V[MVLIAS][LM]',
#  'LIG_IBAR_NPY_1': 'NPY',
#  'LIG_Integrin_collagen_1': 'G[FLMR](P)GE[RKNA]',
#  'LIG_Integrin_isoDGR_2': 'NGR',
#  'LIG_Integrin_KxxGD_FGGC_5': 'K.[AV]GD.$',
#  'LIG_Integrin_RGD_1': 'RGD',
#  'LIG_Integrin_RGDSP_6': 'RGDSP{0,1}',
#  'LIG_Integrin_RGD_TGFB_3': 'RGDL[^P][^P][LI]',
#  'LIG_Integrin_RGDW_4': '[RK]GDW',
#  'LIG_IRF7_LxLS_2': '[VILPFYM].{1,3}L.L(S)',
#  'LIG_IRFs_LxIS_1': '[VILPFYM].{1,3}L.I(S)',
#  'LIG_KEPE_1': '[VILMFT]K.EP.[DE]',
#  'LIG_KEPE_2': '[VILMFT]K.EP.{2,3}[DE]',
#  'LIG_KEPE_3': '[VILMFT]K.EP....[DE]',
#  'LIG_KLC1_WD_1': '[LMTAFSRI][^KRG]W[DE].{3,5}[LIVMFPA]',
#  'LIG_KLC1_Yacidic_2': '[ED].{0,1}[IYVLMTF]Y[LIV][DE]',
#  'LIG_LEDGF_IBM_1': '[LFVIM].{2,3}[LIVCYFM][FW].{3,35}[EDST].{0,1}[EDST].{0,1}F[^G]GF',
#  'LIG_LIR_Apic_2': '[EDST].{0,2}[WFY]..P',
#  'LIG_LIR_Gen_1': '[EDST].{0,2}[WFY][^RKPGWFY][^PG][ILVFM]((.{0,4}[PLAFIVMY])|($)|(.{0,3}[ED]))',
#  'LIG_LIR_LC3C_4': '[EDST].{0,2}LVV',
#  'LIG_LIR_Nem_3': '[EDST].{0,2}[WFY]..[ILVFY]',
#  'LIG_LRP6_Inhibitor_1': '([VILA]..N.I[RK])|([VILA].PN.IG.{0,6}[RK])',
#  'LIG_LSD1_SNAG_1': '^M{0,1}PR.FLV[KR]K{0,1}.',
#  'LIG_LYPXL_L_2': '[ILVM]YP...[ILVM][^P][^P][LI]',
#  'LIG_LYPXL_S_1': '[ILVMF]YP.[ILVMF]',
#  'LIG_LYPXL_SIV_4': '[PA]Y..[AV][^P]{3}L',
#  'LIG_LYPXL_yS_3': 'YP.[ILVM]',
#  'LIG_MAD2': '[KR][IV][LV].....P',
#  'LIG_Menin_MBM1_1': '...[RK][^DE]{0,2}FP[GA][^DE]P',
#  'LIG_MLH1_MIPbox_1': '.S.[FY][F]',
#  'LIG_MSH2_SHIPbox_1': '[LIVMFWYTA].{2,3}[LI][^P]{2,3}[FY].[FYW]',
#  'LIG_MTR4_AIM_1': '[FYW][^P][VILTM]D.(([^P][GPAS])|G)',
#  'LIG_Mtr4_Air2_1': 'GRYFG',
#  'LIG_Mtr4_Trf4_1': '[LFVAIMW].{3,5}[DE][FY][IL][SAPGK][FL].{3,6}[DE]{3}',
#  'LIG_Mtr4_Trf4_2': 'Q[RGQ]DF[LI][PS]L[DE]',
#  'LIG_MYND_1': 'P.L.P',
#  'LIG_MYND_2': 'PP.LI',
#  'LIG_MYND_3': '[LMV]P.LE',
#  'LIG_NBox_RRM_1': 'F..A[ILV]..A..[ILV]',
#  'LIG_NRBOX': '[^P]L[^P][^P]LL[^P]',
#  'LIG_Nrd1CID_NIM_1': '[ED].{0,3}[DN][DEGPA]Y.[PL]..',
#  'LIG_NRP_CendR_1': '[RK].{0,2}R$',
#  'LIG_OCRL_FandH_1': '.F[^P][^P][KRIL]H[^P][^P][YLMFH][^P]...',
#  'LIG_PALB2_WD40_1': '....WF..L',
#  'LIG_PAM2_1': '..[LFP][NS][PIVTAFL].A..(([FY].[PYLF])|(W..)).',
#  'LIG_PAM2_2': '((WPP)|([FL][PV][APQ]))EF.PG.PWKG.',
#  'LIG_PCNA_APIM_2': '[MLIV].[KR][FY][MLIVF][LIV][KR]',
#  'LIG_PCNA_PIPBox_1': '[QM].[^FHWY][LIVM][^P][^PFWYMLIV](([FYHL][FYW])|([FYH][FYWL]))..',
#  'LIG_PCNA_TLS_4': '[KR]..[ILM](([DE][^P][FY][FLI])|([G][^P][FY][FLI].{0,1}[KR]))',
#  'LIG_PCNA_yPIPBox_3': '([KR].{0,6}[QN].[^FHWY][LIVM][^P][^PFWYMLIV][FYLMWV][FYLMWVI])|([QN].[^FHWY][LIVM][^P][^PFWYMLIV][FYLMWV][FYLMWVI].{0,6}[KR])',
#  'LIG_PDZ_Class_1': '...[ST].[ACVILF]$',
#  'LIG_PDZ_Class_2': '...[VLIFY].[ACVILF]$',
#  'LIG_PDZ_Class_3': '...[DE].[ACVILF]$',
#  'LIG_PDZ_Wminus1_1': '.W[ACGILV]$',
#  'LIG_Pex14_1': 'W...[FY]',
#  'LIG_Pex14_2': 'F...[WF]',
#  'LIG_Pex14_3': 'LV.EF[LM]',
#  'LIG_Pex14_4': 'MM[NDE][EDNAG]F[LMA]',
#  'LIG_Pex3_1': 'L..LL...L..F',
#  'LIG_PROFILIN_1': 'PPP[PA]P((P[LGP])|([LG]P))',
#  'LIG_PTAP_UEV_1': '.P[TS]AP.',
#  'LIG_PTB_Apo_2': '(.[^P].NP.[FY].)|(.[ILVMFY].N..[FY].)',
#  'LIG_PTB_Phospho_1': '(.[^P].NP.(Y))|(.[ILVMFY].N..(Y))',
#  'LIG_RBL1_LxSxE_2': '[DE].{0,4}L.S.E.[MLIVAYFWP].{2,4}(S)',
#  'LIG_RB_LxCxE_1': '([DEST]|^).{0,4}[LI].C.E.{1,4}[FLMIVAWPHY].{0,8}([DEST]|$)',
#  'LIG_RB_pABgroove_1': '..[LIMVA].[DE][LMF][FYM][IL]{0,1}([DE]|(S)).',
#  'LIG_REV1ctd_RIR_1': '..FF[^P]{0,2}[KR]{1,2}[^P]{0,4}',
#  'LIG_RPA_C_Fungi': '[^P][MIALVF][^P][^P][NSHRA]R[^P][^P][ASV][^P][^P][RKLIA][RQLIVA]',
#  'LIG_RPA_C_Insects': '[^P][MIAL][^P][^P][NKS][KRLQH][^P][^P]A[^P][^P][RKLI][RKL][^P][^P][KR]',
#  'LIG_RPA_C_Plants': 'R[MIVAS][^P][^P][NQ][KRL][^P][^P]A[^P][^P][RK]',
#  'LIG_RPA_C_Vert': '[KRS]I[^P][^P][NK][KR][^P][^P]A[^P][^P][RKL][RKL][^P][^P][RK]',
#  'LIG_RRM_PRI_1': '.[ILVM]LG..P.',
#  'LIG_Rrp6Rrp47_Mtr4_1': '[ED]LF[^P][VC]F.{0,1}[ED]',
#  'LIG_RuBisCO_WRxxL_1': '[ILVATSRK][^EDN].[NDS]W[RK][^P][^P][LIVAPS]',
#  'LIG_SH2_CRK': '(Y)[^EPILVFYW][^HDEW][PLIV][^DEW]',
#  'LIG_SH2_GRB2like': '(Y)([EDST]|[MLIVAFYHQW])N.',
#  'LIG_SH2_NCK_1': '([^KR][^KR](Y)[DE][^GWFY][AI][SDENQTAGYFP])|([^KR][^KR](Y)[STNA][^GWFY][PV][SDENQTAGYFP])|(..Y[DE][^GWFY][PV][SDENQTAGYFP])',
#  'LIG_SH2_PTP2': '(Y)[IV].[VILP]',
#  'LIG_SH2_SFK_2': '[^KR][^KR](Y)([DEVYI][^KRH][ILVF]|[DEVYI][^KRH][AQPMCW]|[NQSTAFL][^KRH][ILVF])((.{0,3}[DE])|.|$)',
#  'LIG_SH2_SFK_CTail_3': '((Y)QPG[ED])|((Y)Q.QP$)',
#  'LIG_SH2_STAP1': '(Y)[DESTA][^GP][^GP][ILVFMWYA]',
#  'LIG_SH2_STAT3': '(Y)..Q',
#  'LIG_SH2_STAT5': '(Y)[VLTFIC]..',
#  'LIG_SH2_STAT6': 'G(Y)[KQ].F',
#  'LIG_SH3_1': '[RKY]..P..P',
#  'LIG_SH3_2': 'P..P.[KR]',
#  'LIG_SH3_3': '...[PV]..P',
#  'LIG_SH3_4': 'KP..[QK]...',
#  'LIG_SH3_CIN85_PxpxPR_1': 'P.[AP].PR',
#  'LIG_SH3_PxRPPK_7': '[PAVL]P[PEQA][RL]PPK[^DE]',
#  'LIG_SH3_PxxDY_5': 'P..DY',
#  'LIG_SH3_PxxPPRxxK_8': '[PAVLI]P.[LVI]PP[RK][^P][^P][KR]',
#  'LIG_SH3_PxxxRxxKP_6': 'P.[VIF][DNH]R[^P][^P]KP',
#  'LIG_Sin3_1': '[LIV]..[LM]L.AA.[FY][LI]',
#  'LIG_Sin3_2': '[FHYM].A[AV].[VAC]L[MV].[MI]',
#  'LIG_Sin3_3': '[FA].[LA][LV][LVI]..[AM]',
#  'LIG_SPRY_1': '[ED][LIV]NNN[^P]',
#  'LIG_SUFU_1': '[SV][CY]GH[LIF][LAST][GAIV].',
#  'LIG_SUMO_SIM_anti_2': '[DEST]{1,10}.{0,1}[VIL][DESTVILMA][VIL][VILM].[DEST]{0,5}',
#  'LIG_SUMO_SIM_par_1': '[DEST]{0,5}.[VILPTM][VIL][DESTVILMA][VIL].{0,1}[DEST]{1,10}',
#  'LIG_SxIP_EBH_1': '([KR][^ED]{0,5}[ST].IP[^ED]{5,5})|([^ED]{5,5}[ST].IP[^ED]{0,5}[KR])',
#  'LIG_TPR': 'EEVD$',
#  'LIG_TRAF2like_MATH_loPxQ_2': '[PM][LIVTFYHQE][QS].(([DE].)|(.[DE]))',
#  'LIG_TRAF2like_MATH_shPxQ_1': 'P[LIVTFYHQE]Q[DET]',
#  'LIG_TRAF3_MATH_PxP_3': 'P[ILVT]P(([ED][^P].)|(.[^P][ED]))',
#  'LIG_TRAF4_MATH_1': 'RL[^P].R',
#  'LIG_TRAF6_MATH_1': '..P[^P]E[^P].[FYWHDE].',
#  'LIG_Trf4_IWRxY_1': '[IVL]WR.Y',
#  'LIG_TRFH_1': '[FY].L.P',
#  'LIG_TYR_ITAM': '[DEN]..(Y)..[LI].{6,12}(Y)..[LI]',
#  'LIG_TYR_ITIM': '[ILV].(Y)..[ILV]',
#  'LIG_TYR_ITSM': '..T.(Y)..[IV]',
#  'LIG_UBA3_1': '[ILM][ILMF].{1,2}[ILM].{0,4}K',
#  'LIG_UFM1_UFIM_1': '[ND].WGI.[LIV][VMLI].{0,1}[ED]',
#  'LIG_ULM_U2AF65_1': '[KR]{1,4}[KR].[KR]W.',
#  'LIG_VCP_SHPBox_1': '.((F.)|(W))G.G[^P].L.',
#  'LIG_VCP_VBM_3': '[ILMV]R[^PG]{2}R[^PG]{3}[FL][ED]',
#  'LIG_VCP_VIM_2': '[RKQ][^P]{1,3}[AG][^P]AA[^P]{1,2}R[^P]',
#  'LIG_Vh1_VBS_1': '[VMILF][MILVFYHPA][^P][TASKHCV][AVSC][^P][^P][ILVMT][^P][^P][^P][LMTVI][^P][^P][LMVCT][ILVMCA][^P][^P][AIVLMTC]',
#  'LIG_WD40_WDR5_VDV_1': '[ED].{0,3}[VIL]D[VI]',
#  'LIG_WD40_WDR5_VDV_2': '[EDSTY].{0,4}[VIPLA][TSDEKR][ILVA]',
#  'LIG_WD40_WDR5_WIN_1': '[SCA]AR[STCA][EQR][PGILVM][HYFQNKRLVI]',
#  'LIG_WD40_WDR5_WIN_2': '[STCA][CSAGV]R[STCAV][EQR][PGALV][LFYHRK]',
#  'LIG_WD40_WDR5_WIN_3': '[SCA][AFWHSV][KR][TAS][DEQR][GP][RKYFWIVAM]..[IVM]',
#  'LIG_WH1': 'ES[RK][FY].F[HR][PST][IVLM][DES][DE]',
#  'LIG_WRC_WIRS_1': '[FYILMV].[TS]F(G|[^P]).',
#  'LIG_WRPW_1': '[WFY]RP[WFY].{0,7}$',
#  'LIG_WRPW_2': '[WFY][KR]P[WFY]',
#  'LIG_WW_1': 'PP.Y',
#  'LIG_WW_2': 'PPLP',
#  'LIG_WW_3': '.PPR.',
#  'MOD_AAK1BIKe_LxxQxTG_1': '[LIVM][^D][^DEHYWF]Q.(T)G',
#  'MOD_ASX_betaOH_EGF': 'C.([DN]).{4,4}[FY].C.C',
#  'MOD_CAAXbox': '(C)[^DENQ][LIVMF].$',
#  'MOD_CDC14_SPxK_1': '(S)P.[KR]',
#  'MOD_CDK_SPK_2': '...([ST])P[RK]',
#  'MOD_CDK_SPxK_1': '...([ST])P.[KR]',
#  'MOD_CDK_SPxxK_3': '...([ST])P..[RK]',
#  'MOD_CK1_1': 'S..([ST])...',
#  'MOD_CK2_1': '...([ST])..E',
#  'MOD_CMANNOS': '(W)..W',
#  'MOD_Cter_Amidation': '(.)G[RK][RK]',
#  'MOD_DYRK1A_RPxSP_1': 'R[PSVA].([ST])P',
#  'MOD_GlcNHglycan': '[ED]{0,3}.(S)[GA].',
#  'MOD_GSK3_1': '...([ST])...[ST]',
#  'MOD_LATS_1': 'H.[KR]..([ST])[^P]',
#  'MOD_LOK_YxT_1': '[KR][YF][^IVEDPGAC](T)[LMIVWFY][RKH]',
#  'MOD_NEK2_1': '[FLM][^PVIED][^PVID]([ST])[MLIVF][RKH].',
#  'MOD_NEK2_2': '[FLMW][^P][^P]([ST])[^PDEGAN][RKH].',
#  'MOD_N-GLC_1': '.(N)[^P][ST]..',
#  'MOD_N-GLC_2': '(N)[^P]C',
#  'MOD_NMyristoyl': '^M{0,1}(G)[^EDRKHPFYW]..[STAGCN][^P]',
#  'MOD_OFUCOSY': 'C.{3,5}([ST])C',
#  'MOD_OGLYCOS': 'C.(S).PC',
#  'MOD_PIKK_1': '...([ST])Q..',
#  'MOD_PK_1': '[RK]..(S)[VI]..',
#  'MOD_PKA_1': '[RK][RK].([ST])[^P]..',
#  'MOD_PKA_2': '.R.([ST])[^P]..',
#  'MOD_PKB_1': 'R.R..([ST])[^P]..',
#  'MOD_Plk_1': '.[DNE][^PG][ST](([FYILMVW]..)|([^PEDGKN][FWYLIVM]).)',
#  'MOD_Plk_2-3': '[DE]..([ST])[EDILMVFWY](([DE].)|(.[DE]))',
#  'MOD_Plk_4': '..[^IRFW]([ST])[ILMVFWY][ILMVFWY].',
#  'MOD_PRMT_GGRGG_1': 'GGRGG',
#  'MOD_ProDKin_1': '...([ST])P..',
#  'MOD_SPalmitoyl_2': 'G(C)M[GS][CL][KP]C',
#  'MOD_SPalmitoyl_4': '^M{0,1}G(C)..S[AKS]',
#  'MOD_SUMO_for_1': '[VILMAFP](K).E',
#  'MOD_SUMO_rev_2': '[SDE].{0,5}[DE].(K).{0,1}[AIFLMPSTV]',
#  'MOD_TYR_CSK': '[TAD][EA].Q(Y)[QE].[GQA][PEDLS]',
#  'MOD_TYR_DYR': '..[RKTC][IVL]Y[TQHS](Y)[IL]QSR',
#  'MOD_WntLipid': '[ETA](C)[QERK]..F...RWNC[ST]',
#  'TRG_AP2beta_CARGO_1': '[DE].{1,2}F[^P][^P][FL][^P][^P][^P]R',
#  'TRG_Cilium_Arf4_1': 'QV.P.$',
#  'TRG_Cilium_RVxP_2': 'RV.P.',
#  'TRG_DiLeu_BaEn_1': 'E..[^P]L[LIVM]',
#  'TRG_DiLeu_BaEn_2': '[^E]E...F[LIVM]',
#  'TRG_DiLeu_BaEn_3': 'EE...[FIM][LIVM]',
#  'TRG_DiLeu_BaEn_4': 'EE...L[^LIVMF]',
#  'TRG_DiLeu_BaLyEn_6': '[^E]..[RP]L[LI]',
#  'TRG_DiLeu_LyEn_5': '[E]..[RP]L[LI]',
#  'TRG_ENDOCYTIC_2': 'Y..[LMVIF]',
#  'TRG_ER_diArg_1': '([LIVMFYWPR]R[^YFWDE]{0,1}R)|(R[^YFWDE]{0,1}R[LIVMFYWPR])',
#  'TRG_ER_diLys_1': 'K.{0,1}K.{2,3}$',
#  'TRG_ER_FFAT_1': '[EDS].{0,4}[ED][FY][FYKREM][DE][AC].{1,2}[EDST]',
#  'TRG_ER_FFAT_2': '[EDS].{0,4}[EDSQN][FY][FYMITH]([ST])[ACP].{1,2}[EDST]',
#  'TRG_ER_KDEL_1': '[KRHQSAP][DENQT]EL$',
#  'TRG_Golgi_diPhe_1': 'Q.{6,6}FF.{6,7}$',
#  'TRG_LysEnd_GGAAcLL_1': 'D..LL.{1,2}$',
#  'TRG_LysEnd_GGAAcLL_2': 'S[LW]LD[DE]EL[LM]',
#  'TRG_NES_CRM1_1': '([DEQ].{0,1}[LIM].{2,3}[LIVMF][^P]{2,3}[LMVF].[LMIV].{0,3}[DE])|([DE].{0,1}[LIM].{2,3}[LIVMF][^P]{2,3}[LMVF].[LMIV].{0,3}[DEQ])',
#  'TRG_NESrev_CRM1_2': '[FLIM].[VLIMF]..[FLIMVY][^P][^P][^P][LVIM][^P][^P][LVIMA]',
#  'TRG_NLS_Bipartite_1': '[KR][KR].{7,15}[^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]',
#  'TRG_NLS_MonoCore_2': '[^DE]((K[RK])|(RK))[KRP][KR][^DE]',
#  'TRG_NLS_MonoExtC_3': '[^DE]((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))(([PKR])|([^DE][DE]))',
#  'TRG_NLS_MonoExtN_4': '(([PKR].{0,1}[^DE])|([PKR]))((K[RK])|(RK))(([^DE][KR])|([KR][^DE]))[^DE]',
#  'TRG_Oom_RxLR_1': '((R)|(K.)).LR',
#  'TRG_Pf-PMV_PEXEL_1': '(R.[LI].[EDQ])|(R.L..[EDQ])|(K.L.E)',
#  'TRG_PTS1': '(.[SAPTC][KRH][LMFI]$)|([KRH][SAPTC][NTS][LMFI]$)',
#  'TRG_PTS2': '^.{1,40}R[^P][^P][^P][LIV][^P][^P][HQ][LIF]'}

# %%
# Extract ProSite patterns (PA lines only)
prosite_patterns = []
with open(prosite_file, "r") as file:
    for record in Prosite.parse(file):
        if record.type == 'PATTERN':
            prosite_patterns.append((record.name,
                                     record.accession,
                                     record.description,
                                     record.pattern,
                                     record.nr_sp_seqs))
prosite_pd = pd.DataFrame(prosite_patterns, columns=['Name', 'Accession', 'Description', 'Pattern', 'Instances_sprot'])
prosite_pd
# Out:
#                     Name Accession  \
# 0      ASN_GLYCOSYLATION   PS00001
# 1      CAMP_PHOSPHO_SITE   PS00004
# 2       PKC_PHOSPHO_SITE   PS00005
# 3       CK2_PHOSPHO_SITE   PS00006
# 4     TYR_PHOSPHO_SITE_1   PS00007
# ...                  ...       ...
# 1306    SCORPION_CALCINE   PS60028
# 1307         SPIDER_CSTX   PS60029
# 1308     BACTERIOCIN_IIA   PS60030
# 1309               GARP2   PS60031
# 1310               GH9_1   PS60032
#
#                                             Description  \
# 0                                 N-glycosylation site.
# 1     cAMP- and cGMP-dependent protein kinase phosph...
# 2                Protein kinase C phosphorylation site.
# 3                Casein kinase II phosphorylation site.
# 4               Tyrosine kinase phosphorylation site 1.
# ...                                                 ...
# 1306                 Scorpion calcine family signature.
# 1307                Spider toxin CSTX family signature.
# 1308            Bacteriocin class IIa family signature.
# 1309    Glutamic acid-rich protein 2 (GARP2) signature.
# 1310  Glycosyl hydrolases family 9 (GH9) active site...
#
#                                                 Pattern Instances_sprot
# 0                                       N-{P}-[ST]-{P}.
# 1                                       [RK](2)-x-[ST].
# 2                                          [ST]-x-[RK].
# 3                                       [ST]-x(2)-[DE].
# 4                                [RK]-x(2)-[DE]-x(3)-Y.
# ...                                                 ...             ...
# 1306                 C-x(6)-C-x(5)-C-C-x(3)-C-x(9)-R-C.
# 1307              C-{C}(6)-C-{C}(6)-C-C-{C}(8)-C-{C}-C.
# 1308                           Y-G-N-G-[VL]-x-C-x(4)-C.
# 1309           C-D-V-Q-T-R-[VAE]-[MVT]-[GA]-A-G-[GS]-L.
# 1310  [LVS]-x-[GK]-G-[WFYLM]-[YHF]-D-[ACGS]-G-[DSN]-...
#
# [1311 rows x 5 columns]

# %%
# Convert ProSIte Pattern to Regex
def prosite_to_re(pattern):
    """Convert a valid Prosite pattern into a regex string"""
    _prosite_trans = str.maketrans("abcdefghijklmnopqrstuvwxyzX}()<>",
                                  "ABCDEFGHIJKLMNOPQRSTUVW.YZ.]{}^$")
    flg = (pattern[:2] == "[<")
    s = pattern.replace("{", "[^")
    s = s.replace(".", "")
    s = s.replace("-", "")
    s = s.translate(_prosite_trans)
    # special case "[<" and ">]", if they exist
    if flg:
        i = s.index("]")
        s = "(?:^|[" + s[2:i] + "])" + s[i+1:]
    if s[-2:] == "$]":
        i = s.rindex("[")
        s = s[:i] + "(?:" + s[i:-2] + "]|$)"
    elif s[-3:] == "$]$":
        i = s.rindex("[")
        s = s[:i] + "(?:" + s[i:-3] + "]|$)$"
    return s

# %%
prosite_pd['Regex'] = prosite_pd["Pattern"].apply(prosite_to_re)
prosite_pd
# Out:
#                     Name Accession  \
# 0      ASN_GLYCOSYLATION   PS00001
# 1      CAMP_PHOSPHO_SITE   PS00004
# 2       PKC_PHOSPHO_SITE   PS00005
# 3       CK2_PHOSPHO_SITE   PS00006
# 4     TYR_PHOSPHO_SITE_1   PS00007
# ...                  ...       ...
# 1306    SCORPION_CALCINE   PS60028
# 1307         SPIDER_CSTX   PS60029
# 1308     BACTERIOCIN_IIA   PS60030
# 1309               GARP2   PS60031
# 1310               GH9_1   PS60032
#
#                                             Description  \
# 0                                 N-glycosylation site.
# 1     cAMP- and cGMP-dependent protein kinase phosph...
# 2                Protein kinase C phosphorylation site.
# 3                Casein kinase II phosphorylation site.
# 4               Tyrosine kinase phosphorylation site 1.
# ...                                                 ...
# 1306                 Scorpion calcine family signature.
# 1307                Spider toxin CSTX family signature.
# 1308            Bacteriocin class IIa family signature.
# 1309    Glutamic acid-rich protein 2 (GARP2) signature.
# 1310  Glycosyl hydrolases family 9 (GH9) active site...
#
#                                                 Pattern Instances_sprot  \
# 0                                       N-{P}-[ST]-{P}.
# 1                                       [RK](2)-x-[ST].
# 2                                          [ST]-x-[RK].
# 3                                       [ST]-x(2)-[DE].
# 4                                [RK]-x(2)-[DE]-x(3)-Y.
# ...                                                 ...             ...
# 1306                 C-x(6)-C-x(5)-C-C-x(3)-C-x(9)-R-C.
# 1307              C-{C}(6)-C-{C}(6)-C-C-{C}(8)-C-{C}-C.
# 1308                           Y-G-N-G-[VL]-x-C-x(4)-C.
# 1309           C-D-V-Q-T-R-[VAE]-[MVT]-[GA]-A-G-[GS]-L.
# 1310  [LVS]-x-[GK]-G-[WFYLM]-[YHF]-D-[ACGS]-G-[DSN]-...
#
#                                                   Regex
# 0                                         N[^P][ST][^P]
# 1                                          [RK]{2}.[ST]
# 2                                             [ST].[RK]
# 3                                          [ST].{2}[DE]
# 4                                     [RK].{2}[DE].{3}Y
# ...                                                 ...
# 1306                            C.{6}C.{5}CC.{3}C.{9}RC
# 1307                    C[^C]{6}C[^C]{6}CC[^C]{8}C[^C]C
# 1308                                    YGNG[VL].C.{4}C
# 1309                        CDVQTR[VAE][MVT][GA]AG[GS]L
# 1310  [LVS].[GK]G[WFYLM][YHF]D[ACGS]G[DSN].{2}[KMR][...
#
# [1311 rows x 6 columns]

# %%
prosite_patterns = dict(zip(prosite_pd["Name"], prosite_pd["Regex"]))
prosite_patterns
# Out:
# {'ASN_GLYCOSYLATION': 'N[^P][ST][^P]',
#  'CAMP_PHOSPHO_SITE': '[RK]{2}.[ST]',
#  'PKC_PHOSPHO_SITE': '[ST].[RK]',
#  'CK2_PHOSPHO_SITE': '[ST].{2}[DE]',
#  'TYR_PHOSPHO_SITE_1': '[RK].{2}[DE].{3}Y',
#  'MYRISTYL': 'G[^EDRKHPFYW].{2}[STAGCN][^P]',
#  'AMIDATION': '.G[RK][RK]',
#  'ASX_HYDROXYL': 'C.[DN].{4}[FY].C.C',
#  'GLA_1': 'E.{2}[ERK]E.C.{6}[EDR].{10,11}[FYA][YW]',
#  'PHOSPHOPANTETHEINE': '[DEQGSTALMKRH][LIVMFYSTAC][GNQ][LIVMFYAG][DNEKHS]S[LIVMST][^PCFY][STAGCPQLIVMF][LIVMATN][DENQGTAKRHLM][LIVMWSTA][LIVGSTACR][^LPIY][^VY][LIVMFA]',
#  'ER_TARGET': '[KRHQSA][DENQ]EL$',
#  'RGD': 'RGD',
#  'ATP_GTP_A': '[AG].{4}GK[ST]',
#  'EF_HAND_1': 'D[^W][DNS][^ILVFYW][DENSTG][DNQGHRK][^GP][LIVMC][DENQSTAGC].{2}[DE][LIVMFYW]',
#  'ACTININ_1': '[EQ][^LNYH].[ATV][FY][^LDAM][^T]W[^PG]N',
#  'ACTININ_2': '[LIVM].[SGNL][LIVMN][DAGHENRS][SAGPNVT].[DNEAG][LIVM].[DEAGQ].{4}[LIVM].[LM][SAG][LIVM][LIVMT][WS].{0,1}[LIVM]{2}',
#  'KRINGLE_1': '[FY]C[RH][NS].{7,8}[WY]C',
#  'EGF_1': 'C.C.{2}[^V].{2}G[^C].C',
#  'FN2_1': 'C.{2}PF.[FYWIV].{7}C.{8,10}WC.{4}[DNSR][FYW].{3,5}[FYW].[FYWI]C',
#  'HEMOPEXIN': '[LIFAT][^IL].{2}W.{2,3}[PE].[^VF][LIVMFY][DENQS][STA][AV][LIVMFY]',
#  'P_TREFOIL_1': '[KRH].{2}C.[FYPSTV].{3,4}[ST].{3}C.{4}CC[FYWH]',
#  'CHIT_BIND_I_1': 'C.{4,5}CCS.{2}G.CG.{3,4}[FYW]C',
#  'HOMEOBOX_1': '[LIVMFYG][ASLVR].{2}[LIVMSTACN].[LIVM][^Y].{2}[^L][LIV][RKNQESTAIY][LIVFSTNKH]W[FYVC].[NDQTAH].{5}[RKNAIMW]',
#  'ZINC_FINGER_C2H2_1': 'C.{2,4}C.{3}[LIVMFYWC].{8}H.{3,5}H',
#  'LEUCINE_ZIPPER': 'L.{6}L.{6}L.{6}L',
#  'NUCLEAR_REC_DBD_1': 'C.{2}C.{1,2}[DENAVSPHKQT].{5,6}[HNY][FY].{4}C.{2}C.{2}F{2}.R',
#  'ANTENNAPEDIA': '[LIVMFE][FY]PWM[KRQTA]',
#  'ENGRAILED': 'LMA[EQ]GLYN',
#  'PAIRED_1': 'RPC.{11}CVS',
#  'POU_1': '[RKQ]R[LIM].[LF]G[LIVMFY].Q.[DNQ]VG',
#  'BZIP_BASIC': '[KR].{1,3}[RKSAQ]N[^VL].[SAQ]{2}[^L][RKTAENQ].R[^S][RK]',
#  'DEAD_ATP_HELICASE': '[LIVMF]{2}DEAD[RKEN].[LIVMFYGSTN]',
#  'HTH_ARAC_FAMILY_1': '[KRQ][LIVMA].{2}[GSTALIV][^FYWPGDN].{2}[LIVMSA].{4,9}[LIVMF].[^PLH][LIVMSTA][GSTACIL][^GPK][^F].[GANQRF][LIVMFY].{4,5}[LFY].{3}[FYIVA][^FYWHCM][^PGVI].{2}[GSADENQKR].[NSTAPKL][PARL]',
#  'HTH_CRP_1': '[LIVM][STAG][RHNWM].{2}[LIM][GA].[LIVMFYAS][LIVSC][GA].[STACN].{2}[MST].{1,2}[GSTN]R.[LIVMF].{2}[LIVMF]',
#  'HISTONE_LIKE': '[GSK]F.{2}[LIVMF].{4}[RKEQA].{2}[RST].{1,2}[GA].[KN]P.[TN]',
#  'HISTONE_H2A': '[AC]GL.FPV',
#  'HISTONE_H4': 'GAKRH',
#  'PROTAMINE_P1': '[AV]R[NFY]R.{2,3}[ST][^S]S[^NS]S',
#  'RIBOSOMAL_L14': '[GA][LIV]{3}.{9,10}[DNS]G.{4}[FY].{2}[NT].{2}V[LIV]',
#  'RIBOSOMAL_L23': '[RK]{2}[AM][IVFYT][IV][RKT]L[STANEQK].{7}[LIVMFT]',
#  'RIBOSOMAL_L39E': '[KRM][PTKS].{3}[LIVMFG].{2}[NHS].{3}R[DNHY]WR[RS]',
#  'RIBOSOMAL_S7': '[DENSK].[LIVMDET].{3}[LIVMFTA]{2}.{6}GK[KR].{5}[LIVMF][LIVMFC].{2}[STAC]',
#  'RIBOSOMAL_S8': '[GE].{2}[LIV]{2}[STY][ST][^A].G[LIVM]{2}.{4}[AG][KRHAYIL]',
#  'RIBOSOMAL_S11': '[LIVMFR].[GSTACQI][LIVMF].{1,2}[GSTALVM].{0,1}[GSN][LIVMFY].[LIVM].{4}[DEN].[TS][PS].[PA][STCHF][DN]',
#  'RIBOSOMAL_S12': '[RK].PNS[AR].R',
#  'RIBOSOMAL_S17': 'GD.[LIV].[LIVA].[QEK].[RK]P[LIV]S',
#  'RIBOSOMAL_S18': '[IVRLP][DYN][YLF].{2,3}[LIVMTPFS].{2}[LIVM].{2}[FYTS][LIVMT][STNQG][DERPN].{1,2}[GYAH][KCR][LIVM].{3}[RHG][LIVMASR]',
#  'DNA_MISMATCH_REPAIR_1': 'GFRGE[AG]L',
#  'ADH_ZINC': 'GHE.[^EL]G[^AP].{4}[GA].{2}[IVSAC]',
#  'ADH_IRON_2': '[GSW].[LIVTSACD][GH].{2}[GSAE][GSHYQ].[LIVTP][GAST][GAS].{3}[LIVMT].[HNS][GA].[GTAC]',
#  'ADH_SHORT': '[LIVSPADNK].{9}[^P].{2}Y[PSTAGNCV][STAGNQCIVM][STAGC]K[^PC][SAGFYR][LIVMSTAGD].[^K][LIVMFYW][^D].[^YR][LIVMFYWGAPTHQ][GSACQRHM]',
#  'ALDOKETO_REDUCTASE_2': '[LIVMFY].{8}[^L][KREQ][^K][LIVM]G[LIVM][SC]N[FY]',
#  'ALDOKETO_REDUCTASE_3': '[LIVM][PAIV][KR][ST][^EPQG][^RFI].{2}R[^SVAF].[GSTAEQK][NSL].[^LVRI][LIVMFA]',
#  'L_LDH': '[LIVMA]G[EQ]HG[DN][ST]',
#  'D_2_HYDROXYACID_DH_1': '[LIVMA][AG][IVT][LIVMFY][AG].G[NHKRQGSAC][LIV]G.{13,14}[LIVMFT][^A].[FYWCTH][DNSTK]',
#  'HMG_COA_REDUCTASE_1': '[RKH].[^Y][^I].[^I][^L]D.MG.N.[LIVMA]',
#  '3HCDH': '[DNES].{2}[GA]F[LIVMFYA].[NT]R.{3}[PA][LIVMFY][LIVMFYST].{5,6}[LIVMFYCT][LIVMFYEAH].{2}[GVE]',
#  'MDH': '[LIVM]T[TRKMN]LD.{2}R[STA].{3}[LIVMFY]',
#  'G6P_DEHYDROGENASE': 'DH[YF]LGK[EQK]',
#  'ALDEHYDE_DEHYDR_CYS': '[FYLVA].[^GVEP][^DILV]G[QE][^LPYG]C[LIVMGSTANC][AGCN][^HE][GSTADNEKR]',
#  'GAPDH': '[ASV]SC[NT]T[^S].[LIM]',
#  'ACYL_COA_DH_1': '[GAC][LIVM][ST]E.{2}[GSAN]G[ST]D.{2}[GSA]',
#  'ACYL_COA_DH_2': '[QDE].[^P]G[GS].G[LIVMFY].{2}[DEN].{4}[KR].{3}[DEN]',
#  'GLFV_DEHYDROGENASE': '[LIV].{2}GG[SAG]K.[GV].{3}[DNST][PL]',
#  'DHFR_1': '[LVAGC][LIF]G.{4}[LIVMF]PW.{4,5}[DE].{3}[FYIV].{3}[STIQ]',
#  'PYRIDINE_REDOX_1': 'GG.C[LIVA].{2}GC[LIVM]P',
#  'COX1_CUB': '[YWG][LIVFYWTA]{2}[VGS]H[LNP].V.{44,47}HH',
#  'COX2': 'V.H.{33,40}C.{3}C.{3}H.{2}M',
#  'MULTICOPPER_OXIDASE1': 'G.[FYW].[LIVMFYW].[CST].[^PR][^K].{2}[^S].[^LFH]G[LM].{3}[LIVMFYW]',
#  'MULTICOPPER_OXIDASE2': 'HCH.{3}H.{3}[AG][LM]',
#  'LIPOXYGENASE_2': '[LIVMACST]HP[LIVM].[KRQV][LIVMF]{2}.[AP]H',
#  'EXTRADIOL_DIOXYGENAS': '[GNTIV].H.{5,7}[LIVMF]Y.{2}[DENTA]P.[GP].{2,3}E',
#  'INTRADIOL_DIOXYGENAS': '[LIVMF].G.[LIVM].{4}[GS].{2}[LIVMA].{4}[LIVM][DE][LIVMFYC].{6}G.[FY]',
#  'CU2_MONOOXYGENASE_1': 'HHM.{2}F.C',
#  'CU2_MONOOXYGENASE_2': 'H.F.{4}HTH.{2}G',
#  'CYTOCHROME_P450': '[FW][SGNH].[GD][^F][RKHPT][^P]C[LIVMFAP][GAD]',
#  'SOD_CU_ZN_1': '[GA][IMFAT]H[LIVF]H[^S].[GP][SDG].[STAGDE]',
#  'SOD_MN': 'D.[WF]EH[STA][FY]{2}',
#  'RIBORED_LARGE': 'W.{2}[LIVF].{6,7}G[LIVM][FYRA][NH].{3}[STAQLIVM][ASC].{2}[PA]',
#  'NITROGENASE_1_2': '[STANQ][ET]C.{5}GD[DN][LIVMT].[STAGR][LIVMFYST]',
#  'THYMIDYLATE_SYNTHASE': 'R.{2}[LIVMT].{2,3}[FWY][QNYDI].{8,13}[LVESI].PC[HAVMLC].{3}[QMTLHD][FYWL].{0,1}[LV]',
#  'N6_MTASE': '[LIVMAC][LIVFYWA][^DYP][DN]PP[FYW]',
#  'N4_MTASE': '[LIVMF]TSPP[FY]',
#  'C5_MTASE_1': '[DENKS].[FLIV].{2}[GSTC].PC.[^V][FYWLIM]S',
#  'C5_MTASE_2': '[RKQGTF].{2}GN[SA][LIVF].[VIP].[LVMT].{3}[LIVM].{3}[LIVM]',
#  'SHMT': '[DEQHY][LIVMFYA].[GSTMVA][GSTAV][ST][STVM][HQ]K[STG][LFMI].[GAS][PGAC][RQ][GSARH][GA]',
#  'CARBAMOYLTRANSFERASE': 'F.[EK].S[GT]RT',
#  'THIOLASE_1': '[LIVM][NST][^T].C[SAGLI][ST][SAG][LIVMFYNS].[STAG][LIVM].{6}[LIVM]',
#  'THIOLASE_3': '[AG][LIVMA][STAGCLIVM][STAG][LIVMA]C[^Q][AG].[AG].[AG].[SAG]',
#  'CAT': 'Q[LIV]HH[SA].{2}DG[FY]H',
#  'HEXAPEP_TRANSFERASES': '[LIV][GAED].{2}[STAV].[LIV].{3}[LIVAC].[LIV][GAED].{2}[STAVR].[LIV][GAED].{2}[STAV].[LIV].{3}[LIV]',
#  'PHOSPHORYLASE': 'EA[SC]G.[GS].MK.{2}[LM]N',
#  'PUR_PYR_PR_TRANSFER': '[LIVMFYWCTA][LIVM][LIVMA][LIVMFC][DE]D[LIVMS][LIVM][STAVD][STAR][GAC].[STAR]',
#  'EPSP_SYNTHASE_1': '[LIVF][^LV].[GANQK][NLG][SA][GA][TAI][STAGV][^N]R.[LIVMFYAT].[GSTAP]',
#  'AA_TRANSFER_CLASS_1': '[GS][LIVMFYTAC][GSTA]K.{2}[GSALVN][LIVMFA].[GNAR][^V]R[LIVMA][GA]',
#  'GALACTOKINASE': 'GR.N[LIV]IG[DE]H.DY',
#  'PROTEIN_KINASE_ATP': '[LIV]G[^P]G[^P][FYWMGSTNH][SGA][^PW][LIVCAT][^PD].[GSTACLIVMFY].{5,18}[LIVMFYWCSTAR][AIVP][LIVMFAGCKR]K',
#  'PROTEIN_KINASE_ST': '[LIVMFYC].[HY].D[LIVMFY]K.{2}N[LIVMFYCT]{3}',
#  'PROTEIN_KINASE_TYR': '[LIVMFYC][^A][HY].D[LIVMFY][RSTAC][^D][^PF]N[LIVMFYC]{3}',
#  'PYRUVATE_KINASE': '[LIVAC].[LIVM]{2}[SAPCV]K[LIV]E[NKRST].[DEQHS][GSTA][LIVM]',
#  'PGLYCERATE_KINASE': '[KRHGTCVN][VT][LIVMF][LIVMC]R.D.N[SACV]P',
#  'PHOSPHAGEN_KINASE': 'CP.{0,1}[ST]N[ILV]GT',
#  'ADENYLATE_KINASE': '[LIVMFYWCA][LIVMFYW]{2}DG[FYI]PR.{3}[NQ]',
#  'PRPP_SYNTHASE': 'D[LIM]H[SANDT].[QS][IMSTAVF][QMLPH][GA][FY]F.{2}P[LIVMFCT]D',
#  'RNA_POL_II_REPEAT': 'Y[ST]P[ST]SP[STANK]',
#  'DNA_POLYMERASE_B': '[YA][GLIVMSTAC]DTD[SG][LIVMFTC][^LA][LIVMSTAC]',
#  'GAL_P_UDP_TRANSF_I': 'FEN[RK]G.{3}G.{4}HPH.Q',
#  'PA2_HIS': 'CC[^P].H[^LGY].C',
#  'PA2_ASP': '[LIVMA]C[^LIVMFYWPCST]CD[^GS][^G][^N].[^QS]C',
#  'LIPASE_SER': '[LIV][^KG][LIVFY][LIVMST]G[HYWV]S[^YAG]G[GSTAC]',
#  'COLIPASE_1': 'Y.{2}YY.C.C',
#  'CARBOXYLESTERASE_B_1': 'F[GR]G.{4}[LIVM].[LIV].G.S[STAG]G',
#  'ALKALINE_PHOSPHATASE': '[IV].DS[GAS][GASC][GAST][GA]T',
#  'FBPASE': '[AG][RK][LI].{1,2}[LIV][FY]E.{2}P[LIVM][GSA]',
#  'SER_THR_PHOSPHATASE': '[LIVMN][KR]GNHE',
#  'PDEASE_I_1': 'HD[LIVMFY].H.[AG].{2}[NQ].[LIVMFY]',
#  'RNASE_PANCREATIC': 'CK.{2}NTF',
#  'GLYCOSYL_HYDROL_F22_1': 'C.{3}C.{2}[LMF].{3}[DEN][LI].{5}C',
#  'GLYCOSYL_HYDROL_F31_1': '[GFY][LIVMF]W.DM[NSA]E',
#  'U_DNA_GLYCOSYLASE': '[KR][LIVA][LIVC][LIVM].G[QI]DPY',
#  'CARBOXYPEPT_SER_SER': '[LIVM].[GSTA]ESY[AG][GS]',
#  'CARBOXYPEPT_ZN_1': '[PK].[LIVMFY].[LIVMFY].{2}[^E].H[STAG].E.[LIVM][STAG][^L].{5}[LIVMFYTA]',
#  'CARBOXYPEPT_ZN_2': 'H[STAG][^ADNV][^VGFI][^YAR][LIVME][^SDEP].[LIVMFYW]P[FYW]',
#  'TRYPSIN_HIS': '[LIVM][ST]A[STAG]HC',
#  'TRYPSIN_SER': '[DNSTAGC][GSTAPIMVQH].{2}G[DE]SG[GS][SAPHV][LIVMFYWH][LIVMFYSTANQH]',
#  'SUBTILASE_ASP': '[STAIV][^ERDL][LIVMF][LIVM]D[DSTA]G[LIVMFC].{2,3}[DNH]',
#  'SUBTILASE_HIS': 'HG[STM].[VIC][STAGC][GS].[LIVMA][STAGCLV][SAGM]',
#  'SUBTILASE_SER': 'GTS.[SA].P.[^L][STAVC][AG]',
#  'THIOL_PROTEASE_CYS': 'Q[^V].[^DE][GE][^F]C[YW][^DN].[STAGC][STAGCV]',
#  'UCH_1': 'Q.{3}N[SA]CG.{3}[LIVM]{2}H[SA][LIVM][SA]',
#  'ASP_PROTEASE': '[LIVMFGAC][LIVMTADN][LIVFSA]D[ST]G[STAV][STAPDENQ][^GQ][LIVMFSTNC][^EGK][LIVMFGTA]',
#  'ZINC_PROTEASE': '[GSTALIVN][^PCHR][^KND]HE[LIVMFYW][^DEHRKP]H[^EKPC][LIVMFYWGSPQ]',
#  'INSULINASE': 'G.{8,9}G.[STA]H[LIVMFY][LIVMC][DERN][HRKL][LMFAT].[LFSTH].[GSTAN][GST]',
#  'ASN_GLN_ASE_1': '[LIVM].[^L]TGGT[IV][AGS]',
#  'UREASE_2': '[LIVM]{2}[CT]H[HNG]L.{3}[LIVM].{2}D[LIVM].F[AS]',
#  'BETA_LACTAMASE_A': '[FY].[LIVMFY][^E]S[TV].K.{3}[^T][AGLM][^D][^KA][LC]',
#  'SULFATASE_2': 'G[YV].[ST].{2}[IVAS]GK.{0,1}[FYWMK][HL]',
#  'ACYLPHOSPHATASE_1': '[LIV].G.VQ[GH]V.[FM]R',
#  'ACYLPHOSPHATASE_2': 'G[FYW][AVC][KRQAM]N.{3}G.V.{5}G',
#  'ATPASE_ALPHA_BETA': 'P[SAP][LIV][DNH][^LKGN][^F][^S]S[^DCPH]S',
#  'ATPASE_GAMMA': '[IV]T.E.{2}[DE].{3}GA.[SAKR]',
#  'ATPASE_E1_E2': 'DKTGT[LIVM][TI]',
#  'CUTINASE_1': 'P.[STA].[LIV][IVT].[GS]GYS[QL]G',
#  'OMPDECASE': '[LIVMFTAR][LIVMF].D.K.{2}D[IV][ADGP].T[CLIVMNTA]',
#  'RUBISCO_LARGE': 'G.[DN]F.K.DE',
#  'ALDOLASE_CLASS_I': '[LIVM].[LIVMFYW]EG.[LSI]LK[PA][SN]',
#  'ALDOLASE_KDPG_KHG_1': 'G[LIVM].{3}E[LIV]T[LF]R',
#  'ALDOLASE_KDPG_KHG_2': 'G.{3}[LIVMF]K[LF]FP[SA].{3}G',
#  'ISOCITRATE_LYASE': 'K[KR]CGH[LMQR]',
#  'ALPHA_CA_1': 'SE[HN].[LIVM].{4}[FYH].{2}E[LIVMGA]H[LIVMFA]{2}',
#  'FUMARATE_LYASES': 'GS.{2}M.[^RS]K.N',
#  'ENOLASE': '[LIVTMS][LIVP][LIV][KQ].[ND]Q[INV][GA][ST][LIVM][STL][DERKAQG][STA]',
#  'DEHYDRATASE_SER_THR': '[DESH].{4,5}[STVG][^EVKD][AS][FYI]K[DLIFSA][RLVMF][GA][LIVMGA]',
#  'ENOYL_COA_HYDRATASE': '[LIVM][STAG].[LIVM][DENQRHSTA]G.{3}[AG]{3}.{4}[LIVMST].[CSTA][DQHP][LIVMFYA]',
#  'TRP_SYNTHASE_ALPHA': '[LIVM]E[LIVM][GQ].[PALT][FYCHTWP][STPK][DEKY][PA][LIVMYGK][SGALIMY][DE][GN]',
#  'TRP_SYNTHASE_BETA': '[LIVMYAHQ].[HPYNVF].G[STA]HK.N.{2}[LIVM].[QEH]',
#  'D_ALA_DEHYDRATASE': 'G.D.[LIVM]{2}[IV]KP[GSA].{2}Y',
#  'CSA_PPIASE_1': '[FY].{2}[STCNLVA].[FV]H[RH][LIVMNS][LIVM].{2}F[LIVM].Q[AGFT]G',
#  'TIM_1': '[AVG][YLV]EP[LIVMEPKST][WYEAS][SAL][IV][GN][TEKDVS][GKNAD]',
#  'P_GLUCOSE_ISOMERASE_2': '[GSA].[LIVMCAYQS][LIVMFYWN].{4}[FY][DNTH]Q.[GA][IV][EQST].{2}K',
#  'PG_MUTASE': '[LIVM].RHG[EQ].[^Y].N',
#  'TOPO_IB_1': '[DEN].{6}[GS][IT]SK.{2}Y[LIVM].{3}[LIVM]',
#  'TOPOISOMERASE_II': '[LIVMA][^R]EG[DN]SA[^F][STAG]',
#  'AA_TRNA_LIGASE_I': 'P.{0,2}[GSTAN][DENQGAPK].[LIVMFP][HT][LIVMYAC]G[HNTG][LIVMFYSTAGPC]',
#  'GLNA_1': '[FYWL]DGSS.{6,8}[DENQSTAK][SA][DE].{2}[LIVMFY]',
#  'GLNA_ATP': 'KP[LIVMFYA].{3,5}[NPAT][GA][GSTAN][GA].H.{3}S',
#  'GLNA_ADENYLATION': 'K[LIVM].{5}[LIVMA]D[RK][DN][LI]Y',
#  'UBC_1': '[FYWLSP]H[PC][NHL][LIV].{3,4}G.[LIVP]C[LIV].{1,2}[LIVR]',
#  'GARS': 'R[LF]GDPE.[EQIM]',
#  'IPNS_1': '[RK].[STA].{2}S.CY[SL]',
#  'IPNS_2': '[LIVM]{2}.CG[STA].{2}[STAG].{2}T.[DNG]',
#  'TPP_ENZYMES': '[LIVMF][GSA].{5}P.{4}[LIVMFYW].[LIVMF].GD[GSA][GSAC]',
#  'BIOTIN': '[GDN][DEQTR].[LIVMFY].{2}[LIVM].[AIV]MK[LVMAT].{3}[LIVM].[SAV]',
#  'LIPOYL': '[GDN].{2}[LIVF].{3}[^VH][^M][LIVMFCA].{2}[LIVMFA][^LDFY][^KPE].K[GSTAIVW][STAIVQDN].{2}[LIVMFS].{5}[GCN].[LIVMFY]',
#  'CYTOCHROME_B5_1': '[FY][LIVMK][^I][^Q]HP[GA]G',
#  'THIOREDOXIN_1': '[LIVMF][LIVMSTA].[LIVMFYC][FYWSTHE].{2}[FYWGTN]C[GATPLVE][PHYWSTA]C[^I].[^A].{3}[LIVMFYWT]',
#  'GLUTAREDOXIN_1': '[LIVMD][FYSA].{4}C[PV][FYWH]C.{2}[TAV].{2,3}[LIV]',
#  'COPPER_BLUE': '[GA].{0,2}[YSA].{0,1}[VFY][^SEDT]C.{1,2}[PG].{0,1}H.{2,4}[MQ]',
#  '2FE2S_FER_1': 'C[^C][^C][GA][^C]C[GAST][^CPDEKRHFYW]C',
#  '4FE4S_FER_1': 'C.[^P]C[^C].C[^CP].[^C]C[PEG]',
#  'FLAVODOXIN': '[LIV][LIVFY][FY].[ST][^V].[AGC].T[^P].{2}A[^L].[LIV]',
#  'RUBREDOXIN': '[LIVM].[^G][^R]W.CP.C[AGD]',
#  'METALLOTHIONEIN_VRT': 'C.C[GSTAP].{2}C.C.{2}C.C.{2}C.K',
#  'FERRITIN_2': 'D.{2}[LIVMF][STACQV][DH][FYMI][LIV][EN].{2}[FYC]L.{6}[LIVMQ][KNER]',
#  'TRANSFERRIN_LIKE_1': 'Y.{0,1}[VAS]V[IVAC][IVA][IVA][RKH][RKS][GDENSA]',
#  'TRANSFERRIN_LIKE_2': '[YI].GA[FLI][KRHNQS]CL.{3,4}G[DENQ]V[GAT][FYW]',
#  'TRANSFERRIN_LIKE_3': '[DENQK][YF].[LY]LC.[DN].{5,8}[LIV].{4,5}C.{2}A.{4}[HQR].[LIVMFYW][LIVM]',
#  'PLANT_GLOBIN': '[SN]P.[LV].{2}HA.{3}F',
#  'HEMOCYANIN_1': 'Y[FYW].ED[LIVM].{2}N.{6}H.{3}P',
#  'HEMOCYANIN_2': 'T.{2}RDP.[FY][FYW]',
#  'ABC_TRANSPORTER_1': '[LIVMFYC][SA][SAPGLVFYKQH]G[DENQMW][KRQASPCLIMFW][KRNQSTAVM][KRACLVM][LIVMFYPAN][^PHY][LIVMFW][SAGCLIVP][^FYWHP][^KRHP][LIVMFYWSTA]',
#  'ALBUMIN_1': '[FY].{6}CC.{2}[^C].{4}C[LFY].{6}[LIVMFYW]',
#  'LIPOCALIN': '[DENG][^A][DENQGSTARK].{0,2}[DENQARK][LIVFY][^CP]G[^C]W[FYWLRH][^D][LIVMTA]',
#  'FABP': '[GSAIVK][^FE][FYW].[LIVMF].{2}[^K].[NHG][FY][DE].[LIVMFY][LIVM][^N][^G][LIVMAKR]',
#  'SUGAR_TRANSPORT_1': '[LIVMSTAG][LIVMFSAG][^SH][^RDE][LIVMSA][DE][^TD][LIVMFYWA]GR[RK].{4,6}[GSTA]',
#  'SUGAR_TRANSPORT_2': '[LIVMF].G[LIVMFA][^V].G[^KP].{7}[LIFY].{2}[EQ].{6}[RK]',
#  'AMINO_ACID_PERMEASE_1': '[STAGC]G[PAG].{2,3}[LIVMFYWA]{2}.[LIVMFYW].[LIVMFWSTAGC]{2}[STAGC].{3}[LIVMFYWT].[LIVMST].{3}[LIVMCTA][GA]E.{5}[PSAL]',
#  'ANION_EXCHANGER_1': 'FGG[LIVM]{2}[KR]D[LIVM][RK]RRY',
#  'ANION_EXCHANGER_2': '[FI]LISLIFIYETF.KL',
#  'MIP': '[HNQA][^D]NP[STA][LIVMF][ST][LIVMF][GSTAFY]',
#  'IGFBP_N_1': '[GP]C[GSET][CE][CA].{2}C[ALP].{6}C',
#  'ANNEXIN_1': '[TG][STV].{8}[LIVMF].{2}R.{3}[DEQNH].{2}[^S].{4}[IFY].{7}[LIVMF].{3}[LIVMF].{5}[^I].{5}[LIVMFA].{2}[LIVMF]',
#  'CLATHRIN_LIGHT_CHN_1': 'FLA[QH][QE]ES',
#  'IF_ROD_1': '[IV][^K][TACI]Y[RKH][^E][LM]L[DE]',
#  'TUBULIN': '[SAG]GGTG[SA]G',
#  'TUBULIN_B_AUTOREG': '^MR[DE][IL]',
#  'TAU_MAP_1': 'GS.{2}N.{2}H.[PA][AG]G{2}',
#  'MAP1B_NEURAXIN': '[STAGDN]Y.YE[^AV][^L][DE][KR][STAGCI]',
#  'F_ACTIN_CAPPING_BETA': 'C[DE][YF]NRD',
#  'CADHERIN_1': '[LIV].[LIV].D.ND[NH].P',
#  'CHIT_BIND_RR_1': 'G.{7}[DEN]G.{6}[FY].A[DNG].{2,3}G[FY].[APV]',
#  'GAS_VESICLE_A_1': '[LIVM].[DE][LIVMFYT][LIVM][DE].[LIVM]{2}[DKR]{2}G.[LIVMA][LIVM]',
#  'GAS_VESICLE_C': 'FL.{2}T.{3}R.{3}A.{2}Q.{3}L.{2}F',
#  'NEUROTR_ION_CHANNEL': 'C.[LIVMFQ].[LIVMF].{2}[FY]P.D.{3}C',
#  'G_PROTEIN_RECEP_F1_1': '[GSTALIVMFYWC][GSTANCPDE][^EDPKRH].[^PQ][LIVMNQGA][^RK][^RK][LIVMFT][GSTANC][LIVMFYWSTAC][DENH]R[FYWCSH][^PE].[LIVM]',
#  'OPSIN': '[LIVMFWAC][PSGAC].[^G].[SAC]K[STALIMR][GSACPNV][STACP].{2}[DENF][AP].{2}[IY]',
#  'RECEPTOR_TYR_KIN_II': '[DN][LIV]Y.{3}YYR',
#  'RECEPTOR_TYR_KIN_III': 'G.H.N[LIVM]VNLLGACT',
#  'INTEGRIN_ALPHA': '[FYWS][RK].GFF.R',
#  'I_EGF_1': 'C.[GNQ].{1,3}G.C.C.{2}C.C',
#  'REACTION_CENTER': '[NQH].{4}P.H.{2}[SAG].{11}[SAGC].H[SAG]{2}',
#  'PHYTOCHROME_1': '[RGS][GSA][PV]H.CH.{2}Y',
#  'WNT1': 'C[KR]CHG[LIVMT]SG.C',
#  'HBGF_FGF': 'G.[LIM].[STAGP].{6,7}[DENA]C.[FLM].[EQ].{6}Y',
#  'NGF_1': '[GSRE]C[KRL]G[LIVT][DE].{3}[YW].S.C',
#  'PDGF_1': 'P[PSR]CV.{3}RC[GSTA]GCC',
#  'TGF_BETA_1': '[LIVM].{2}P.{2}[FY].{4}C.G.C',
#  'THD_1': '[LV].[LIVM][^V].[^L]G[LIVMF]Y[LIVMFY]{2}.{2}[QEKHL][LIVMGT].[LIVMFY]',
#  'INTERFERON_A_B_D': '[FYH][FY].[GNRCDS][LIVM].{2}[FYL]L.{7}[CY][AT]W',
#  'INTERLEUKIN_1': '[FC].S[ASLV].{2}P.{2}[FYLIV][LI][SCA]T.{7}[LIVM]',
#  'INTERLEUKIN_6': 'C.{9}C.{6}GL.{2}[FY].{3}L',
#  'INTERLEUKIN_7_9': 'N.[LAP][SCT]FLK.LL',
#  'AKH': 'Q[LV][NT][FY][ST].{2}W',
#  'BOMBESIN': 'WA.G[SH][LF]M',
#  'CALCITONIN': 'C[SAGDN][STN].{0,1}[SA]TC[VMA].{3}[LYF].{3}[LYF]',
#  'GASTRIN': 'Y.{0,1}[GD][WH]M[DR]F',
#  'GLUCAGON': '[YH][STAIVGD][DEQ][AGF][LIVMSTE][FYLR].[DENSTAK][DENSTA][LIVMFYG].{8}[^K][KREQL][KRDENQL][LVFYWG][LIVQ]',
#  'GLYCO_HORMONE_BETA_1': 'C[STAGM]G[HFYL]C.[ST]',
#  'INSULIN': 'CC[^P][^P].C[STDNEKPI].{3}[LIVMFS].{3}C',
#  'NATRIURETIC_PEPTIDE': 'CFG.{3}[DEA][RH]I.{3}S.{2}GC',
#  'NEUROHYPOPHYS_HORM': 'C[LIFY][LIFYV].N[CS]P.G',
#  'PANCREATIC_HORMONE_1': '[FY].{3}[LIVM].{2}Y.{3}[LIVMFY].R.R[YF]',
#  'SOMATOTROPIN_1': 'C.[STN].{2}[LIVMFYS].[LIVMSTA]P.{5}[TALIV].{7}[LIVMFY].{6}[LIVMFY].{2}[STACV]W',
#  'TACHYKININ': 'F[IVFY]G[LM]M(?:[G]|$)',
#  'CECROPIN': 'W.{0,2}[KDN][^Q][^L]K[KRE][LI]E[RKN]',
#  'DEFENSIN': 'C.C.{3,5}C.{7}G.C.{9}CC',
#  'ENDOTHELIN': 'C.C.{4}D.{2}C.{2}[FY]C',
#  'THIONIN': 'CC.{5}R.{2}[FY].{2}C',
#  'SNAKE_TOXIN': 'GC.{1,3}CP.{8,10}CC.{2}[PDEN]',
#  'ENTEROTOXIN_H_STABLE': 'CC.{2}CC.PAC.GC',
#  'AEROLYSIN': '[KT].{2}NW.{2}T[DN]T',
#  'SHIGA_RICIN': '[LIVMA].[LIVMSTA]{2}.E[SAGV][STAL]R[FY][RKNQST].[LIVM][EQS].{2}[LIVMF]',
#  'CHANNEL_COLICIN': 'T.{2}W.P[LIVMFY]{3}.{2}E',
#  'STAPH_STREP_TOXIN_1': 'YGG[LIV]T[^I][^N].{2}N',
#  'STAPH_STREP_TOXIN_2': 'K.{2}[LIVF].{4}[LIVF]D.{3}R.{2}L.{5}[LIV]Y',
#  'MACPF_1': 'Y.{6}[FY]GTH[FY]',
#  'BPTI_KUNITZ_1': 'F.{2}[^I]GC.{6}[FY].{5}C',
#  'BOWMAN_BIRK': 'C.{5,6}[DENQKRHSTA]C[PASTDH][PASTDK][ASTDV]C[NDEKS][DEKRHSTA]C',
#  'KAZAL_1': 'C.{4}[^C].{2}C.[^A].{4}Y.{3}C.{2,3}C',
#  'SOYBEAN_KUNITZ': '[LIVM].D[^EK][EDNTY][DG][RKHDENQ].[LIVM].[^E][^Q].{2}Y.[LIVM]',
#  'SERPIN': '[LIVMFY][^G][LIVMFYAC][DNQ][RKHQS][PST]F[LIVMFY][LIVMFYC].[LIVMFAH]',
#  'POTATO_INHIBITOR': '[FYW]P[EQH][LIV]{2}G.{2}[STAGV].{2}A',
#  'SQUASH_INHIBITOR': 'CP.{5}C.{2}[DN].DC.{3}C.C',
#  'CYSTATIN': '[GSTEQKRV]Q[LIVT][VAF][SAGQ]G[^DG][LIVMNK][^TK].[LIVMFY][^S][LIVMFYA][DENQKRHSIV]',
#  'TIMP': 'C.C.P.HPQ.{2}[FIV]C',
#  'PTX_1': 'H.C.[ST]W.[ST]',
#  'IG_MHC': '[FY][^L]C[^PGAD][VA][^LC]H',
#  'PRION_1': 'AGAAAAGAVVGGLGGY',
#  'CYCLINS': 'R.{2}[LIVMSA].{2}[FYWS][LIVM].{8}[LIVMFC].{4}[LIVMFYA].{2}[STAGC][LIVMFYQ].[LIVMFYC][LIVMFY]D[RKH][LIVMFYW]',
#  'PCNA_2': '[RKA]C[DE][RH].{3}[LIVMF].{3}[LIVM].[SGAN][LIVMF].K[LIVMF]{2}',
#  'PRENYLATION': 'C[^DENQ][LIVM].$',
#  'ARRESTINS': '[FY]RYG.[DE]{2}.[DE][LIVM]{2}G[LIVM].F.[RK][DEQ][LIVM]',
#  'CHAPERONINS_CPN60': 'A[AS][^L][DEQ]E[^A][^Q][^R].GG[GA]',
#  'HSP70_1': '[IV]DLGT[ST].[SC]',
#  'HSP90': 'Y.[NQHD][KHR][DE][IVA]F[LM]R[ED]',
#  'UBIQUITIN_1': 'K.{2}[LIVM].[DESAK].{3}[LIVM][PAQ].{3}Q.[LIVM][LIVMC][LIVMFY].G.{4}[DE]',
#  'SRP54': 'P[LIVM].[FYL][LIVMAT][GS][^Q][GS][EQ].[^K].{2}[LIVMF]',
#  'G_TR_1': 'D[KRSTGANQFYW].{3}E[KRAQ].[RKQD][GC][IVMK][ST][IV].{2}[GSTACKRNQ]',
#  'IF5A_HYPUSINE': '[PT]GKHG.AK',
#  'S100_CABP': '[LIVMFYW]{2}.{2}[LKQ]D.{3}[DN].{3}[DNSG][FY].[ES][FYVC].{2}[LIVMFS][LIVMF]',
#  'SASP_1': 'K.E[LIV]A.[DE][LIVMF]G[LIVMF]',
#  '11S_SEED_STORAGE': 'NG.[DE]{2}.[LIVMF]C[ST].{11,12}[PAG]D',
#  'CASEIN_ALPHA_BETA': 'CL[LV]A.A[LVF]A',
#  'LECTIN_LEGUME_BETA': '[LIV][STAG]V[DEQV][FLI]D[ST]',
#  'LECTIN_LEGUME_ALPHA': '[LIV][^LA][EDQ][FYWKR]V[^VF][LIVF]G[LF][ST]',
#  'LAMP_1': '[STA]C[LIVM][LIVMFYW]A.[LIVMFYW].{3}[LIVMFYW].{3}Y',
#  'LAMP_2': 'C.{2}D.{3,4}[LIVM]{2}P[LIVM].[LIVM]G.{2}[LIVM].G[LIVM]{2}.[LIVM]{4}A[FY].[LIVM].{2}[KR][RH].{1,2}[STAG]{2}Y[EQ]',
#  'GLYCOPHORIN_A': 'II.[GAC]VMAG[LIVM]{2}',
#  'SVP_I': '[IVM].GQD.VK.{5}[KN]G.{3}[STLV]',
#  'ICE_NUCLEATION': 'AGYGST.T',
#  'DEHYDRIN_1': 'S{4}[SD][DE].[DE][GVE].{1,7}[GE].{0,2}[KR]{4}',
#  'THAUMATIN_1': 'G.[GF].C.T[GA]DC.{1,2}[GQ].{2,3}C',
#  'HMG_COA_REDUCTASE_2': '[LIVM]G.[LIVM]GG[AG]T',
#  'APP_CUBD': 'G[VT][EK][FY]VCCP',
#  'APP_INTRA': 'GYENPTY[KRS]',
#  'RECA_1': 'AL[KR][IF][FY][STA][STAD][LIVMQ]R',
#  'HISTONE_H3_1': 'KAPRK[QH][LI]',
#  'RIBOSOMAL_S19': '[STDNQ]G[KRNQMHSI].{6}[LIVM].{4}[LIVMC][GSD].{2}[LFI][GAS][DE][FYM].{2}[ST]',
#  'ASPARTOKINASE': '[LIVM].K[FY]GG[ST][SC][LIVM]',
#  'TROPOMYOSIN': 'LK[EAD]AE.RA[ET]',
#  'BACTERIAL_OPSIN_RET': '[FYIV][^ND][FYVG][LIVM]D[LIVMF].[STA]K.[^K][FY]',
#  'HCP': 'HRHRGH.{2}[DE]{7}',
#  'HSP70_2': '[LIVMF][LIVMFY][DN][LIVMFS]G[GSH][GS][AST].{3}[ST][LIVM][LIVMFC]',
#  'HEMOLYSIN_CALCIUM': 'D.[LI].{4}G.D.[LI].GG.{3}D',
#  'MALIC_ENZYMES': '[FM].[DV]D.{2}[GS]T[GSA].[IV].[LIVMAT][GAST][GASTC][LIVMFA][LIVMFY]',
#  'SOD_CU_ZN_2': 'G[GNHD][SGA][GR].R.[SGAWRV]C.{2}[IV]',
#  'DNA_LIGASE_A2': 'EG[LIVMA][LIVM][LIVMA][KR].{5,8}[YW][QNEKTI].{2,6}[KRH].{3,5}K[LIVMFY]K',
#  'PARATHYROID': 'VSE.Q.{2}H.{2}G',
#  'BETA_LACTAMASE_C': '[FY]E[LIVM]GS[LIVMG][SA]K',
#  'BETA_LACTAMASE_D': '[PA].S[ST]FK[LIV][PALV].[STA][LI]',
#  'SOMATOTROPIN_2': 'C[LIVMFY][^PT].D[LIVMFYSTA].[^S][^RK][^A].[LIVMFY].{2}[LIVMFYT].{2}C',
#  'SURFACT_PALMITOYL': 'IPCCPV',
#  'MICROBODIES_CTER': '[STAGCN][RKH][LIVMAFY]$',
#  'GATA_ZN_FINGER_1': 'C.[DNEHQSTI]C.{4,6}[ST].{2}[WM][HR][RKENAMSLPGQT].{3,4}[GNEP].{3,6}C[NES][ASNR]C',
#  'ETS_DOMAIN_1': 'L[FYW][QEDH]F[LI][LVQK][^N][LI]L',
#  'ETS_DOMAIN_2': '[RKHN].{2}M.Y[DENQ].[LIVM][STAG]R[STAG][LI]R.Y',
#  'ZF_PARP_1': 'C[KR].C.{3}I.[KAL].{3}[RG].{16,18}W[FYH]H.{2}C',
#  'P53': 'MCNSSC[MV]GGMNRR',
#  'CTF_NFI_1': 'RKRKYFKKHEKR',
#  'MADS_BOX_1': '[RGS].[RKS].{5}[IL].[DNGSK].{3}[KR].{2}T[FY].[RK]{3}.{2}[LIVM].[KE]K[AT].[EQ][LIVM][STA].L.{4}[LIVM].[LIVM][LIVMT][LIVM].{6}[LIVMFC].{2}[FYLS]',
#  'TFIID': 'Y.[PK].{2}[IF].{2}[LIVM]{2}.[KRH].{3}P[RKQ].{3}L[LIVM]F.[STN]G[KR][LIVMA].{3}G[TAGL][KR].{7}[AGCS].{7}[LIVMF]',
#  'CSD_1': '[FYKH]G[FL][IL].{6,7}[DER][LIVM][FQ].H.[STKR].[LIVMFYC]',
#  'HMG_BOX_1': '[FI]S[KR]KC.[EK]RWKT[MV]',
#  'HMGI_Y': '[AT].{1,2}[RK]{2}[GP]RGRP[RK].',
#  'HMG14_17': '[RQ]RSA[RS]LSA[RKM][PL]',
#  'HTH_LACI_1': '[LIVM].[DE][LIVM]A.{2}[STAGV].V[GSTP].{2}[STAG][LIVMA].{2}[LIVMFYAN][LIVMC]',
#  'HISTONE_H2B': '[KR]E[LIVM][EQ]T.{2}[KR].[LIVM]{2}.[PAG][DE]L.[KR]HA[LIVM][STA]EG',
#  'RIBOSOMAL_L5': '[LIVM].{2}[LIVM][STAVC][GE][QV].{2}[LIVMA].[STC].[STAG][KRH].[STA]',
#  'RIBOSOMAL_L11': '[RKN].[LIVM].G[ST].{2}[SNQ][LIVM]G.[^M][LIVM].{0,1}[DENG]',
#  'RIBOSOMAL_S9': '[GS]GG.{2}[GSA][QK].{2}[SA].{3}[GSA].[GSTAV][KR][GSALVD][LIFV]',
#  'RIBOSOMAL_S10': '[AV].{3}[GDNSR][LIVMSTAG].{3}GP[LIVM].[LIVM]PT',
#  'RIBOSOMAL_S15': '[LIVM].{2}H[LIVMFY].{3}[^S].D.{2}[STAGN].{3}[LF].{2}[^A].{6}[LIVM].{2}[FY]',
#  'BACTERIAL_PQQ_1': '[DEN][WV].{3}G[RKNM].{6}[FYW][SV].{4}[LIVM]N.{2}NV.{2}L[RKT]',
#  'BACTERIAL_PQQ_2': 'W.{4}[YF]D.{3}[DN][LIVMFYT][LIVMFY]{3}.{2}G.{2}[STAG][PVT]',
#  'NIR_SIR': '[STVN]GC.{3}C.{6}[DE][LIVMF][GAT][LIVMF]',
#  'URICASE': '[LV].[LV][LIV]K[STV][ST].[SN].F.{2}[FY].{4}[FY].{2}L.{5}R',
#  'BH4_AAA_HYDROXYL_1': 'PD.{2}H[DE][LIVF][LIVMFY]GH[LIVMC][PA]',
#  'RIBORED_SMALL': '[IVMSEQ]E.{1,2}[LIVTA][HY][GSA].[STAVM]Y.{2}[LIVMQ].{3}[LIVFY][IVFYCSA]',
#  'PTS_HPR_HIS': 'G[LIVM]H[STAV]R[PAS][GSTA][STAMVN]',
#  'PEP_ENZYMES_PHOS_SITE': 'G[GA].[STN].H[STA][STAV][LIVM]{2}[STAV][RG]',
#  'PTS_EIIA_TYPE_1_HIS': 'G.{2}[LIVMFA][LIVMF]{2}H[LIVMF]G[LIVMF].T[LIVA]',
#  'PTS_EIIA_TYPE_2_HIS': '[DENQ].{6}[LIVMF][GA].{2}[LIVM]A[LIVM]PH[GAC]',
#  'GART': 'G.[STMC][IVTL].[FYWVQELKR][VMAT].[DEVMKAI].[LIVMY]D.G.{2}[LIVTYA].{6}[LIVM]',
#  'MGMT': '[LIVMF]PCHR[LIVMF]{2}',
#  'UDPGT': '[FW].{2}[QL].{2}[LIVMYA][LIMV].{4,6}[LVGAC][LVFYAHM][LIVMF][STAGCM][HNQ][STAGC]G.{2}[STAG].{3}[STAGL][LIVMFA].{4,5}[PQR][LIVMTA].{3}[PA].{2,3}[DES][QEHNR]',
#  'ADOMET_SYNTHASE_1': '[GN][AS]GDQG.{3}G[FYHG]',
#  'ADOMET_SYNTHASE_2': 'G[GA]G[ASC][FY]S.K[DE]',
#  'HEXOKINASE_1': '[LIVM]GF[TN]FS[FY]P.{5}[LIVM][DNST].{3}[LIVM].{2}WTK.[LF]',
#  'CDP_ALCOHOL_P_TRANSF': 'DG.{2}AR.{7,8}G.{3}D.{3}D',
#  'RHODANESE_1': '[FY].{3}H[LIV]PGA.{2}[LIVF]',
#  'CLP_PROTEASE_SER': 'T.{2}[LIVMF]G.A[SAC]S[MSA][PAG][STA]',
#  'CLP_PROTEASE_HIS': 'R.{3}[EAP].{3}[LIVMFYT][LM][LIVM]HQP',
#  'TYR_PHOSPHATASE_1': '[LIVMF]HC.{2}G.{2}R[STC][STAGP]',
#  'PROKAR_ZN_DEPEND_PLPC_1': 'HY.[GT]D[LIVMAF][DNSH].P.H[PA].N',
#  'ALPHA_L_FUCOSIDASE': 'P.{2}L.{3}KWE.C',
#  'PPASE': 'D[SGDN]D[PE][LIVMF]D[LIVMGAC]',
#  'PROTEASOME_ALPHA_1': '[FYNAGS].{4}[STNLV].[FYW]S[PDS].{0,1}G[RKHDS].{2}Q[LIVA][DENR][YH][GSAD].{2}[GSAG]',
#  'ATPASE_DELTA': '[LIVM].[LIVMFYT].{3}[LIVMT][DENQK].[^G][LIVM].[GSA]G[LIVMFYGA][^S][LIVM][KRHENQ].[GSEN]',
#  'ATPASE_NA_K_BETA_1': '[FYWMV].{2}[FYWM].[FYW][DN].{6}[LIVMF][GA]RT.{3}[WRL]',
#  'ATPASE_NA_K_BETA_2': '[RK].{2}C[RKQWI].{5}L.{2}C[SA]G',
#  'DDC_GAD_HDC_YDC': 'S[LIVMFYW].[^KG].{3}K[LIVMFYWGH][LIVMFYWG].[^R].[LIVMFYW][^V][CA].{2}[LIVMFYWQ][^K].[RK]',
#  'PEPCASE_2': '[IVLC]M[LIVM]GYSDS.K[DF][STAG]G',
#  'DNA_PHOTOLYASES_1_1': 'TG.P[LIVM]{2}DA.M[RA].[LIVM]',
#  'ALANINE_RACEMASE': '[SACVLG][AIPTV].{0,1}K[ADGS][DEN][GA]YG[HACILN][GD]',
#  'TOPO_IA_1': '[EQ].LY[DEQSTLM].{3,12}[LIVST][ST]Y.R[ST][DEQSN]',
#  'RECOMBINASES_1': 'Y[LIVAC]R[VA]S[ST].{2}Q',
#  'RECOMBINASES_2': 'G[DE].{2}[LIVM][^E].[^V][LIVM][DT]R[LIVM][GSA]',
#  'SUCCINYL_COA_LIG_2': 'G.{2}A.{4,7}[RQT][LIVMF]GH[AS][GH]',
#  'LBP_BPI_CETP': '[PA][GA][LIVMC].{2}R[IV][ST].{3}L.{5}[EQAV].{4}[LIVM][EQK].{8}P',
#  'PROK_SULFATE_BIND_1': 'K.[NQEK][GT]G[DQ].[LIVM].{3}QS',
#  '43_KD_POSTSYNAPTIC': 'GQDQTKQQI',
#  'ACTINS_1': '[FY][LIV][GV][DE]E[ARV][QLAH].{1,2}[RKQ]{2}[GD]',
#  'CONNEXINS_1': 'C[DNH][TL].[QT]PGC.{2}[VAIL]C[FY]D',
#  'CONNEXINS_2': 'C.{3,4}PC.{2,3}[LIVMTA][DENT]C[FYN][LIVMQ][SA][KRH]P',
#  'PROKAR_NTER_METHYL': '[KRHEQSTAG]G[FYLIVM][ST][LT][LIVP]E[LIVMFWSTAG]{14}',
#  'G_DYNAMIN_1': 'LP[RKT][GD][STNKEA][GND][LIVMG][VICA]TR',
#  'KINESIN_MOTOR_1': '[GSAT][KRHPSTQVME][LIVMFY].[LIVMF][IVC][DN][LS][AH]G[SAN]E',
#  'NEUROMODULIN_1': '^MLCC[LIVM]RR',
#  'NEUROMODULIN_2': 'SFRGHI.RKK[LIVM]',
#  'PROFILIN': '^.{0,1}[STA].{0,1}W[DENQH].[YI].[DEQ]',
#  'SYNAPSIN_1': 'LRRRLSDS',
#  'SYNAPSIN_2': 'GHAH[SA]GMGK[IV]K',
#  'SYNAPTOBREVIN': '[NT][LIVMF][DENSTG][KLNRGS][VAI].[DEQA]R.{2}[KRN][LIVM][STDEA].[LIVM].[DEQGN][KR][TAS][DEAS]',
#  'POTEX_CARLAVIRUS_COAT': '[RK][FYW]A[GAP]FD.F.{2}[LV].{3}[GASTY][GASTV]',
#  'PHOTOSYSTEM_I_PSAAB': 'CDGP[GE]RGGTC',
#  'SRCR_1': '[GNRVM].{5}[GLKA].{2}[EQ].{6}[WPS][GLKH].{2}C.{3}[FYW].{8}[CM].{3}G',
#  'TM4_1': '[GC].{3}[LIVMFS].{2}[GSA][LIVMFTC][LIVMFA]G[CLYI].[GA][STAPL].{2}[EGAR].{2}[CWNLF][LIVMGA][LIVM]',
#  'GRANINS_1': '[DE][SN]L[SAN][^EGI][^ELT][DE].EL',
#  'GRANINS_2': 'C[LIVM]{2}E[LIVM]{2}S[DN][STA]L.K.[SN].{3}[LIVM][STA].EC',
#  'INTERLEUKIN_2': 'TE[LF].{2}L.CL.{2}EL',
#  'CEREAL_TRYP_AMYL_INH': 'C.{4}[SAGDV].{4}[SPAL][LF].{2}C[RH].[LIVMFYA]{2}.{3,4}C',
#  'DISINTEGRIN_1': 'C.{2}[GS].CC.{1,2}[NQRSEKD]C.[FMYLVI].{6}C[RKNQ]',
#  'FTSW_RODA_SPOVE': '[NV].{5}[GTR][LIVMA].P[PTLIVME].G[LIVM].{3}[LIVMFW]{2}S[YSAQ]GG[STN][SA]',
#  'STAPHYLOCOAGULASE': 'ARP.{3}K.S.TNAYNVTT.{2}[DN]G.{3}YG',
#  'TONB_DEPENDENT_REC_1': '^.{10,115}[DENF][ST][LIVMF][LIVSTEQ]V[^AGPN][AGP][STANEQPK]',
#  'SMALL_HYDR_PLANT_SEED': 'G[EQ]TVVPGGT',
#  'ACTINS_2': 'W[IVC][STAK][RK].[DE]Y[DNE][DE]',
#  'PHOSPHOFRUCTOKINASE': '[RK].{4}[GAS]H.[QL][QR][GS][GF].{5}[DE][RL]',
#  'HSF_DOMAIN': 'L.{3}[FY]KH.N.[STAN]SF[LIVM]RQL[NH].Y.[FYW][RKH]K[LIVM]',
#  'PEROXIDASE_1': '[DET][LIVMTA][^NSYL][^RPFC][LIVM][LIVMSTAG][SAG][LIVMSTAG]H[STA][LIVMFY]',
#  'PEROXIDASE_2': '[SGATV][^D].{2}[LIVMA]R[LIVMA].[FW]H[^V][SAC]',
#  'CATALASE_1': 'R[LIVMFSTAN]F[GASTNP]Y.D[AST][QEH]',
#  'CATALASE_2': '[IF].[RH].{4}[EQ]R.{2}H.{2}[GAS][GASTFY][GAST]',
#  'ACYLTRANSF_C_1': '[LI][PK].[LVPQ]P[IVTAL]P.[LIVMA].[DENQAS][ST][LIVMA].{2}[LY]',
#  'ACYLTRANSF_C_2': 'R[FYW].[DA][KA].{0,1}[LIVMFY].[LIVMFY]{2}.{3}[DNS][GSA].{6}[DE][HS].{3}[DE][GAC]',
#  'CHALCONE_SYNTH': 'R[LIVMFYS].[LIVM].[QHG].GC[FYNA][GAPV]G[GAC][STAVK].[LIVMF][RAL]',
#  'POLYPRENYL_SYNTHASE_2': '[LIVMFY]G.{2}[FYL]Q[LIVM].DD[LIVMFY].[DNG]',
#  'FGGY_KINASES_2': '[GSA].[LIVMFYW][^D]G[LIVM].{7,8}[HDENQ][LIVMF][^PEQ][^DTAI][AS][STALIVM][LIVMFY][DEQ]',
#  'RNA_POL_D_30KD': 'N[SGAT][LIVMF]RR.{9}[SAR].{3}[VA].{4}N.[STA].{3}[DN]E.[LIV][GSA].R[LI][GAS][LIVM]{2}[PV]',
#  'DNA_POLYMERASE_A': 'R.{2}[GSAV]K.{3}[LIVMFY][AGQ].{2}Y.{2}[GS].{3}[LIVMA]',
#  'CLOS_CELLULOSOME_RPT': 'D[LIVMFY][DNV].[DNS].{2}[LIVM][DN][SALM].D.{3}[LIVMF].[RKS].[LIVMF]',
#  'ATPASE_A': '[STAGN][^E][STAG][LIVMF]RL[^LP][SAGV]N[LIVMT]',
#  'ACONITASE_1': '[LIVM].{2}[GSACIVM].[LIV][GTIV][STP]C.{0,1}TN[GSTANI].{4}[LIVMA]',
#  'PATHOGENESIS_BETVI': 'G.{2}[LIVMF].{4}E.{2,3}[CSTAENV].{8,9}[GNDS][GS]{2}[CS].{2}[KT].{4}[FY]',
#  'GUANYLATE_CYCLASE_1': '[GD][VI][LIVM].{0,1}[GS].{5}[FY].[LIVM][FYWL][GS][DNTHKWE][DNTAS][IV][DNTAY].{5}[DEC]',
#  'AMP_BINDING': '[LIVMFY][^E][^VES][STG][STAG]G[ST][STEI][SG].[PASLIVM][KR]',
#  'NA_SOLUT_SYMP_1': '[GS].{2}[LIY].{3}[LIVMFYWSTAG]{7}.{3}[LIY][STAV].{2}GG[LMF].[SAP]',
#  'NA_SOLUT_SYMP_2': '[GAST][LIVM].{3}[KR].{4}GA.{2}[GAS][LIVMGS][LIVMW][LIVMGAT]G.[LIVMGA]',
#  'ANF_RECEPTORS': 'GP.C.Y.AA.V.R.{3}HW',
#  'MYOTOXINS_1': 'K.CH.K.{2}HC.{2}K.{3}C.{8}K.{2}C.{2}[RK].KCCKK',
#  'GLUTATHIONE_PEROXID_1': '[GNDRC][RKHNQFYCS].[LIVMFCS][LIVMF]{2}.N[VT].[STCA].[CU][GA].[TA]',
#  '6PGD': '[LIVM].[DG].{2}[GAEHS][NQSD][KS]G[TE]G.W',
#  'G_GLU_TRANSPEPTIDASE': 'T[STA]H.[ST][LIVMA].{4}G[SN].V[STA].T.T[LIVM][NE].{1,2}[FY]G',
#  'ZN2_CY6_FUNGAL_1': '[GASTPV]C.{2}C[RKHSTACW].{2}[RKHQ].{2}C.{5,12}C.{2}C.{6,8}C',
#  'RIBOSOMAL_L22': '[RKQN].{2}[^G].[RH][GAS].G[KRQS].{8}[^L][HDN][LIVM][^A][LIVMS].[LIVM]',
#  'POU_2': 'SQ[STK][TA]I[SC]R[FH][ET].[LSQ].{0,1}[LIR][ST]',
#  'ZF_TFIIS_1': 'C.{2}C.{9}[LIVMQSART][QH][STQLMI][RA][SACR].[DE][DET][PGSEAM].{6}C.{2,5}C.{3}[FWE]',
#  'RIBOSOMAL_L2': 'P.{2}RG[STAIV]{2}.N[APK].[DE]',
#  'COBALAMIN_BINDING': '[SN][VT]DT[GAME]A[LIVM][AV].[LM]A[LIVMF][ST]C',
#  'NDPK': 'N.{2}H[GA]SD[GSA][LIVMPKNE]',
#  'IDH_IMDH': '[NSK][LIMYTV][FYDNH][GEA][DNGSTY][IMVYL].[STGDN][DN].{1,2}[SGAP].{3,4}[GE][STG][LIVMPA][GA][LIVMF]',
#  'SMALL_CYTOKINES_CXC': 'C.C[LIVMS].{4,6}[LIVMFY].{2}[RKSEQNA].[LIVM].{2}[LIVMA].{5}[STAG].{2}C.{3}[EQ][LIVM]{2}.{9,10}C[LV][DN]',
#  'SMALL_CYTOKINES_CC': 'CC[LIFYTRQ].{5,8}[LIR].{4}[LIVMFA].{2}[FYWECI].{5,8}C.{3,4}[SAG][LIVM]{2}[FL].{7,9}C[STAV]',
#  'GNRH': 'Q[HY][FYW]S.{4}PG',
#  'RIBOSOMAL_L3': '[FL].{6}[DN].{2}[AGS].[ST].G[KRH]G.{2}G.{3}R',
#  'RIBOSOMAL_L15': '[KR][LIVM]{2}[GASL].[GT].[LIVMA].{2,5}[LIVMF].[LIVMF].{3,4}[LIVMFCA][ST].{2}A.{3}[LIVM].{3}G',
#  'FATTY_ACID_DESATUR_1': 'GE.[FYN]HN[FY]HH.FP.DY',
#  'ALPHA_2_MACROGLOBULIN': '[PG].[GS]C[GA]E[EQ].[LIVM]',
#  'LIM_DOMAIN_1': 'C.{2}C.{15,21}[FYWHPCR]H.{2}[CH].{2}C.{2}C.{3}[LIVMF]',
#  'ZF_DAG_PE_1': 'H.[LIVMFYW].{8,11}C.{2}C.{3}[LIVMFC].{5,10}C.{2}C.{4}[HD].{2}C.{5,9}C',
#  'CITRATE_SYNTHASE': 'G[FYAV][GA]H.[IV].{1,2}[RKTQ].{2}[DV][PS]R',
#  'THIOL_CYTOLYSINS': '[RK]ECTGL.WEWW[RK]',
#  'DIHYDROOROTASE_1': 'D[LIVMFYWSAP]H[LIVA]H[LIVF][RN].[PGANF]',
#  'DIHYDROOROTASE_2': '[GAVS][ST]D.APH.{4}K',
#  'THYROGLOBULIN_1_1': '[FYWHPVAS].{3}C.{3,4}[SG].[FYW].{3}Q.{5,12}[FYW]C[VA].{3,4}[SG]',
#  'A_DEAMINASE': '[SA][LIVM][NGS][STA]DDP',
#  'DNA_MISMATCH_REPAIR_2': '[STA][LIVMF].[LIVM].DE[LIVMFY][GCA][RKHAS][GS][GST].{4}G',
#  'IMP_DH_GMP_RED': '[LIVMT][RK][LIVM]G[LIVM]G.G[SRK][LIVMAT]C.T',
#  'PAL_HISTIDASE': '[GS][STG][LIVM][STG][SAC]SG[DH]L.[PN]L[SA].{2,3}[SAGVTL]',
#  'RNA_POL_PHAGE_2': '[LIVMF].R.{3}K.{2}[LIVMF]M[PT].{2}Y',
#  'MOLYBDOPTERIN_PROK_2': '[STA].[STAC]{2}.{2}[STA]D[LIVMY]{2}LP.[STAC]{2}.{2}E',
#  'PROLINE_PEPTIDASE': '[HA][GSYR][LIVMT][SG]H.[LIV]G[LIVMNKS].[IVEL][HNC][DEV]',
#  'CLUSTERIN_1': 'CKPCLK.TC',
#  'CLUSTERIN_2': 'CL[RK]M[RK].[EQ]C[ED]KC',
#  'BACTERIAL_LUCIFERASE': '[GA][LIVM]P[LIVM].[LIVMFY].W.{6}[RK].{6}Y.{3}[AR]',
#  'APPLE': 'C.{3}[LIVMFY].{5}[LIVMFY].{3}[DENQ][LIVMFY].{10}C.{3}CT.{4}C.[LIVMFY]F.[FY].{13,14}C.[LIVMFY][RK].[ST].{14,15}SG.[ST][LIVMFY].{2}C',
#  'PII_GLNB_UMP': 'Y[KR]G[AS][AE]Y',
#  'TYROSINASE_1': 'H.{4,5}F[LIVMFTP].[FW]HR.{2}[LVMT].{3}E',
#  'TYROSINASE_2': 'DP.F[LIVMFYW].{2}H.{3}D',
#  'THYMOSIN_B4': 'L[KR]KT[DENT]T.{2}KN[PT]L',
#  'SPASE_I_1': '[GS][^PR]SM[^RS][PS][AT][LF]',
#  'POLYGALACTURONASE': '[GSDENKRH].{2}[VMFC].{2}[GS]HG[LIVMAG].{1,2}[LIVM]GS',
#  'PECTINESTERASE_2': '[IV].G[STAD][LIVT]D[FYI][IV][FSN]G',
#  'FRD_SDH_FAD_BINDING': 'R[ST]H[ST].{2}A.GG',
#  'PEPCK_GTP': '[FY]PS[AGMS]CGKT[NS]',
#  'BETA_AMYLASE_1': 'H.CGGNVGD',
#  'NI_HGENASE_L_1': 'RG[LIVMF]E.{15}[QESMP][RK].C[GR][LIVM]C',
#  'NI_HGENASE_L_2': '[FY]D[PI][CU][LIMAV][ASG]C.{2,3}H',
#  'RAS_GTPASE_ACTIV_1': '[GSNA].[LIVMF][FYCI][LIVMFY]R[LIVMFY]{2}[GACNS][PAV][AV][LIV][LIVM][SGANT]P',
#  'MALATE_SYNTHASE': '[KR][DENQ][HN].{2}GLN.G.WDY[LIVM]F',
#  'CRF': '[PQA].[LIVM]S[LIVM].{2}[PST][LIVMF].[LIVM]LR.{2}[LIVMW]',
#  'ALPHA_GALACTOSIDASE': 'G[LIVMFY].{2}[LIVMFY].[LIVM]D[DF].{1,2}W.{3,7}[RV][DNSF]',
#  'ADENYLOSUCCIN_SYN_2': 'GI[GR]P.Y.{2}K.{2}R',
#  'FIBRINOGEN_C_1': 'WW[LIVMFYW].{2}C.{2}[GSA].{2}NG',
#  'SVP_II': '[GSA]Q.KS[FY].Q.K[SA]',
#  'ALKYLBASE_DNA_GLYCOS': 'G[IV][GK].W[ST][AVI].[LIVMFY]{2}.[LIVM].{8}[MF].{2}[ED]D',
#  'RNASE_3_1': '[DEQ][KRQT][LMF]E[FYW][LV]GD[SARHG]',
#  'ZF_RING_1': 'C.H.[LIVMFY]C.{2}C[LIVMYA]',
#  'HTH_ASNC_1': '[GSTAP].{2}[DNEQA][LIVM][GSA].{2}[LIVMFYT][GAN][LIVMST][ST].{6}R[LIVT].{2}[LIVM].{3}G',
#  'INTERLEUKIN_10': '[KQS].{4}C[QYCS].{4}[LIVM]{2}.[FLR][FYT][LMVR].[DERTI][IV][LMF]',
#  'P5CR': '[PALF].{2,3}[LIV].{3}[LIVM][STAC][STV].[GANK]G.T.{2}[AG][LIV].{2}[LMF][DENQK]',
#  'DNA_POLYMERASE_X': 'G[SG][LFY].R[GE].{3}[SGCL].D[LIVM]D[LIVMFY]{3}.{2}[SAP]',
#  'SULFATASE_1': '[SAPG][LIVMST][CS][STACG]P[STA]R.{2}[LIVMFW]{2}[TAR]G',
#  'SMB_1': 'C.C.{3}C.{5,6}CC.[DN][FY].{3}C',
#  'RIBOSOMAL_L6_1': '[PS][DENS].YK[GA]KG[LIVM]',
#  'RIBOSOMAL_L19E': 'Q[KR]R[LIVM].[SA].{4}[CV]G.{3}[IV][WK][LIVF][DNSV][PE]',
#  'RIBOSOMAL_S14': '[RP].{0,1}C.{11,12}[LIVMF][^L][LIVMF][SC][RG].[^D][^PK][RN]',
#  'RIBOSOMAL_S4E': 'H.KR[LIVMF][SANK].P.{2}[WY].[LIVM].[KRP]',
#  'RIBOSOMAL_S24E': '[FYAT]G.{2}[KREILYV][STAI].[GCAVI][FYKRE][GTALV].[LIVYA]Y[DENQAKY][STDN].{7}E',
#  'RNASE_T2_1': '[FYWL].[LIVM]HGL[WY]P',
#  'RNASE_T2_2': '[LIVMF].{2}[HDGTY][EQ][FYW].[KRT]H[GA].C',
#  'PEPCK_ATP': 'LIGDDEH.W.[DEPKVNA].[GVS][IV].N',
#  'PORPHOBILINOGEN_DEAM': 'E[KR].[LIVMFAT].{3}[LIVMFAC].[GSALV][GSANHD]C.[IVTACS][PLA][LIVMF][GSA]',
#  'FERROCHELATASE': '[LIVMF][LIVMFC].[ST].H[GS][LIVM]P.{4,5}[DENQKRLHAFSTI].[GN][DPC].{1,4}[YA]',
#  'COMPLEX1_49K': '[LIVMH]H[RT][GA].EK[LIVMTN].E.[KRQ]',
#  'UBIQUITIN_ACTIVAT_1': 'K[AI][CL]SGK[FI].[PQ]',
#  'CYTOCHROME_B559': '[LIV].[ST][LIVF]R[FYW].{2}[IVL]H[STGAV][LIV][STGA][IV]P',
#  'CHEMOTAXIS_TRANSDUC_1': 'RTE[EQ]Q.{2}[SA][LIVM].[EQ]TAASMEQLTATV',
#  'PYROKININ': 'F[GSTV]PRL(?:[G]|$)',
#  'FERRITIN_1': 'E.[KR]E.{2}E[KR][LF][LIVMA].{2}QN.R.GR',
#  'TP1': 'SKRKYRK',
#  'COMPLEX1_30K': 'ERE.{2}[DE][LIVMFY]{2}.{6}[HK].{3}[KRP].[LIVM][LIVMYS]',
#  'HLYD_FAMILY': '[LIVM].{2}G[LM].{3}[STGAV].[LIVMT].[LIVMTK][GE].[KR].[LIVMFYW]{2}.[LIVMFYW]{2}[LIVMFYWK]',
#  'METMALONYL_COA_MUTASE': 'RIARN[TQ].{2}[LIVMFY]{2}.[EQH]E.{4}[KRN].{2}DP.[GSA]GS',
#  'ALDOSE_1_EPIMERASE': '[NS].TNH.Y[FW]N[LI]',
#  'CYSTEINE_SWITCH': 'PRC[GN].P[DR][LIVSAPKQ]',
#  'TRANSGLUTAMINASES': '[GT]Q[CA]WV.[SA][GAS][IVT].{2}T.[LMSC]R[CSAG][LV]G',
#  'RIBOSOMAL_S3': '[GSTA][KR].{6}G.[LIVMT].{2}[NQSCH].{1,3}[LIVFCA].{3}[LIV][DENQ].{7}[LMT].{2}G.{2}[GS]',
#  'BACTERIOFERRITIN': '^M.G.{3}[IV][LIV].{2}[LM].{3}L.{3}L',
#  'HEMERYTHRINS': 'HF.{2}[EQ][ENQ].{2}[LMF].{4,7}[FY].{5,6}H.{3}[HR]',
#  'MOLYBDOPTERIN_PROK_1': '[STAN].[CH].{2,3}C[STAG][GSTVMF].C.[LIVMFYW].[LIVMA].{3,4}[DENQKHT]',
#  'HTH_MERR_1': '[GSA].[LIVMFA][ASM].{2}[STACLIV][GSDENQR][LIVC][STANHK].{3}[LIVM][RHF].[YW][DEQ].{2,3}[GHDNQ][LIVMF]{2}',
#  'LAMBDA_PHAGE_CIII': 'ES.L.R.{2}[KR].L.{4}[KR]{2}.{2}[DE].L',
#  'TEA_1': 'GRNELI.{2}[YH]I.{3}[TC].{3}RT[RK]{2}Q[LIVM]SSH[LIVM]QV',
#  'ICOSAH_VIR_COAT_S': '[FYW].[PSTA].{7}G.[LIVM].[LIVM].[FYWI].{2}D.{5}P',
#  'HOK_GEF': '[LIVMA]{4}C[LIVMFA]T[LIVMA]{2}.{4}[LIVM].[RG].{2}L[CY]',
#  'FMN_HYDROXY_ACID_DH_1': 'SNHG[AG]RQ',
#  'EUKARYOTIC_PORIN': '[YH].{2}D[SPCAD].[STA].{3}[TAG][KR][LIVMF][DNSTA][DNS].{4}[GSTAN][LIVMA].[LIVMY]',
#  'MOLYBDOPTERIN_EUK': '[GA][^A].{2}[KRNQHT].{11,14}[LIVMFYWS].{3}[^V][^GK].{3}[LIVMF].C.{2}[DEN]R.{2}[DE]',
#  'CARBOXYPEPT_SER_HIS': '[LIVF].{2}[LIVSTA].[IVPST].[GSDNQL][SAGV][SG]H.[IVAQ]P.{3}[PSA]',
#  'CBM2_A': 'WN[STAGR][STDN][LIVM].{2}[GST].[GST].{2}[LIVMFT][GA]',
#  'CBM1_1': 'CGG.{4,7}G.{3}C.{4,5}C.{3,5}[NHGS].[FYWMI].{2}QC',
#  'STATHMIN_1': 'P[KRQ][KR]{2}[DE].SL[EG]E',
#  'ARGININOSUCCIN_SYN_1': '[ASL][FY]SGG[LV]DT[ST]',
#  'ARGININOSUCCIN_SYN_2': 'G.T.[KRM]GND.{2}RF',
#  'FIBRILLARIN': '[GST][LIVMAPKR][IVEAT][FY][GSAC][IVL]E[FYV][SA].{0,1}[REA].{2}[RQSFT][DEK]',
#  'PHOSPHORIBULOKINASE': 'K[LIVM].RD.{3}RG.[ST].E',
#  'MYELIN_P0': 'S[KR]S.K[AG].[SA]EKK[STA]K',
#  'MYELIN_MBP': 'VVHFFKN',
#  'RING_HYDROXYL_ALPHA': 'C.HR[GAR].{7,8}[GEKVI][NERAQ].{4,5}C.[FY]H',
#  'AMIDASES': 'G[GAV]S[GS]{2}G.[GSAE][GSAVYCT].[LIVMT][GSA].{6}[GSAT].[GA].[DE].[GA].S[LIVM]R.P[GSACTL]',
#  'GLYCOSYL_HYDROL_F1_1': '[LIVMFSTC][LIVFYS][LIV][LIVMST]ENG[LIVMFAR][CSAGN]',
#  'PYRIDINE_REDOX_2': 'C.{2}CD[GAS].{2,4}[FYA].{4}[LIVMAT].{0,1}[LIVM]{2}[GI][GDS][GRD][DN]',
#  'FATTY_ACID_DESATUR_2': '[ST][SA].{3}[QR][LI].{5,6}DY.{2}[LIVMFYW][LIVM][DE]',
#  'MYELIN_PLP_1': 'G[MV]ALFCGCGH',
#  'GRAM_NEG_PORIN': '[LIVMFY].{2}G.{2}Y.F.K.{2}[SN][STAV][LIVMFYW]V',
#  'AVIDIN_1': '[DENY].{2}[KRI][STA].{2}VG.[DN].[FW]T[KR]',
#  'RIBOSOMAL_S6E': '[LIVM][STAMR]GG.[DG].{2}G.[PV]M',
#  'RIBOSOMAL_L29': '[KNQS][PSTLNH][^D][^F][LIVMFA][KRGSADN].[LIVYSTA][KR][KRHQS][DESTANQRL][LIV]A[KRCQVT][LIVMA]',
#  'RIBOSOMAL_L32E': 'F.R.{4}[KRL].{2}[KRT][LIVMFT].{3,5}WR[KR].{2}G',
#  'CLATHRIN_LIGHT_CHN_2': '[KR][DS].[SE][KR][LIVMF][KR].[LIVM][LIVMY][LIVM].L[KA]',
#  'RIBOSOMAL_L33': '[YW].[STKV].[KR][NSKQ].{3,4}[PATQS].{1,2}[LIVMF][EAQVSIT].{2}K[FYH][CSD]',
#  'PFKB_KINASES_1': '[AG]G.{0,1}[GAP].N[^AGLS][STA].{2}[^A].[^G][^GNKA][GS].{9}G',
#  'PFKB_KINASES_2': '[DNSK][PSTV].[SAG]{2}[GD]D.{3}[SAGV][AG][LIVMFYA][LIVMSTAP]',
#  'RIBOSOMAL_S5': 'G[KRQEA].{3}[FYVIM].[ACVTI].{2}[LIVMA][LIVMAT][AG][DN].{2,3}G.[LIVMA][GS].[SAG].{5,6}[DEQGHS][LIVMARFY].{2,3}[AS][LIVMFRY]',
#  'RIBOSOMAL_L16_1': '[KRG][KR].[GSAC][KRQVA][LIVMK][WY][LIVM][KRN][LIVM][LFY][APK]',
#  'GLYCOSYL_HYDROL_F17': '[LIVMKS].[LIVMFYWA]{3}[STAG]E[STACVI]G[WY]P[STN].[SAGQ]',
#  'FLAGELLA_BB_ROD': '[GTARYQ].[^R].{7}[LIVMYSTA]{2}[GSTA][STADEN]N[LIVM][SAN]N.[SADENFR][STV]',
#  'PTS_HPR_SER': '[GSTADE][KREQSTIV].[^EPRK][^VPGL].[KRDN]S[LIVMF]{2}[^EVPL][LIVM][^EATN].[LIVM][GADE]',
#  'LIF_OSM': '[PST].{4}F[NQ].K.{3}C.[LF]L.{2}Y[HK]',
#  'GH10_1': '[GTA][^QNAG][^GSV][LIVN].[IVMF][ST]E[LIY][DN][LIVMF]',
#  'GH9_2': '[HLY][AILMV][FIL]G.[NSTW].{2,4}[SCTV][FY][LIVMFY][SITV]G.{1,5}[GSY].{2}[AFPSTY][FLPSV].{2}[AILPQVM][HV][DHLS][KRS]',
#  'HEME_OXYGENASE': 'L[IV]AH[STACH]Y[STV][RT]Y[LIVM]G',
#  'AROMATIC_AA_PERMEASE_1': 'IG[GA]GM[LF][SA].P.{3}[SA]G.{2}F',
#  'AA_TRANSFER_CLASS_5': '[LIVFYCHT][DGH][LIVMFYAC][LIVMFYA].{2}[GSTAC][GSTA][HQR]K.{4,6}G.[GSAT].[LIVMFYSAC]',
#  'PLANT_LTP': '[LIVM][PA].{2}C.{1,2}[LIVM].{1,2}[LIVMST].[LIVMFY].{1,2}[LIVMF][STRD].{3}[DN]C.{2}[LIVM]',
#  'CHROMO_1': '[FYL].[LIVMC][KR]W.[GDNR][FYWLME].{5,6}[ST]W[ESV][PSTDEN].{2,3}[LIVMC]',
#  'AA_TRANSFER_CLASS_2': 'T[LIVMFYW][STAG]K[SAG][LIVMFYWR][SAG][^ENKR][^TNDR][SAG]',
#  'AA_TRANSFER_CLASS_3': '[LIVMFYWCS][LIVMFYWCAH].D[ED][IVA].{2,3}[GAT][LIVMFAGCYN].{0,1}[RSACLIH].[GSADEHRM].{10,16}[DH][LIVMFCAG][LIVMFYSTAR].{2}[GSA]K.{2,3}[GSTADNV][GSAC]',
#  'IRF_1': 'W.[DNH].{5}[LIVF].[IV]PW.H.{9,10}[DE].{2}[LIVF]F[KRQ].[WR]A',
#  'ALDOLASE_CLASS_II_1': '[FYVMT].{1,3}[LIVMH][APNT][LIVM].{1,2}[LIVM]H.DH[GACH]',
#  'TK_CELLULAR_TYPE': '[GA].{1,2}[DE].Y.[STAPV].C[NKR].[CH][LIVMFYWH]',
#  'SYNAPTOP': 'LSV[DE]C.NKT',
#  'ATPASE_C': '[GSTA]R[NQ]P.{5}[^A].[^F].{2}[LIVMFYW]{2}.{3}[LIVMFYW].[DE]',
#  'KS3_1': 'G[^A][^KGR].{2}[LIVMFTAP][^R].[AGC]C[STA]{2}[STAG].{2}[^LI][LIVMF]',
#  'PDEASE_II': 'H.HLDH[LIVM].[GS][LIVMA][LIVM]{2}.S[AP]',
#  'GLYCOSYL_HYDROL_F2_2': '[DENQLF][KRVW]N[HRY][STAPV][SAC][LIVMFS][LIVMFSA][LIVMFS]W[GSV].{2,3}NE',
#  'GLYCOSYL_HYDROL_F32': 'H.{2}[PV].{4}[LIVMA]NDPN[GA]',
#  'NA_NEUROTRAN_SYMP_1': 'W[RK]F[GPA][YF].{4}[NYHS]GG[GCA].[FY]',
#  'HISOL_DEHYDROGENASE': '[IVTPM][DEG].{2,3}[AYEPQ]G[PT][ST][ED][LIVSTA][LIVMAECGFT][LIVMA][LIVMAYF][ACNDSTI].{2,3}[ACNGVST].{4,6}[LIVMAC][AVLKIT][SACLYWNRMTV][DEG][LIVMFCA][LIVMKFR][SAGVI].{2}EH',
#  'OSTEONECTIN_1': 'C.[DNS].{2}C.{2}G[KRH].C.{6,7}P.C.C.{3,5}CP',
#  'OSTEONECTIN_2': 'FP.R[IM].DWL.[NQ]',
#  'IGPS': '[LIVMFY][LIVMC].E[LIVMFYC]K[KRSPQV][STAHKRYC]SP[STRK].{3,7}[LIVMFYST]',
#  'C_TYPE_LECTIN_1': 'C[LIVMFYATG].{5,12}[WL][^T][DNSR][^C][^LI]C.{5,6}[FYWLIVSTA][LIVMSTA]C',
#  'HIS_ACID_PHOSPHAT_1': '[LIVM].{2}[LIVMA].{2}[LIVM].RH[GN].R.[PAS]',
#  'RECF_1': '[LIFV].{6}[LIF][LIVF].[GSDE][GSTADNPE][PASG].{2}RR.[FYW][LIVMF][DN]',
#  'RECF_2': '[LIV][LIFYMV].[LIVM]D[DEA][LIVF].{2}[EHCGK]LD.{2}[KRH].{3}[LIVF]',
#  'PTN_MK_1': 'S[DE]C.[DE]W.W.{2}C.P.[SN].DCG[LIVMA]G.REG',
#  'PTN_MK_2': 'C[KR][LIVM]PCNWKK.FGA[DE]CKY.F[EQ].WG.C',
#  'TISSUE_FACTOR': 'WK.KC.{2}T.[DEN]TECD[LIVM]TDE',
#  'HTH_LUXR_1': '[GDC].{2}[NSTAVY].{2}[IV][GSTA].{2}[LIVMFYWCT].[LIVMFYWCR].{3}[NST][LIVM].{2}[^T].{2}[NRHSA][LIVMSTA].{2}[KR]',
#  'GMC_OXRED_1': '[GA][RKNC].[LIVW]G{2}[GST]{2}.[LIVM][NH].{3}[FYWA].{2}[PAG].{5}[DNESHQA]',
#  'GMC_OXRED_2': '[GS][PSTA].{2}[ST][PS].[LIVM]{2}.{2}SG[LIVM]G',
#  'RCC1_1': 'G.ND.{2}[AV]LGR.T',
#  'RCC1_2': '[LIVMFA][STAGC]{2}G.[^TAV]H[STAGLI][LIVMFA][^KI][LIVM]',
#  'GHMP_KINASES_ATP': '[LIVM][PK].[GSTA].{0,1}G[LM][GS]SS[GSA][GSTAC]',
#  'RIBOSOMAL_S19E': 'P.{6}[SANG].{2}[LIVMAC].R.[ALIV][LV][QH].L[EQ]',
#  'IMP_1': '[FWV].{0,1}[LIVM]DP[LIVM]D[SG][ST].{2}[FYA].{0,1}[HKRNSTY]',
#  'IMP_2': '[WYV]D.[AC][GSA][GSAPV].[LIVFACP][LIVM][LIVAC].{3}[GH][GA]',
#  'CYTOSOL_AP': '[NS][TS]DAEGR[LVMI]',
#  'RIBOSOMAL_S4': '[LIVM][DERA].R[LI].{3}[LIVMC][VMFYHQL][KRTS].{3}[STAGCVF].[ST].{3}[SAI][KRQ].[LIVMF]{2}',
#  'BROMODOMAIN_1': '[STANVFHG].{2}[FAS].{4}[DNSPAKT].{0,7}[DENQTFG]Y[HFYLRKT].{2}[LIVMFY].{3}[LIVM].{4}[LIVM].{6,10}Y.{12,13}[LIVM].{2}N[SACF].{2}[FY]',
#  'RIBOSOMAL_L30': '[IVTAS][LIVM].{2}[LF].[LI].[KRHQEG].{2}[STNQH].[IVTR].{10}[LMSN][LIV].{2}[LIVA].{2}[LMFY][IVT]',
#  'PILI_CHAPERONE': '[LIVMFY][APN].[DNS][KREQ]E[STR][LIVMAR].[FYWTE].[NCS][LIVM].{2}[LIVM]P[PAS]',
#  'DNAJ_1': '[FY][^GL].[LIVMA][^IP].{2}[FYWHNT][DENQSA].L.[DN].{3}[KR][^F][^P][FYI]',
#  'PII_GLNB_CTER': '[ST].{3}G[DY]G[KR][IV][FW][LIVM].{2}[LIVM]',
#  'THIOL_PROTEASE_HIS': '[LIVMGSTAN][^IEVK]H[GSACE][LIVM][^GPSI][LIVMAT]{2}G[^SLAG][GSADNH]',
#  'THIOL_PROTEASE_ASN': '[FYCH][WI][LIVT].[KRQAG]N[ST]W.{3}[FYW]G.{2}G[LFYW][LIVMFYG].[LIVMF]',
#  'COMPLEX1_75K_1': 'P.{2}C[YWSD].{7}[GA].CR.C',
#  'COMPLEX1_75K_2': 'CP.C[DE].[GS]{2}.C.LQ',
#  'COMPLEX1_75K_3': 'RC[LIVM].C.RC[LIVMT].[LMFY]',
#  'COMPLEX1_51K_1': 'G[AM]G[AR]Y[LIVM]CG[DE]{2}[STA]{2}[LIM]{2}[END]S',
#  'COMPLEX1_51K_2': 'E[ST]CG.C.PCR.G',
#  'RIBOSOMAL_S13_1': '[KRQSEAT][GS].RH.{2}[GSNHKLCD].{2}[LIVMCT][RNH]GQ',
#  'THYMID_PHOSPHORYLASE': '[SA][GS]R[GA][LIV].{2}[TAP][GAS]GT.D.[LIVMF][EDS]',
#  'RIBONUCLEASE_P': '[LIVMFYSNAD].{2}A.{2}R[NH][KRQLYAT][LIVMFSA][KRA]R.[LIVMTA][KR]',
#  'G_PROTEIN_RECEP_F2_1': 'C.{3}[FYWLIV]D.{3,4}C[FW].{2}[STAGV].{8,9}C[PF]',
#  'G_PROTEIN_RECEP_F2_2': '[QL]G[LMFCAV][LIVMFTA][LIV].[LIVFSTM][LIFHV][VFYHLG]C[LFYAVI].[NKRQDS].{2}[VAI]',
#  'RIBOSOMAL_L9': 'G.{2}[GNF].{4}[VAI].{2}G[FY].{2}[NH][FYWL]L.{5}[GA].{3}[STNG]',
#  'TNFR_NGFR_1': 'C.{4,6}[FYH].{5,10}C.{0,2}C.{2,3}C.{7,11}C.{4,6}[DNEQSKP][^PD][^CP]C',
#  'GLYCOSYL_HYDROL_F1_2': 'F.[FYWM][GSTA].[GSTA].[GSTA]{2}[FYNH][NQ].E.[GSTA]',
#  'PRD_1': '[ST][DM]H[LIC].{2}[FA][LIY][EQK]R.{2}[QNKA]',
#  'GLYCOSYL_HYDROL_F6_1': 'V.Y.{2}P.RDC[GSAF].{2}[GSA]{2}.G',
#  'GLYCOSYL_HYDROL_F6_2': '[LIVMYA][LIVA][LIVT][LIV]EPD[SAL][LI][PSAG]',
#  'FORK_HEAD_1': '[KR]P[PTQ][FYLVQH]S[FY].{2}[LIVM].{3,4}[AC][LIM]',
#  'FORK_HEAD_2': 'W[QKR][NSD][SA][LIV]RH',
#  'GLYCOSYL_HYDROL_F5': '[LIV][LIVMFYWGA]{2}[DNEQG][LIVMGST][^SENR]NE[PV][RHDNSTLIVFY]',
#  'FERM_1': 'W[LIV].{3}[KRQ].[LIVM].{2}[QH].{0,2}[LIVMF].{6,8}[LIVMF].{3,5}F[FY].{2}[DENS]',
#  'FERM_2': '[HYW].{9}[DENQSTV][SA].{3}[FYC][LIVM].{2,3}[ACVWD].{2}[LM].{2}[FY][GM].[DENQSTH][LIVMFYS]',
#  'T2SP_E': '[LIVM]R.{2}PD.[LIVM]{3}GE[LIVM]RD',
#  'VINCULIN_1': '[KR].[LIVMF].{3}[LIVMA].{2}[LIVM].{6}RQQEL',
#  'VINCULIN_2': '[LIVM].[QA]A.{2}W[IL].[DN]P',
#  'DHDPS_1': '[GSA][LIVM][LIVMFY].{2}G[ST][TG]GE[GASNF].{6}[EQ]',
#  'DHDPS_2': 'Y[DNSAH][LIVMFAN]P.{2}[STAV].{2,3}[LIVMFT].{13,14}[LIVMCF].[SGA][LIVMFNS]K[DEQAFYH][STACI]',
#  'COMPLEX1_ND1_1': 'G[LIVMFYKRSAQT][LIVMAGPF][QAM].[LIVMFYCA].D[AGIM][LIVMFTA][KS][LVMYSTI][LIVMFYGA].[KRE][EQG]',
#  'COMPLEX1_ND1_2': 'PFD[LIVMFYQN][STAGPVMI]E[GACS]E.{0,2}[EQLN][LIVMS].{1,2}G',
#  'GAS_VESICLE_A_2': 'R[LIVA]{3}A[GS][LIVMFY].[TK].{3}[YFI][AG]',
#  'D_2_HYDROXYACID_DH_2': '[LIVMFYWA][LIVFYWC].{2}[SAC][DNQHR][IVFA][LIVF].[LIVF][HNI].P.{4}[STN].{2}[LIVMF].[GSDN]',
#  'D_2_HYDROXYACID_DH_3': '[LMFATCYV][KPQNHAR].[GSTDNK].[LIVMFYWRC][LIVMFYW]{2}N.[STAGC]R[GP].[LIVH][LIVMCT][DNVE]',
#  'V8_HIS': '[ST]G[LIVMFYW]{3}[GN].{2}T[LIVM].T.{2}H',
#  'V8_SER': 'T.{2}[GC][NQ]SGS.[LIVM][FY]',
#  'AAA': '[LIVMTR].[LIVMT][LIVMF].[GATMC][ST][NS].{4}[LIVM]D.[AS][LIFAV].{1,2}R',
#  'SIGMA54_INTERACT_1': '[LIVMFY]{3}.G[DEQ][STE]G[STAV]GK.{2}[LIVMFY]',
#  'SIGMA54_INTERACT_2': '[GS].[LIVMFA].{2}[AS][DNEQASH][GNEKT]G[STIM][LIVMFY]{3}[DE][EK][LIVM]',
#  'DAO': '[LIVM]{2}H[NHA]YG.[GSA]{2}.G.{5}G.A',
#  'WD_REPEATS_1': '[LIVMSTAC][LIVMFYWSTAGC][LIMSTAG][LIVMSTAGC].{2}[DN].[^P][LIVMWSTAC][^DP][LIVMFSTAG]W[DEN][LIVMFSTAGCN]',
#  'BETA_AMYLASE_2': 'G.[SA]GE[LIVM]RYPSY',
#  'MAP_1': '[MFY].GHG[LIVMC][GSHN].{3}H.{4}[LIVM].{1,2}[HN][YWVHF]',
#  'CHAPERONINS_CPN10': '[LIVMFY].P[ILT].[DEN][KR][LIVMFA]{3}[KREQS].{8,9}[SG].[LIVMFY]{3}',
#  'ZP_1': '[LIVMFYW].{7}[STAPDNLR].{3}[LIVMFYW].[LIVMFYW].[LIVMFYW].{2}C[LIVMFYW].[STA][PSLT].{2,4}[DENSG].[STADNQLFM].{6}[LIVM]{2}.{3,4}C',
#  'RHODANESE_2': '[AV].{2}[FY][DEAP]G[GSA][WF].E[FYW]',
#  'SASP_2': '[KRC][SAQ].G.[VF]G[GA].[LIVM].[KR][KRC][LIVM]{2}',
#  'NFYB_HAP3': 'C[VA][ST]E.ISF[LIVM]T[SGC]EA[SCN][DE][KRQ]C',
#  'NFYA_HAP2_1': '[FY]VN[AS]KQ[FY].{2}I[ILM][KR]RR.{2}RAK[LA]E',
#  'ALDEHYDE_DEHYDR_GLU': '[LIVMFGA]E[LIMSTAC][GS]G[KNLM][SADN][TAPFV]',
#  'SIGMA54_INTERACT_3': '[FYW]P[GS]N[LIVM]R[EQ]L.[NHAT]',
#  'GLYCO_HORMONE_BETA_2': '[PA]VA.{2}C.C.{2}C.{4}[STDAI][DEY]C.{6,8}[PGSTAVMI].{2}C',
#  'DEAH_ATP_HELICASE': '[GSAH].[LIVMF]{3}DE[ALIV]H[NECR]',
#  'DNA_PHOTOLYASES_1_2': '[DN]R.R[LIVM][LIVMN].[STA][STAQ]F[LIVMFA].K.L.{2,3}W[KRQ]',
#  'NIFH_FRXC_2': 'D.LGDVVCGGF[AGSP].P',
#  'ENT_VIR_OMP_1': 'G[LIVMFY]N[LIVM]KYRYE',
#  'ENT_VIR_OMP_2': '[FYW].{2}G.GY[KR]F$',
#  'ETF_ALPHA': '[LI]Y[LIVM][AT].[GA][IV][SD]G.[IV]Q[HP].{2}G.{6}[IV].A[IV]N',
#  'DNA_LIGASE_A1': '[EDQH][^K]K[^VEDI][DN]G[^GLYN]R[GACIVM]',
#  'GH9_3': '[FYW].D.{4}[FYW].{3}E.[STA].{3}N[STA]',
#  'NITROGENASE_1_1': '[LIVMFYH][LIVMFST]H[AG][AGSP][LIVMNQA][AG]C',
#  'RIBOSOMAL_L6_2': '[QLS].{3}[LIVM].{2}[KRWYF].{2}R.F.DG[LIVM][YF][LIVM].{2}[KR]',
#  'RIBOSOMAL_L16_2': 'RMG.[GR]KG.{4}[FWKR]',
#  'GM_CSF': 'CP[LP]T.E[ST].C',
#  'OKR_DC_1': '[STAV].S.HK.{2}[GSTAN]{2}.[STA]Q[STA]{2}',
#  'PROK_CO2_ANHYDRASE_1': 'C[SA]DSR[LIVM].[AP]',
#  'PROK_CO2_ANHYDRASE_2': '[EQ][YF]A[LIVM].{2}[LIVM].{4}[LIVMF]{3}.GH.{2}CG',
#  'PRION_2': 'E.[ED].K[LIVM]{2}.[KR][LIVM]{2}.[QE]MC.{2}QY',
#  'GLYCOSYL_HYDROL_F31_2': 'G[AVP][DT][LIVMTAS][CG]G[FY].{3}[STP].{3}L[CL].RW.{2}[LVMI][GSA][SA][FY].P[FY].R[DNA]',
#  'PRO_ENDOPEP_SER': 'D.{3}A.{3}[LIVMFYW].{14}G.S.GG[LIVMFYW]{2}',
#  'RIBOSOMAL_L30E_1': '[STA].{5}G.[QKRN].{2}[LIVMQ][KRQT].{2}[KR].[GS].{2}[KQ].[LIVM]{3}',
#  'PGM_PMM': '[GSA][LIVMF].[LIVM][ST][PGA]SH[NIC]P',
#  'LIPOXYGENASE_1': '[HQ][EQ].{3}H.[LMA][NEQHRCS][GSTA]H[LIVMSTAC]{2}.E',
#  'RIBOSOMAL_S17E': '[IVDYPKS].[ST]K.[LIVMTF][RIKM]N.[IV][SA]G[FY].[TV][HKRA]',
#  'NA_DICARBOXYL_SYMP_1': 'P.{0,1}[GP][DES].[LIVMF]{2}.[LIVMA][LIVM][KREQS][LIVMG][LIVM][LIVMF].[PS]',
#  'NA_DICARBOXYL_SYMP_2': 'P.G.[STA].[NT][LIVMCP]D[GA][STANQF].[LIVM][FY].{2}[LIVM].{2}[LIVM][FY][LIV][SA][QH]',
#  'SIGMA70_1': '[DE][LIVMF]{2}[HEQS].G.[LIVMFA]GL[LIVMFYE].[GSAM][LIVMAP]',
#  'SIGMA70_2': '[STN].{2}[DENQ][LIVMT][GAS].{4}[LIVMF][PSTG].{3}[LIVMA].[NQR][LIVMA][EQH].{3}[LIVMFWK].{2}[LIVM]',
#  'SIGMA54_1': 'P[LIVM].[LIVM].{2}[LIVM]A.{2}[LIVMFT].{2}[HS].ST[LIVM]SR',
#  'SIGMA54_2': 'RRT[IV][ATN]KYR',
#  'GLYCOSYL_HYDROL_F2_1': 'N.[LIVMFYWD]R[STACN]{2}HYP.{4}[LIVMFYWS]{2}.{3}[DN].{2}G[LIVMFYW]{4}',
#  'RASGEF': '[VI]P[FYWVI].[GPSV].{2}[LIVMFYK].[DNE][LIVM].{13,35}[IVL]N[FYME].K',
#  'FTHFS_1': '[GN][LIVMS]KG[GST][AG][AST]G[GAS]G[YLHRKF]',
#  'FTHFS_2': 'V[ASV][TS][IVLA][RQ][AGS][LIM][KER].[HN][GAS][GLKD]',
#  'POLYPRENYL_SYNTHASE_1': '[LIVM]{2}.DD.{2,4}D.{4}RR[GH]',
#  'SRP1_TIP1': 'PWY[ST]{2}RL',
#  'GERMIN': 'G.{4}H.HP.[AGS].E[LIVM]',
#  'AP_NUCLEASE_F1_1': '[APF]D[LIVMF]{2}[^T][LIVM]QE[^G]K',
#  'AP_NUCLEASE_F1_2': 'D[ST][FY][RP][KHQ].{7,8}[FYWD][ST][FYW]{2}',
#  'AP_NUCLEASE_F1_3': 'N.G.R[LIVM]D[LIVMFYH].[LV].S',
#  'AP_NUCLEASE_F2_1': 'H[GSAD].Y[LIF][LIMN]N[LIVMFCAP][AGC]',
#  'AP_NUCLEASE_F2_2': '[GSARY][LIVMF][CT][LIVMFY]DTCH',
#  'AP_NUCLEASE_F2_3': '[LIVMFW]H.N[DEG][SA].{4}[GNAQ].{3}D.H',
#  'RIBOSOMAL_S16': '[LIVMT].[LIVM][KR]L[STAK]R[^E]G[AKR]',
#  'RIBOSOMAL_S26E': '[YH]C[VI][SA]CAIH',
#  'THIOLASE_2': 'N.{2}GG.[LIVM][SA].GHP.[GAS].[ST]G',
#  'ADOHCYASE_1': '[GSAP][CS]N.[FYLM]S[ST][QALKHD][DENG].[AV][AVTS][ADERQ][ACSG][LIVMCG]',
#  'ADOHCYASE_2': '[GA][KSR].{3}[LIV].G[FY]G.[VC]G[KRL][GA].{1,2}[ASC]',
#  'MAM_1': '[GE].[LIVMFY]{2}.{3}[STA].{10,11}[LV].{4}[LIVMF].{6,7}C[LIVM].F.[LIVMFY].{3}[GSC]',
#  'DH_1': '[LM].{2}[LIVMFYWGS][LI].{2}[PEQ][LIVMRF].{2}[LIVM].[KRS].{2}[LT].[LIVM].[DEQN][LIVM].{3}[STM]',
#  'PEP_ENZYMES_2': '[DEQSKN].[LIVMF][SA][LIVMF]G[ST]ND[LIVM].Q[LIVMFYGT][STALIV][LIVMFY][GAS].{2}R',
#  'BETA_LACTAMASE_B_1': '[LI].[STN][HN].H[GSTAD]D.{2}G[GP].{7,8}[GS]',
#  'BETA_LACTAMASE_B_2': 'P.{3}[LIVM]{2}.G.C[LIVMF]{2}K',
#  'RF_PROK_I': '[ARH][STA].G.GGQ[HNGCSY][VI]N.{3}[ST][AKG][IV]',
#  'NIFH_FRXC_1': 'E.GGP.{2}[GA].GC[AG]G',
# ...
#  'ADX': 'C.{2}[STAQ].[STAMV]C[STA]TC[HR]',
#  'AIPM_HOMOCIT_SYNTH_1': 'LR[DE]G.Q.{4}[^L].{5}K',
#  'AIPM_HOMOCIT_SYNTH_2': '[LIVMFW].{2}H.H[DN]D.G.[GAS].[GASLI]',
#  'EPO_TPO': 'P.{4}CD.R[LIVM]{2}.[KR].{14}C',
#  'DPS_1': 'H[FW].[LIVM].G.{5}[LV]H.{3}[DE]',
#  'DPS_2': '[LIVMFY][DH].[LIVM][GA]ER.{3}[LIF][GDN].{2}[PA]',
#  'GLUCOAMYLASE': '[STN][GP].{1,2}[DE].WEE.{2}[GS]',
#  'CYTO_HEME_LYASE_1': 'HN.{2}NE.{2}W[NQKRS].{4}WE',
#  'CYTO_HEME_LYASE_2': 'PFDRHDW',
#  'DEHYDRIN_2': '[KR][LIM]K[DE]K[LIM]PG',
#  'EF1BD_1': '[DEG]{2}[DEK][DE][LIVMF]DLFG',
#  'EF1BD_2': '[IV]QS.D[LIVM].A[FWM][DNQS]K[LIVM]',
#  'MARCKS_1': 'GQENGHV[KR]',
#  'MARCKS_2': 'ETPK{5}.{0,1}FSFKK.FKLSG.SFK[KR][NS][KR]KE',
#  'RIBOSOMAL_L36': '[CHDS].{2}[CND].{2}[LIVM].R.{3}[LIVMNR].[LIVM].[CN].{3,4}[KRSN][HLFR].[QCAV].Q',
#  'GREAB_1': '[EKH][LHVI].{9,10}[IVNLR].{3}[LIV].{6}GD.{2}EN[GSA].Y',
#  'GREAB_2': 'S.{2}S[PK][LIVMF][AG].[SAGNE][LIVM][LIVY].{4}[DNG][DE]',
#  'RIBOSOMAL_L27': 'G.[LIVM]{2}.RQRG.{5}G',
#  '25A_SYNTH_1': 'GS.[AG][KRN].T.L[KRN].{3}[DE].[DET][LM][VI].F',
#  '25A_SYNTH_2': 'RP[VI]ILDP.[DE]PT',
#  'OMPTIN_1': 'WTD.S.HP.T',
#  'OMPTIN_2': 'AGYQE[ST]R[FYW]S[FYW][TN]A.GG[ST]Y',
#  'ALADH_PNT_1': '[GA][LIVM][PKV].{0,1}E.{3}[NG]E.{1,3}R[VT][AG].[ST]P.[GSTVN][VA].{2}[LI].[KRHNGSED].G',
#  'ALADH_PNT_2': '[LIVM][LIVMF]G[GAV]G.[AV][GA].{2}[SA].{3}[GA].[SGR][LIVM][GN]A.V.{3}[DE]',
#  'INTERLEUKIN_4_13': '[LI].E[LIVM]{2}.{4,5}[LIVM][TL].{5,7}C.{4}[IVA].[DNS][LIVMA]',
#  'SUMT_1': '[LIVM][GS][STAL]GPG.{3}[LIVMFY][LIVM]T[LIVM][KRHQG][AG]',
#  'SUMT_2': '[VW].{2}[LI].{2}[GA][DT].{3}[FYW][GS].{8}[LIVFA].{5,6}[LIVMFYWPAC].[LIVMY].[PN]G',
#  'XPG_1': '[VILT][KREIT][PV].[FYIL][VI][FW]DG.{2}[PILHSTF].[LVCQMFAKS]K',
#  'XPG_2': '[GSN][LIVM][PERD][FYSCV][LIVM].AP.EA[DE][PAS][QSE][CLM]',
#  'DALA_DALA_LIGASE_1': 'H[GN].{2}[GC]E[DNT]G.[LIVMAFT][QSAPH][GSA]',
#  'DALA_DALA_LIGASE_2': '[LIVAMSFT].{3}[GAHDVSI].[GSAIVCT]R[LIVMCAFST][DE][LIVMFAYGT][LIVMFAR].{7,12}[LIVWCAF].[EK][LIVAPMT]N[STPA].P[GA]',
#  'CAP_GLY_1': '[GD].{0,10}[FYWA].{0,1}G[LIVM].{0,2}[LIVMFYD].{0,7}G[KN][NHW].{0,1}G[STARCV].{0,2}[GD].{0,2}[LY][FC]',
#  'HTH_ARSR_1': 'C.{2}D[LIVM].{6}[ST].{4}S[HYR][HQ]',
#  'MCM_1': 'G[IVT][LVAC]{2}[IVT]D[DE][FL][DNST]',
#  'COX5B_1': '[LIVM]{2}[FYW].{10}C.{2}CG.{2}[FY]KL',
#  'GLY_RADICAL_1': '[STIV].R[IVT][CSA]GY[^GI][GACV]',
#  'BETA_ELIM_LYASE': '[YV].D.{3}MS[GA]KKD.[LIVMF][LIVMAG].[LIVM]GG',
#  'PROTEASOME_BETA_1': '[LIVMACFT][GSA][LIVMF].[FYLVGAC].{2}[GSACFYI][LIVMSTACF][LIVMSTAC][LIVMFSTAC][GACI][GSTACV][DES].{15,16}[RK].{12,13}G.{2}[GSTA]D',
#  'SPASE_II': '[LIVM].[GASF][GA][GAST][LIVMTF][GAS]N[LVMFGIA][LIVFYGT]D[RIK][LIVMFAC]',
#  'GUANYLATE_KINASE_1': '[TS][ST]R.{2}[KR].{2}[DE].{2}[GA].{2}Y.[FY][LIVMKHRT]',
#  'PREPHENATE_DEHYDR_1': '[FY].[LIVM].{2}[LIVM].{5}[DN].{5}TRF[LIVMW].[LIVM]',
#  'PREPHENATE_DEHYDR_2': '[LIVM][ST][KR][LIVMF]E[ST]RP',
#  'GTP_CYCLOHYDROL_1_1': '[DENGQST][LIVMPF][LIVM].{1,2}[KRNQELD][DENKGS][LIVM].{3}[STG].C[EP]HH',
#  'GTP_CYCLOHYDROL_1_2': '[SA].[RK].Q[LIVMT]QE[RNAK][LIM][TSNV]',
#  'GALANIN': 'GWTLNSAGYLLGP',
#  'OX2_COVAL_FAD': 'P.{7}[^L].{2}[DE][LIVM].{3}[LIVM].{9,12}[LIVM].{3}[GSA][GSTCHRQ]GH',
#  'CALSEQUESTRIN_1': '[EQ][DE]GL[DN]FP.YDG.DRV',
#  'CALSEQUESTRIN_2': '[DE]LEDW[LIVM]EDVL.G.[LIVM]NTEDDD',
#  'UBIQUITIN_ACTIVAT_2': 'P[LIVMG]CT[LIVM][KRHA].[FTNM]P',
#  'CPSASE_1': '[FYV][PS][LIVMC][LIVMA][LIVM][KR][PSA][STA].{3}[SG]G.[AG]',
#  'CPSASE_2': '[LIVMF][LIMN]E[LIVMCA]N[PATLIVM][KR][LIVMSTAC]',
#  'CYS_MET_METAB_PP': '[DQ][LIVMFY].{3}[STAGCN][STAGCIL]TK[FYWQI][LIVMF].G[HQD][SGNH]',
#  'RENAL_DIPEPTIDASE_1': '[LIVM]EG[GA].{2}[LIVMF].{6}L.{3}Y.{2}G[LIVM]R',
#  'CLPAB_1': '[DA][AI][SGA][NQS][LIVMF]{2}K[PT].[LM].{2}G',
#  'CLPAB_2': '[RGT][LIVMFY][DN].[ST]E[LIVMFY].[ED][KRQEAS].[STA].[STAD][KRS][LIVM].G[STAP]',
#  'NA_GALACTOSIDE_SYMP': '[DG].{3}G.{3}[DN].{6,8}[GA][KRHQ][FSAR][KRL][PT][FYW][LIVMWQ][LIV].{0,1}[GAFV][GSTA]',
#  'NA_ALANINE_SYMP': 'GG.[GA]{2}[LIVM]FWMW[LIVM].[STAV][LIVMFA]{2}G',
#  'T2SP_F': '[KRQ][LIVMAW].{2}[SAIV][LIVM].[TY]P.{2}[LIVM].{3}[STAGV].{6}[LMY].{3}[LIVMF]{2}P',
#  'T2SP_D': '[GRH][DEQKG][STVM][LIVMA]{3}[GA]G[LIVMFY].{11}[LIVM]P[LIVMFYWGS][LIVMF][GSAE].[LIVMS]P[LIVMFYW][LIVMFYWS].{2,3}[LV][FK]',
#  'IDO_1': 'GGS[AN][GA]QSS.{2}Q',
#  'IDO_2': '[FY]L[DQ][DE][LIVM].{2}YM.{3}H[KR]',
#  'ODR_DC_2_1': '[FY][PA].K[SACV][NHCLFW].{4}[LIVMF][LIVMTA].{2}[LIVMA].{3}[GTE]',
#  'ODR_DC_2_2': '[GSA].{2,6}[LIVMSCP].[^N][LIVMF][DNS][LIVMCA]GGG[LIVMFY][GSTPCEQ]',
#  'ACB_1': '[PTLV][GSTA].[DENQA].[LMFK].{2}[LIVMFY][YV][GSA].[FYH]KQ[GSAV][STL].G',
#  'NI_HGENASE_CYTB_1': 'R[LIVMFYW].HW[LIVM].{2}[LIVMF][STAC][LIVM].{2}L.[LIVM]TG',
#  'NI_HGENASE_CYTB_2': '[RH][STA][LIVMFYW]H[RH][LIVM].{2}W.[LIVMF].{2}F.{3}H',
#  'OSTEOPONTIN': '[KQ].[TA].{2}[GA]SSEEK',
#  'EPSP_SYNTHASE_2': '[KR].[KH]E[CSTVI][DNE]R[LIVMY].[GSTAVLD][LIVMCTF].{3}[LIVMFA].{2}[LIVMFCGANY]G',
#  'ILVD_EDD_1': 'CDK.{2}P[GA].{3}[GA]',
#  'ILVD_EDD_2': '[SGALC][LIMF][LIVMF]TD[GA]R[LIVMFY]S[GA][GAV][ST]',
#  'CNMP_BINDING_1': '[LIVM][VIC].[^H]G[DENQTA].[GAC][^L].[LIVMFY]{4}.{2}G',
#  'CNMP_BINDING_2': '[LIVMF]GE.[GAS][LIVM].{5,11}R[STAQ]A.[LIVMA].[STACV]',
#  'HIT_1': '[NQAR].{4}[GSAVY].[QFLPA].[LIVMY].[HWYRQ][LIVMFYST]H[LIVMFT]H[LIVMF][LIVMFPT][PSGAWN]',
#  'NUDIX_BOX': 'G.{5}E.{4}[TAGCV][LIVMACF].R[EL][LIVMFGSTA].[EA]E.[GNDTHR]',
#  'HTH_DEOR_1': 'R[^G].{2}[LIVM].{3}[LIVM].{16,17}[STA].{2}T[LIVMA][RH][KRNAQ]D[LIVMF]',
#  '3_HYDROXYISOBUT_DH': '[LIVMFY]{2}GLG.[MQ]G.{2}[MA][SAV].[SNHR]',
#  'LACY_1': 'G[LIVM]{2}.D[RK]LGL[RK]{2}.[LIVM]{2}W',
#  'LACY_2': 'P.[LIVMF]{2}NR[LIVM]G.KN[STA][LIVM]{3}',
#  'EPENDYMIN_1': '[DE][SQLM][KAH][NT][QEK][SQ]C[SRKH].[EQKM][STM]L',
#  'EPENDYMIN_2': 'F.[PL]P[STA][FYT]C[DEQ][GAMI][LVMA].[TLF][DE][DEK]',
#  'RNA_POL_PHAGE_1': 'P[LIVM].{2}D[GA][ST][AC][SN][GA][LIVMFY]Q',
#  'CYS_SYNTHASE': 'K.E.{3,4}[PAF][STAGC].S[IVAPM]K.R.[STAG].{2}[LIVM]',
#  'GLUTAMATE_5_KINASE': '[GSTNAD].{2}[GAS].G[GC][IM].[STAG]K[LIVMCT].[SAI][TCAGFS].{2}[GALVCMI]',
#  'CYT_DCMP_DEAMINASES_1': '[CH][AGV]E.{2}[LIVMFGAT][LIVM].{17,33}PC.{2,8}C.{3}[LIVM]',
#  'GTP1_OBG': 'D[LIVMA]PG[LIVM]{2}[DEYPKQV][GN]A.{2}G.G',
#  'UROD_1': '[SP][IVCLAM]W[LIVMFYC][LM]R[QR][AVS]GR',
#  'UROD_2': '[LIMF][GAVS]F[STAGCV][STAGC].[PA][FWYV]T[LIVM].{2}Y.{2,3}[ADE][GK]',
#  'MR_MLE_1': '[AT].[SAGCN][SAGC][LIVM][DEQ].A[LA].[DE][LIA].[GA][KRQ].{4}[PSA][LIV].{2}L[LIVMF]G',
#  'MR_MLE_2': '[LIVF].{2}D.[NH].{7}[ACL].{6}[LIVMF].{7}[LIVM]E[DENQ]P',
#  'UPF0029': 'G.{2}[LIVM]{2}.{2}[LIVM].{4}[LIVM].{5}[LIVM]{2}.R[FYW]{2}GG.{2}[LIVM]G',
#  'DHODEHASE_1': '[GSA].{4}[GK][GSTA][LIVFSTA][GST].{3}[NQRK].G[NHY].{2}P[RTV]',
#  'DHODEHASE_2': '[LIVM]{2}[GSA].GG[IV].[STGDN].{3}[ACV].{2}[^A][^R].[^L]GA',
#  'ADH_IRON_1': '[STALIV][LIVF].[DE].{6,7}P.{4}[ALIV].[GST].{2}D[TAIVM][LIVMF].{4}E',
#  'SYNTAXIN': '[RQLKA].{3}[LIVMAW].{2}[LIVM][ESHLKAGQV].{2}[LIVMT].[DEVMNRAST][LIVMT].{2}[LIVMQ][FSAQGVM].{2}[LIVMF].{3}[LIVT].{2}Q[GADEQVST].{2}[LIVMA][DNQTEI].[LIVMF][DESVHAG].{2,3}[LIVM]',
#  'PI3_4_KINASE_1': '[LIVMFAC]K.{1,3}[DEA][DE][LIVMCP]RQ[DE].{4}Q',
#  'PI3_4_KINASE_2': '[GSET].[AVE].{3}[LIVM].{2}[FYHW][LIVM]{2}.[LIVMFN].DR[HNG].{2}N',
#  'ASN_GLN_ASE_2': '[GA].[LIVM].{2}HGTDT[LIVM]',
#  'DNASE_I_2': 'GDFNA.C[SAK]',
#  'DNASE_I_1': '[LIVM]{2}[AP][LQ]H[STA][STAE]P.{5}E[LIVM][DN].L.[DE]V',
#  'NITRIL_CHT_1': 'G.{2}[LIVMFY]{2}.[IF].E.{2}[LIVM].GYP',
#  'NITRIL_CHT_2': 'G[GAQ].{2}C[WA]E[NH].{2}[PST][LIVMFYS].[KR]',
#  'TRANSGLYCOSYLASE': '[LIVM].{3}ES.{3}[AP].{3}S.{5}G[LIVM][LIVMFYW].[LIVMFYW].{4}[SAG]',
#  'ASP_GLU_RACEMASE_1': '[IVA][LIVM].C.{0,1}N[ST][MSA][STH][LIVFYSTANK]',
#  'ASP_GLU_RACEMASE_2': '[LIVM]{2}.[AG]CT[DEH][LIVMFY][PNGRS].[LIVM]',
#  'OLEEI': '[EQT]G.VYCD[TNP]CR',
#  'LYSYL_OXIDASE': 'W.WH.CH.H[YN]HS[MI][DE]',
#  'TREHALASE_1': 'PGGRF.E.Y.WD.Y',
#  'TREHALASE_2': 'QWD.P.[GAV]W[PAS]P',
#  'PIR_REPEAT_1': 'SQ[IV][STGNH]DGQ[LIV]Q[AIV][STA]',
#  'RDS_ROM1': 'D[GS]VPF[ST]CCNP.SPRPC',
#  'CUTINASE_2': 'C.{3}D.[IV]C.G[GST].{2}[LIVM].{2,3}H',
#  'MOLYBDOPTERIN_PROK_3': 'A.{3}[GDTN][IF].[DNQTKEH].[DEAQ].[LIVM].[LIVMC].[NS].{2}[GS].{4,5}[AV].[LIVMEF][STY]',
#  'FGGY_KINASES_1': '[MFYGS].[PST].{2}K[LIVMFYW][^G]W[LIVMF][^E][DENQTKR][ENQH]',
#  'GLYOXALASE_I_1': '[HQ][IVT].[LIVFY].[IV].{4}[^E][STA].{2}F[YM].{2,3}[LMF]G[LMF]',
#  'GLYOXALASE_I_2': 'G[NTKQ].{0,5}[GA][LVFY][GH]H[IVF][CGA].[STAGLE].{2}[DNC]',
#  'RIBOSOMAL_L35': 'K[STNV][^F].[GSAM][SAILV].[KRA]R[IVFY].{14,16}[GSANQKR]H',
#  'RIBOSOMAL_L20': 'K.{3}[KRCV].[LIVM]W[IVN][STNALVQCMI][RH][LIVM][NS].{3}[RKHSG]',
#  'IF3': '[KR][LIVM]{2}[DN][FY][GSTN][KR][LIVMFYS].[FY][DEQTAHI].{2}[KRQ]',
#  'RIBOSOMAL_L1E': '[NP].{3}[KRM].{2}A[LIVTK].[SA][AC][LIV].[ALCM][STL][SGAKTI].{7}[RK][GS]H',
#  'GAMMA_THIONIN': '[KRGAQS].C.{3}[SVA].{2}[FYWH].{1,2}[GF].C.{5}C.{3}C',
#  'CARBOXYLESTERASE_B_2': '[EDA][DG]CL[YTF][LIVT][DNS][LIV][LIVFYW].[PQR]',
#  'GLPT': '[QEK][RF]G.{3}[GSA][LIVF][WL][NS].[SA][HM]N[LIV][GA]G',
#  'UBIA': 'N.{3}[DEH].{2}[LIMFYT]D.{2}[VM].R[ST].{2}R.{4}[GYNKR]',
#  'CKS_1': 'YS.[KR]Y.[DE]{2}.[FY]EYRHV.[LV][PT][KRP]',
#  'CKS_2': 'H.PE.H[IV]LLF[KR]',
#  'CATHELICIDINS_1': 'Y.[ED].V.[RQ]A[LIVMA][DQG].[LIVMFY]N[EQ]',
#  'CATHELICIDINS_2': 'F.[LIVM]KET.C.{10}C.F[KR][KE]',
#  'RIBOSOMAL_S7E': '[KRAI]L.RELEKKF[SAPQG].[KRN][HED]',
#  'AUTOINDUCER_SYNTH_1': '[LMFYA]R.{3}F.{2}[KRQ].{2}W.[LIVM].{6,9}E.D.[FY]D',
#  'BACTERIAL_OPSIN_1': 'RY.[DT]W.[LIVMF][ST][TV]P[LIVM][LIVMNQ][LIVM]',
#  'ER_LUMEN_RECEPTOR_1': 'G[LIV]S.[KR].[QH].L[FY].[LIV]{2}[FYW].{2}RY',
#  'ER_LUMEN_RECEPTOR_2': 'LE[SA]VAI[LM]PQ[LI]',
#  'GLYCOSYL_HYDROL_F25_1': 'D[LIVM].{3}[NQ][PGE].{9,15}[GR].{4}[LIVMFY]{2}K.[ST]E[GS].{2}[FYL].[DN]',
#  'IGP_DEHYDRATASE_1': '[LIVMY][DE].HH.{2}E.{2}[GCA][LIVM][STAVCL][LIVMF]',
#  'IGP_DEHYDRATASE_2': '[GW].[DNIE].HH.{2}E[STAGC].[VMFYHS]K',
#  'HYDROPHOBIN': '[GN][DNQPSA].C[GSTANK][GSTADNQ][STNQI][PTIV].CC[DENQKPST]',
#  'NAD_G3PDH': '[GSA][ATIVS][LIVMYCAFST]K[DN][LIVMA][LIVMFYT][GA].[GACKMSIFT].G[ALIVMF].{2}[SGAQ][LIVMYERAKQFS].{0,1}[TLIVMFYWAQ][ETGAS].{0,1}[NDVS]',
#  'TRANSALDOLASE_2': '[LIVMA].[LIVM]K[LIVM][PAS].[STC].[DENQPAS][GC][LIVM].[AGV].{0,1}[QEKRSTH].[LIVMF]',
#  'HISTONE_H3_2': 'PF.[RA]L[VA][KRQ][DEG][IV]',
#  'BTG_1': 'Y.{2}[HP]W[FYH][APS][DE].P.KG.[GA][FY]RC[IV][RH][IV]',
#  'RIBOSOMAL_S28E': 'E[ST][EA]REA[RK].[LI]',
#  'RIBOSOMAL_S2_1': '[LIVMFA].[^GPRV][LIVMFYC]{2}[^LPC][STAC][GSTANQEKR][STALV][HY][LIVMF]G',
#  'RIBOSOMAL_S2_2': 'P.{2}[LIVMF]{2}[LIVMS].[GDN].{3}[DENL].{3}[LIVM].E.{4}[GNQKRH][LIVM][AP]',
#  'SYNDECAN': '[FY]R[IM][KR]K{2}DEGSY',
#  'PMI_I_1': 'Y.D.NHKPE',
#  'PMI_I_2': 'HAY[LIVM].G.{2}[LIVM]E.MA.SDN.[LIVM]RAG.TPK',
#  'NMU': 'F[LIVMF]FRPRN',
#  'ANTENNA_COMP_ALPHA': '[LIVFAG].[GASV][LIVFA].[IV]H.{3}[LIVM][GSTAE][STANH].{1,3}[STN]W[LIVMFYW]',
#  'ANTENNA_COMP_BETA': '[EQ].{4}[HGQ].{5}[GSTA].{3}[FYV].{3}[AG].{2}[AV]H.{7}P',
#  'TP2_1': 'H.{3}HS[NS]S.PQ[SG]',
#  'TP2_2': 'K.RK.{2}EGK.{2}K[KR]K',
#  'USP_1': 'G[LIVMFY].{1,3}[AGCY][NASMQG].C[FYWC][LIVMFCA][NSTAD][SACV].[LIVMSF][QF]',
#  'USP_2': '[YMF].[LK].[SAGNC][LIVMFT].{2}H.G.{4,6}GH[YF]',
#  'MANNITOL_DHGENASE': '[LIVMY].[FS].{2}[STAGCV].VDR[IV].[PS]',
#  'NMT_1': '[DEK][IV]N[FS]LC.HK',
#  'NMT_2': 'KFG.GDG',
#  'FAD_G3PDH_1': '[IV]GGG.{2}G[STACV]G.[AT].[DQ].{3}[RAS]G',
#  'FAD_G3PDH_2': 'GGK.{2}[GSTE]YR.{2}A',
#  'G_PROTEIN_RECEP_F3_1': '[LV].N[LIVM]{2}.LF.I[PA]Q[LIVM][STA].[STA]{3}[STAN]',
#  'G_PROTEIN_RECEP_F3_2': 'CC[FYW].C.{2}C.{4}[FYW].{2,5}[DNE].{2}[STAHENRI]C.{2}C',
#  'G_PROTEIN_RECEP_F3_3': '[FLY]N[ED][STA]K.[IV][STAG][FM][ST][MVL]',
#  'PHYTOENE_DH': '[NG].[FYWV][LIVMF].G[AGC][GS][TA][HQT]PG[STAV]G[LIVM].{5}[GS]',
#  'LY6_UPAR': '[EQR]C[LIVMFYAH].C.{5,8}C.{3,8}[EDNQSTV]C[^C].{5}C.{12,24}C',
#  'UROTENSIN_II': 'CFWKYC',
#  'SPERMADHESIN_1': 'CG.{2}[LIY].{4}G.I.{9}C.WT',
#  'SPERMADHESIN_2': 'C.KE.[LIVM]E[LIVM].[DE].{3}[GSE].{5}K.C',
#  'PTPS_1': 'CNN.{2}GHGHNY',
#  'PTPS_2': 'DHKNLD.D',
#  'CLAT_ADAPTOR_S': '[LIVMC][LIVM]Y[KR].{4}LYF',
#  'CLAT_ADAPTOR_M_1': '[IVT][GSP]WR.{2,3}[GAD].{2}[HY].{2}N.[LIVMAFY]{3}D[LIVM][LIVMT]E',
#  'CLAT_ADAPTOR_M_2': '[LIV].[FL][IQ]PP.G.[LIVMFY].[LV].{2}Y',
#  'SAA': 'ARGNY[ED]A.[QKR]RG.GG.WA',
#  'RIBOSOMAL_L30E_2': '[DE][LM]G[STALPD].{2}[GK][KR].{6}[LIVM].[LIVM].[DEN].[GI]',
#  'FHIPEP': 'R[LIVM][GSAT]EV[GSAR]ARF[STAIV]LD[GSA][LM]PGKQM[GSA]ID[GSA][DAE]',
#  'TCP1_3': 'Q[DEK]..[LIVMGTA][GA]DGT',
#  'RIBOSOMAL_S21E': '[LV]Y[IVC]PRKCS[SAT]',
#  'G10_1': 'LCC.[KR]C.{4}[DE].N.{4}C.CRVP',
#  'G10_2': 'C.HCGC[KRH]GC[SA]',
#  'SSI': 'C.P.{2,3}G.{0,1}H[PA].{4}AC[ATDE].L',
#  'SDH_CYT_1': 'RP[LIVMT].{3}[LIVM].{6}[LIVMWPK].{4}S.{2}HR.[ST]',
#  'SDH_CYT_2': 'H.{3}[GA][LIVMT]R[HF][LIVMF].[FYWM]D.[GVA]',
#  'TCTP_1': '[IFAED][GA][GASF]N[PAK]S[GTA]E[GDEVCF][PAGEQV][DEQGAV]',
#  'TCTP_2': '[FLIV].{4}[FLVH][FY][MIVCT]GE.{4,7}[DENP][GAST].[LIVM][GAVI].{3}[FYWQ]',
#  'MYELIN_PLP_2': 'C.[ST].[DE].{3}[ST][FY].L[FY]I.{4}GA',
#  'FORMATE_NITRITE_TP_1': '[LIVMA][LIVMY].G[GSTA][DES]L[FI][TN][GS]',
#  'FORMATE_NITRITE_TP_2': '[GA].{2}[CA]N[LIVMFYW]{2}VC[LV]A',
#  'TRANSPOSASE_MUTATOR': 'D.{3}G[LIVMF].{6}[STAV][LIVMFYW][PT].[STAV].{2}[QR].C.{2}H',
#  'DNAA': '[IL][GA].{2}[LIVMF][SGADENK].{0,1}[KR].H[STPA][STAV][LIVM].{2}[SGAMN].{3}[LIVM]',
#  'CRISP_1': '[GDER][HR][FYWH][TVS][QA][LIVM][LIVMA]W.{2}[STN]',
#  'CRISP_2': '[LIVMFYH][LIVMFY].C[NQRHS]Y.[PARH].[GL]N[LIVMFYWDN]',
#  'FOLYLPOLYGLU_SYNT_1': '[LIVMFY].[LIVM][STAG]GT[NK]GK.[STG].{4}[^A].[^EAD][LIVM]{2}.{3,4}[GSKQT]',
#  'FOLYLPOLYGLU_SYNT_2': '[LIVMFY]{2}[EK].G[LIVM][GA]G.{2}D.[GST].[LIVM]{2}',
#  'OSBP': 'E[KQ].[SC]H[HR][PG][PL].{1,2}[STACFI][ACGY]',
#  'NUSG': '[LIVM]FG[KRW].TP[IV].[LIVM]',
#  'RIBOSOMAL_L19': '[LIVMF].[KRGTIEQSN].[GSAIYN][KRQDAVLSIH][VGAIT][RSNAK].{0,1}[KRAQ][SAKG][KYR][KLI][LYSFT][YF][LIM][RK]',
#  'GLYCOPROTEASE': '[KRC][GSAT].{4}[FYWLMH][DQNGKRH].P.[LIVMFY].{3}H.{2}[GSA]H[LIVMFA]',
#  'STEROL_REDUCT_1': 'G.{2}[LIVMF][IFYH][DN].[FYWM].G.{2}[LF][NY]P[RQ]',
#  'STEROL_REDUCT_2': '[LIVM]{2}[LIVMFT][HWD]R.{2}RD.{3}C.{2}KY[GK].{2}[FW].{2}Y',
#  'COPROGEN_OXIDASE': 'K.[WQA][CA].{2}[FYH]{2}.[LIVM].[HY]R.E.RG[LIVMT]GG[LIVM]F[FY]D',
#  'PTR2_1': '[GA][GAS][LIVMFYWA][LIVM][GAS]D.[LIVMFYWT][LIVMFYW]G.{3}[TAV][IV].{3}[GSTAV].[LIVMF].{3}[GA]',
#  'PTR2_2': '[FYT].{2}[LMFY][FYV][LIVMFYWA].[IVG]N[LIVMAG]G[GSA][LIMF]',
#  'PR55_1': 'EFDYLKSLEIEEKIN',
#  'PR55_2': '[NH][AG]H[TAD]YHINSIS[LIVMN][NS]SD',
#  'PHOTOSYSTEM_I_PSAGK': '[GTND][FPMI].[LIVMH].[DEAT].{2}[GA].[GTAM][STA].GH.[LIVM][GAS]',
#  'GLYCOSYL_HYDROL_F39': 'W.FE.WNEP[DN]',
#  'DEHYDROQUINASE_I': 'D[LIVM][DE][LIVMN].{18,20}[LIVM]{2}.[SC][NHY]H[DN]',
#  'DEHYDROQUINASE_II': '[LIVM][NQHS]GPN[LVI].{2}[LT]G.R[QED].{3}[FY]G',
#  'RNA_POL_M_15KD': '[FY]C[^M][DEKSTG]C[GNK][DNSA][LIFVMHG][LIVM].{8,14}C.{1,2}C',
#  'PPM_1': '[LIVMFY][LIVMFYA][GSAC][LIVM][FYC]DGH[GAV]',
#  'GH16_1': 'E[LIV]D[LIVF].{0,1}E.{2}[GQ][KRNF].[PSTA]',
#  'PTS_EIIB_TYPE_1_CYS': 'N[LIVMFY].{5}C.TR[LIVMF].[LIVMF].[LIVM].[DQEN]',
#  'HSP70_3': '[LIVMY].[LIVMF].GG.[ST][^LS][LIVM]P.[LIVM].[DEQKRSTA]',
#  'SBP_BACTERIAL_1': '[GAP][LIVMFA][STAVDN].[^H].{2}[GSAV][LIVMFY]{2}Y[ND].{3}[LIVMF].[KNDE]',
#  'SBP_BACTERIAL_3': 'G[FYIL][DE][LIVMT][DE][LIVMF][^PS][^YG].[LIVMA][VAGC][^TPRG][^GL][LIVMAGN]',
#  'SBP_BACTERIAL_5': '[AG].{6,7}[DNEG].{2}[STAIVE][LIVMFYWA].[LIVMFY].[LIVM][KR][KRHDE][GDN][LIVMA][KNGSP][FW]',
#  'STATHMIN_2': 'AE[KR]REHE[KR]EV',
#  'HOMOSER_DHGENASE': 'A.{3}G[LIVMFY][STAG].{2,3}[DNS]P.{2}D[LIVM].G.D.{3}K',
#  'TRANSPOSASE_IS30': 'RG.{2}EN.NG[LIVM]{2}R[QE][LIVMFY]{2}PK',
#  'SQUALEN_PHYTOEN_SYN_1': 'Y[CSAM].{2}[VSG]A[GSA][LIVAT][IV]G.{2}[LMSC].{2}[LIV]',
#  'SQUALEN_PHYTOEN_SYN_2': '[LIVM]G.{3}Q.{2,3}[ND][IFL].[RE]D[LIVMFY].{2}[DE].{4,7}R.[FY].P',
#  'LON_SER': 'DG[PD]SA[GS][LIVMCA][TA][LIVM]',
#  'HMA_1': '[LIVNS].[^L][LIVMFA].C.[STAGCDNH]C.{3}[LIVFG][^LV].{2}[LIV].{9,11}[IVA].[LVFYS]',
#  'RIBOSOMAL_S6': 'G.[KRC][DENQRH]L[SA]Y.I[KRNSA]',
#  'YJEF_C_1': '[SAV][IVW][LVA][LIV]G[PNS]GL[GP].[DENQT]',
#  'YJEF_C_2': '[GA]G.GD[TV][LT][STA]G.[LIVM]',
#  'CALPONIN_1': '[LIVM].[LS]Q[MASY]G[STY][NT][KRQ].{2}[STN]Q.G.{3,4}G',
#  'ARGINASE_1': '[ST][LIVMFY]D[LIVM]D.{3}[PAQ].{3}P[GSA].{7}G',
#  'TRANSALDOLASE_1': '[DGH][IVSAC]T[ST]NP[STA][LIVMF]{2}',
#  'DNA_LIGASE_N1': 'K[LIVMF]DG[LIVMAS][SAG].{4}Y.{2}[GRD].[LF].{4}[ST]RG[DN]G.{2}G[DE][DENL]',
#  'DNA_LIGASE_N2': '[IV]G[KR][ST]G.[LIVM][STNK].[VTLYF].{2}[LVMF].[PS][IV]',
#  'SAICAR_SYNTHETASE_1': '[LIVMRPA][LIVFY][PLNRKG][LIVMF]E.[IV][LVCATI]R.{3}[TAEYSI]G[ST]',
#  'SAICAR_SYNTHETASE_2': '[LI][IVCAP]D.K[LIFY]E[FI]G',
#  'FLIP_1': '[PA][AS][FY].[LIVT][STH][EQ][LI].{2}[GA]F[KREQ][IM][GV][LIF]',
#  'FLIP_2': 'P[LIVMF]K[LIVMF]{5}.[LIVMA][DNGS]GW',
#  ...}

# %%
# Fetch protein sequences from UniProt
def fetch_protein_sequence(accession):
    url = f"https://www.uniprot.org/uniprot/{accession}.fasta"
    response = requests.get(url)
    if response.status_code == 200:
        return "".join(response.text.split("\n")[1:])  # Remove FASTA header
    return None

# %%
# Find Motifs Inside Disordered Regions
def find_motifs(sequence, motifs, disordered_regions):
    """Find motifs inside disordered protein regions."""
    matches = []
    for name, pattern in motifs.items():
        for match in re.finditer(pattern, sequence):
            start, end = match.start(), match.end()
            # Ensure match is inside disordered regions
            if any(s <= start and end <= e for s, e in disordered_regions):
                matches.append((name, start, end, sequence[start:end]))
    return matches

# %%
# Compute Z-Score and P-Value for Motif Conservation
def compute_conservation_stats(motif_counts):
    """Calculate Z-score & p-value for significantly conserved motifs."""
    counts = np.array(list(motif_counts.values()))
    mean, std = np.mean(counts), np.std(counts)

    significant_motifs = {}
    for motif, count in motif_counts.items():
        z_score = (count - mean) / std if std > 0 else 0
        p_value = 1 - norm.cdf(z_score)  # Right-tailed test
        if p_value < 0.05:  # Significance threshold
            significant_motifs[motif] = (count, z_score, p_value)

    return significant_motifs

# %%
prosite_motif_counts = {}
elm_motif_counts = {}

for protein_id in protein_ids:
    sequence = fetch_protein_sequence(protein_id)
    if sequence and protein_id in disordered_regions:
        disorder_regions = disordered_regions[protein_id]

        # Find motifs in ProSite & ELM
        prosite_matches = find_motifs(sequence, prosite_patterns, disorder_regions)
        elm_matches = find_motifs(sequence, elm_patterns, disorder_regions)

        # Count occurrences
        for match in prosite_matches:
            motif_name = match[0]
            prosite_motif_counts[motif_name] = prosite_motif_counts.get(motif_name, 0) + 1

        for match in elm_matches:
            motif_name = match[0]
            elm_motif_counts[motif_name] = elm_motif_counts.get(motif_name, 0) + 1


# Compute Significant Motifs
prosite_significant_motifs = compute_conservation_stats(prosite_motif_counts)
elm_significant_motifs = compute_conservation_stats(elm_motif_counts)

# Save Results
prosite_results = pd.DataFrame.from_dict(prosite_significant_motifs, orient="index", columns=["Count", "Z-Score", "P-Value"])
elm_results = pd.DataFrame.from_dict(elm_significant_motifs, orient="index", columns=["Count", "Z-Score", "P-Value"])

# %%
prosite_results
# Out:
#                   Count   Z-Score   P-Value
# CK2_PHOSPHO_SITE    204  2.006186  0.022418

# %%
prosite_pd[prosite_pd['Name'] == 'CK2_PHOSPHO_SITE']
# Out:
#                Name Accession                             Description  \
# 3  CK2_PHOSPHO_SITE   PS00006  Casein kinase II phosphorylation site.
#
#            Pattern Instances_sprot         Regex
# 3  [ST]-x(2)-[DE].                  [ST].{2}[DE]

# %%
elm_results
# Out:
#                      Count   Z-Score       P-Value
# MOD_GSK3_1             191  5.114677  1.571393e-07
# DOC_USP7_MATH_1        119  2.987711  1.405377e-03
# LIG_WD40_WDR5_VDV_2    126  3.194499  7.003686e-04
# MOD_CK2_1              107  2.633216  4.229022e-03
# DOC_WW_Pin1_4          111  2.751381  2.967227e-03
# LIG_SH3_3               79  1.806063  3.545426e-02
# MOD_GlcNHglycan        142  3.667158  1.226305e-04
# MOD_ProDKin_1          104  2.544593  5.470262e-03
# MOD_CK1_1              156  4.080735  2.244676e-05

# %%
elm_classes_pd[elm_classes_pd['ELMIdentifier'].isin(['MOD_GSK3_1', 'DOC_USP7_MATH_1', 'LIG_WD40_WDR5_VDV_2', 'MOD_CK2_1',
                                                     'DOC_WW_Pin1_4', 'LIG_SH3_3', 'MOD_GlcNHglycan', 'MOD_ProDKin_1', 'MOD_CK1_1'])]
# Out:
#       Accession        ELMIdentifier  \
# 81   ELME000239      DOC_USP7_MATH_1
# 85   ELME000136        DOC_WW_Pin1_4
# 240  ELME000155            LIG_SH3_3
# 274  ELME000365  LIG_WD40_WDR5_VDV_2
# 292  ELME000063            MOD_CK1_1
# 293  ELME000064            MOD_CK2_1
# 297  ELME000085      MOD_GlcNHglycan
# 298  ELME000053           MOD_GSK3_1
# 317  ELME000159        MOD_ProDKin_1
#
#                               FunctionalSiteName  \
# 81                            USP7 binding motif
# 85                             WW domain ligands
# 240                           SH3 domain ligands
# 274  WDR5 WD40 repeat (blade 5,6)-binding ligand
# 292   Casein kinase 1 (CK1) Phosphorylation site
# 293   Casein kinase 2 (CK2) Phosphorylation site
# 297            Glycosaminoglycan attachment site
# 298                    GSK3 phosphorylation site
# 317                    MAPK Phosphorylation Site
#
#                                            Description  \
# 81   The USP7 MATH domain binding motif variant bas...
# 85   The Class IV WW domain interaction motif is re...
# 240  This is the motif recognized by those SH3 doma...
# 274  Fungi-specific variant of the WDR5-binding mot...
# 292                           CK1 phosphorylation site
# 293         Casein kinase 2 (CK2) phosphorylation site
# 297                  Glycosaminoglycan attachment site
# 298              GSK3 phosphorylation recognition site
# 317  Proline-Directed Kinase (e.g. MAPK) phosphoryl...
#
#                                   Regex  Probability  #Instances  \
# 81                [PA][^P][^FYWIL]S[^P]     0.012388          10
# 85                          ...([ST])P.     0.015433          96
# 240                          ...[PV]..P     0.013173          26
# 274  [EDSTY].{0,4}[VIPLA][TSDEKR][ILVA]     0.046779           2
# 292                        S..([ST])...     0.017041          27
# 293                        ...([ST])..E     0.014568          34
# 297                  [ED]{0,3}.(S)[GA].     0.017919           6
# 298                    ...([ST])...[ST]     0.026787          22
# 317                        ...([ST])P..     0.015433          38
#
#      #Instances_in_PDB
# 81                   6
# 85                   1
# 240                  1
# 274                  0
# 292                  0
# 293                  0
# 297                  0
# 298                  0
# 317                  0
